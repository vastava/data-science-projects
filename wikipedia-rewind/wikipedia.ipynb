# %%
import urllib.request as urllib2
import time
from datetime import datetime
import json
from urllib.parse import urlencode, quote_plus

# %%
TOP_API_URL = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'\
              'top/{lang}.{project}/all-access/{year}/{month}/{day}'

def get_traffic(year, month, day):
    '''\
    Get the traffic report for the top 1000 articles for a given day.
    TODO: Get from local file, if available
    '''
    url = TOP_API_URL.format(lang='en',
                             project='wikipedia',
                             year=year,
                             month=month,
                             day=day)
#     if DEBUG:
#         print 'Getting %s' % url
    resp = urllib2.urlopen(url)
    resp_bytes = resp.read()
#         rec.success('Fetched {len_bytes} bytes from {url}',
#                     len_bytes=len(resp_bytes), url=url)

    data = json.loads(resp_bytes)
    articles = data['items'][0]['articles']
    return articles

# %%
get_traffic('2020', '02','29')
# Out:
# [{'article': 'Main_Page', 'views': 11011950, 'rank': 1},
#  {'article': 'United_States_Senate', 'views': 5785633, 'rank': 2},
#  {'article': 'Special:Search', 'views': 1379510, 'rank': 3},
#  {'article': 'February_29', 'views': 449520, 'rank': 4},
#  {'article': '2019–20_coronavirus_outbreak', 'views': 401916, 'rank': 5},
#  {'article': 'The_Invisible_Man_(2020_film)', 'views': 275387, 'rank': 6},
#  {'article': 'Coronavirus', 'views': 268392, 'rank': 7},
#  {'article': 'Carlton_Tavern,_Kilburn', 'views': 244195, 'rank': 8},
#  {'article': '2019–20_coronavirus_outbreak_by_country_and_territory',
#   'views': 158829,
#   'rank': 9},
#  {'article': 'Boris_Johnson', 'views': 143594, 'rank': 10},
#  {'article': 'Mila_Kunis', 'views': 142252, 'rank': 11},
#  {'article': 'Leap_year', 'views': 139097, 'rank': 12},
#  {'article': 'Roman_Polanski', 'views': 138395, 'rank': 13},
#  {'article': 'Zhong_Nanshan', 'views': 126388, 'rank': 14},
#  {'article': 'Muhyiddin_Yassin', 'views': 124799, 'rank': 15},
#  {'article': 'Bible', 'views': 118980, 'rank': 16},
#  {'article': 'Spanish_flu', 'views': 115849, 'rank': 17},
#  {'article': 'WrestleMania_36', 'views': 104952, 'rank': 18},
#  {'article': 'Parasite_(2019_film)', 'views': 104200, 'rank': 19},
#  {'article': 'Third_Battle_of_Panipat', 'views': 103669, 'rank': 20},
#  {'article': 'Deaths_in_2020', 'views': 96759, 'rank': 21},
#  {'article': 'Altered_Carbon_(TV_series)', 'views': 94884, 'rank': 22},
#  {'article': 'Benjaman_Kyle', 'views': 93062, 'rank': 23},
#  {'article': 'Elimination_Chamber_(2020)', 'views': 91071, 'rank': 24},
#  {'article': 'Dietmar_Hopp', 'views': 90152, 'rank': 25},
#  {'article': 'Richard_Ramirez', 'views': 88824, 'rank': 26},
#  {'article': '2020_coronavirus_outbreak_in_Italy', 'views': 88503, 'rank': 27},
#  {'article': 'Coronavirus_disease_2019', 'views': 84038, 'rank': 28},
#  {'article': 'Carrie_Symonds', 'views': 79804, 'rank': 29},
#  {'article': 'Ken_Miles', 'views': 79648, 'rank': 30},
#  {'article': 'Miguel_Ángel_Félix_Gallardo', 'views': 77643, 'rank': 31},
#  {'article': 'Tyson_Fury', 'views': 72478, 'rank': 32},
#  {'article': 'Super_Tuesday', 'views': 70674, 'rank': 33},
#  {'article': '2020_Democratic_Party_presidential_primaries',
#   'views': 69040,
#   'rank': 34},
#  {'article': 'Freeman_Dyson', 'views': 68192, 'rank': 35},
#  {'article': "RuPaul's_Drag_Race_(season_12)", 'views': 67656, 'rank': 36},
#  {'article': 'Michael_Bloomberg', 'views': 66581, 'rank': 37},
#  {'article': 'The_Eyes_of_Darkness', 'views': 65776, 'rank': 38},
#  {'article': 'Bernie_Sanders', 'views': 64803, 'rank': 39},
#  {'article': 'Wikipedia', 'views': 64799, 'rank': 40},
#  {'article': 'Knives_Out', 'views': 64782, 'rank': 41},
#  {'article': 'Love_Is_Blind_(TV_series)', 'views': 63344, 'rank': 42},
#  {'article': 'BBC_World_Service', 'views': 62838, 'rank': 43},
#  {'article': 'Hunters_(2020_TV_series)', 'views': 61337, 'rank': 44},
#  {'article': 'North_East_Delhi_riots', 'views': 59893, 'rank': 45},
#  {'article': 'Priti_Patel', 'views': 59658, 'rank': 46},
#  {'article': 'Wikipedia:Picture_of_the_day', 'views': 56332, 'rank': 47},
#  {'article': 'Maria_Sharapova', 'views': 55930, 'rank': 48},
#  {'article': 'Crash_Landing_on_You', 'views': 54442, 'rank': 49},
#  {'article': 'I_Am_Not_Okay_with_This', 'views': 54126, 'rank': 50},
#  {'article': 'Donald_Trump', 'views': 54048, 'rank': 51},
#  {'article': '2020_South_Carolina_Democratic_primary',
#   'views': 53588,
#   'rank': 52},
#  {'article': 'Portal:Current_events', 'views': 53428, 'rank': 53},
#  {'article': 'Donald_trump', 'views': 53413, 'rank': 54},
#  {'article': 'Candyman_(1992_film)', 'views': 53047, 'rank': 55},
#  {'article': 'All_the_Bright_Places_(film)', 'views': 52418, 'rank': 56},
#  {'article': 'Pete_Davidson', 'views': 52148, 'rank': 57},
#  {'article': '2019–20_Wuhan_coronavirus_outbreak', 'views': 51843, 'rank': 58},
#  {'article': '2009_flu_pandemic', 'views': 50963, 'rank': 59},
#  {'article': "Kepler's_Supernova", 'views': 49568, 'rank': 60},
#  {'article': 'Alexandria_Ocasio-Cortez', 'views': 49532, 'rank': 61},
#  {'article': 'Onward_(film)', 'views': 48817, 'rank': 62},
#  {'article': 'Eurovision_Song_Contest_2020', 'views': 48202, 'rank': 63},
#  {'article': 'Rich_Energy', 'views': 47958, 'rank': 64},
#  {'article': 'Roman_Polanski_sexual_abuse_case', 'views': 47908, 'rank': 65},
#  {'article': 'Thappad', 'views': 47735, 'rank': 66},
#  {'article': 'Kobe_Bryant', 'views': 45782, 'rank': 67},
#  {'article': 'Microsoft_Office', 'views': 45692, 'rank': 68},
#  {'article': 'Philip_Rutnam', 'views': 45425, 'rank': 69},
#  {'article': 'Super_ShowDown_(2020)', 'views': 45235, 'rank': 70},
#  {'article': 'Ted_Kaczynski', 'views': 44833, 'rank': 71},
#  {'article': 'XXXX', 'views': 44758, 'rank': 72},
#  {'article': 'Achtung_Baby', 'views': 44732, 'rank': 73},
#  {'article': 'Ismaïla_Sarr', 'views': 44194, 'rank': 74},
#  {'article': 'Sonic_the_Hedgehog_(film)', 'views': 43648, 'rank': 75},
#  {'article': 'Taliban', 'views': 43386, 'rank': 76},
#  {'article': 'Joe_Coulombe', 'views': 43100, 'rank': 77},
#  {'article': 'Concert_tour', 'views': 42999, 'rank': 78},
#  {'article': 'Doja_Cat', 'views': 42771, 'rank': 79},
#  {'article': '1996_California_Proposition_218', 'views': 42600, 'rank': 80},
#  {'article': 'Sex', 'views': 41830, 'rank': 81},
#  {'article': 'List_of_Bollywood_films_of_2020', 'views': 41750, 'rank': 82},
#  {'article': 'Billie_Eilish', 'views': 41268, 'rank': 83},
#  {'article': 'All_the_Bright_Places', 'views': 41252, 'rank': 84},
#  {'article': 'Candyman_(2020_film)', 'views': 40971, 'rank': 85},
#  {'article': 'Sharon_Tate', 'views': 40935, 'rank': 86},
#  {'article': 'Daniel_Andreas_San_Diego', 'views': 40579, 'rank': 87},
#  {'article': 'Adèle_Haenel', 'views': 40568, 'rank': 88},
#  {'article': 'Anne-Marie_(singer)', 'views': 40346, 'rank': 89},
#  {'article': 'Jojo_Rabbit', 'views': 40167, 'rank': 90},
#  {'article': 'UFC_Fight_Night:_Benavidez_vs._Figueiredo',
#   'views': 39476,
#   'rank': 91},
#  {'article': 'XFL_(2020)', 'views': 39290, 'rank': 92},
#  {'article': 'Severe_acute_respiratory_syndrome', 'views': 39257, 'rank': 93},
#  {'article': 'Amado_Carrillo_Fuentes', 'views': 38858, 'rank': 94},
#  {'article': 'The_Invincibles_(football)', 'views': 38688, 'rank': 95},
#  {'article': '2020_coronavirus_outbreak_in_Europe',
#   'views': 38553,
#   'rank': 96},
#  {'article': 'John_Tenniel', 'views': 38392, 'rank': 97},
#  {'article': 'United_States', 'views': 38256, 'rank': 98},
#  {'article': 'Pandemic', 'views': 38256, 'rank': 98},
#  {'article': 'Hailey_Baldwin', 'views': 38142, 'rank': 100},
#  {'article': 'Tom_Steyer', 'views': 37807, 'rank': 101},
#  {'article': 'Elton_John', 'views': 37306, 'rank': 102},
#  {'article': 'Sophia_Lillis', 'views': 37011, 'rank': 103},
#  {'article': '2019_Formula_One_World_Championship',
#   'views': 36676,
#   'rank': 104},
#  {'article': 'Ala_Vaikunthapurramuloo', 'views': 36285, 'rank': 105},
#  {'article': 'Birds_of_Prey_(2020_film)', 'views': 35908, 'rank': 106},
#  {'article': 'NXT_TakeOver:_Tampa_Bay', 'views': 35378, 'rank': 107},
#  {'article': 'Judy_Garland', 'views': 35134, 'rank': 108},
#  {'article': 'Severe_acute_respiratory_syndrome_coronavirus_2',
#   'views': 35051,
#   'rank': 109},
#  {'article': 'Dua_Lipa', 'views': 34908, 'rank': 110},
#  {'article': 'Black_Death', 'views': 34670, 'rank': 111},
#  {'article': 'Elisabeth_Moss', 'views': 34645, 'rank': 112},
#  {'article': 'Distribution_resource_planning', 'views': 34523, 'rank': 113},
#  {'article': 'Lady_Gaga', 'views': 34170, 'rank': 114},
#  {'article': 'Fred_Rogers', 'views': 33843, 'rank': 115},
#  {'article': 'Star_Trek:_Picard', 'views': 33837, 'rank': 116},
#  {'article': 'Pete_Buttigieg', 'views': 33810, 'rank': 117},
#  {'article': 'YouTube', 'views': 33434, 'rank': 118},
#  {'article': 'Joker_(2019_film)', 'views': 33408, 'rank': 119},
#  {'article': 'John_Cena', 'views': 33353, 'rank': 120},
#  {'article': 'Fantasy_Island_(film)', 'views': 33275, 'rank': 121},
#  {'article': '2020_coronavirus_outbreak_in_Germany',
#   'views': 33012,
#   'rank': 122},
#  {'article': 'Pablo_Acosta_Villarreal', 'views': 32686, 'rank': 123},
#  {'article': 'Once_Upon_a_Time_in_Hollywood', 'views': 32603, 'rank': 124},
#  {'article': 'Panipat_(film)', 'views': 32527, 'rank': 125},
#  {'article': 'Elizabeth_II', 'views': 32412, 'rank': 126},
#  {'article': 'Anthony_Joshua', 'views': 32251, 'rank': 127},
#  {'article': '2020_coronavirus_outbreak_in_South_Korea',
#   'views': 31584,
#   'rank': 128},
#  {'article': 'Mike_Tyson', 'views': 31542, 'rank': 129},
#  {'article': 'The_Pirate_Bay', 'views': 31533, 'rank': 130},
#  {'article': 'Harvey_Weinstein', 'views': 31466, 'rank': 131},
#  {'article': 'Bad_Bunny', 'views': 31313, 'rank': 132},
#  {'article': 'Bombshell_(2019_film)', 'views': 31067, 'rank': 133},
#  {'article': 'Locke_&_Key_(TV_series)', 'views': 31058, 'rank': 134},
#  {'article': 'Periodic_table', 'views': 30927, 'rank': 135},
#  {'article': 'Giannis_Antetokounmpo', 'views': 30642, 'rank': 136},
#  {'article': 'Apple_Network_Server', 'views': 30564, 'rank': 137},
#  {'article': 'Elon_Musk', 'views': 30259, 'rank': 138},
#  {'article': 'Citizenship_(Amendment)_Act,_2019', 'views': 30163, 'rank': 139},
#  {'article': "Charlie's_Angels_(2019_film)", 'views': 29916, 'rank': 140},
#  {'article': 'Zoo_TV_Tour', 'views': 29887, 'rank': 141},
#  {'article': 'Joaquín_"El_Chapo"_Guzmán', 'views': 29520, 'rank': 142},
#  {'article': 'Help:IPA/English', 'views': 29311, 'rank': 143},
#  {'article': '1917_(2019_film)', 'views': 29091, 'rank': 144},
#  {'article': 'Coca-Cola', 'views': 29024, 'rank': 145},
#  {'article': 'Ford_v_Ferrari', 'views': 28984, 'rank': 146},
#  {'article': 'The_Stranger_(British_TV_series)', 'views': 28701, 'rank': 147},
#  {'article': 'Narcos:_Mexico', 'views': 28461, 'rank': 148},
#  {'article': 'India', 'views': 28448, 'rank': 149},
#  {'article': 'Carroll_Shelby', 'views': 28384, 'rank': 150},
#  {'article': 'The_Invisible_Man', 'views': 28263, 'rank': 151},
#  {'article': "Bachelor's_Day_(tradition)", 'views': 28260, 'rank': 152},
#  {'article': 'Freddie_Mercury', 'views': 27999, 'rank': 153},
#  {'article': 'Superman:_Red_Son_(film)', 'views': 27813, 'rank': 154},
#  {'article': 'Hyun_Bin', 'views': 27807, 'rank': 155},
#  {'article': 'Justin_Bieber', 'views': 27789, 'rank': 156},
#  {'article': 'Marina_Wheeler', 'views': 27734, 'rank': 157},
#  {'article': 'Brooklyn', 'views': 27650, 'rank': 158},
#  {'article': '2020_coronavirus_outbreak_in_the_United_States',
#   'views': 27596,
#   'rank': 159},
#  {'article': 'Uncut_Gems', 'views': 27486, 'rank': 160},
#  {'article': 'Frozen_II', 'views': 27462, 'rank': 161},
#  {'article': 'AEW_Revolution', 'views': 27458, 'rank': 162},
#  {'article': 'Ana_de_Armas', 'views': 27128, 'rank': 163},
#  {'article': 'List_of_Marvel_Cinematic_Universe_films',
#   'views': 26856,
#   'rank': 164},
#  {'article': 'Inter_Miami_CF', 'views': 26774, 'rank': 165},
#  {'article': 'BTS_(band)', 'views': 26659, 'rank': 166},
#  {'article': "Trader_Joe's", 'views': 26433, 'rank': 167},
#  {'article': 'Itaewon_Class', 'views': 26349, 'rank': 168},
#  {'article': 'Barack_Obama', 'views': 26160, 'rank': 169},
#  {'article': 'Sadashivrao_Bhau', 'views': 25931, 'rank': 170},
#  {'article': 'Aileen_Wuornos', 'views': 25930, 'rank': 171},
#  {'article': 'An_Officer_and_a_Spy_(film)', 'views': 25761, 'rank': 172},
#  {'article': 'Michael_Jordan', 'views': 25739, 'rank': 173},
#  {'article': 'Johnny_Cash', 'views': 25723, 'rank': 174},
#  {'article': 'Index_of_Windows_games_(S)', 'views': 25719, 'rank': 175},
#  {'article': 'Deontay_Wilder', 'views': 25405, 'rank': 176},
#  {'article': 'List_of_epidemics', 'views': 25389, 'rank': 177},
#  {'article': 'The_Suicide_Squad_(film)', 'views': 25342, 'rank': 178},
#  {'article': 'Elle_Fanning', 'views': 25175, 'rank': 179},
#  {'article': 'Pablo_Escobar', 'views': 25125, 'rank': 180},
#  {'article': 'Jumanji:_The_Next_Level', 'views': 25093, 'rank': 181},
#  {'article': 'Christian_Horner', 'views': 24954, 'rank': 182},
#  {'article': 'Joaquin_Phoenix', 'views': 24950, 'rank': 183},
#  {'article': 'Oliver_Jackson-Cohen', 'views': 24929, 'rank': 184},
#  {'article': 'A_Quiet_Place_(film)', 'views': 24871, 'rank': 185},
#  {'article': 'Elizabeth_Warren', 'views': 24864, 'rank': 186},
#  {'article': 'Better_Call_Saul', 'views': 24721, 'rank': 187},
#  {'article': 'Keanu_Reeves', 'views': 24700, 'rank': 188},
#  {'article': 'Geri_Halliwell', 'views': 24557, 'rank': 189},
#  {'article': 'Lewis_Hamilton', 'views': 24227, 'rank': 190},
#  {'article': 'Contagion_(2011_film)', 'views': 24139, 'rank': 191},
#  {'article': 'Bill_Goldberg', 'views': 23918, 'rank': 192},
#  {'article': 'Greta_Thunberg', 'views': 23879, 'rank': 193},
#  {'article': 'Melania_Trump', 'views': 23775, 'rank': 194},
#  {'article': 'Halsey_(singer)', 'views': 23569, 'rank': 195},
#  {'article': 'Stupid_Love_(Lady_Gaga_song)', 'views': 23554, 'rank': 196},
#  {'article': 'Influenza', 'views': 23238, 'rank': 197},
#  {'article': 'Al_Pacino', 'views': 23230, 'rank': 198},
#  {'article': 'Altered_Carbon', 'views': 23114, 'rank': 199},
#  {'article': 'The_Call_of_the_Wild_(2020_film)', 'views': 23073, 'rank': 200},
#  {'article': 'Muhammad_Ali', 'views': 23065, 'rank': 201},
#  {'article': 'Prime_Minister_of_Malaysia', 'views': 22999, 'rank': 202},
#  {'article': 'Adolf_Hitler', 'views': 22851, 'rank': 203},
#  {'article': 'Dwayne_Johnson', 'views': 22811, 'rank': 204},
#  {'article': 'Kannum_Kannum_Kollaiyadithaal', 'views': 22799, 'rank': 205},
#  {'article': 'Draupathi_(2020_film)', 'views': 22728, 'rank': 206},
#  {'article': '2020_Formula_One_World_Championship',
#   'views': 22702,
#   'rank': 207},
#  {'article': '2020_United_States_presidential_election',
#   'views': 22429,
#   'rank': 208},
#  {'article': 'United_Kingdom', 'views': 22388, 'rank': 209},
#  {'article': 'Princess_Margaret,_Countess_of_Snowdon',
#   'views': 22201,
#   'rank': 210},
#  {'article': 'Justice_Smith', 'views': 22102, 'rank': 211},
#  {'article': 'Girl_on_the_Third_Floor', 'views': 22057, 'rank': 212},
#  {'article': 'Special:MyContributions', 'views': 21862, 'rank': 213},
#  {'article': 'Joe_Biden', 'views': 21819, 'rank': 214},
#  {'article': 'Portrait_of_a_Lady_on_Fire', 'views': 21800, 'rank': 215},
#  {'article': 'The_Last_Thing_He_Wanted_(film)', 'views': 21694, 'rank': 216},
#  {'article': 'Shubh_Mangal_Zyada_Saavdhan', 'views': 21689, 'rank': 217},
#  {'article': 'Special:MyTalk', 'views': 21664, 'rank': 218},
#  {'article': 'Haas_F1_Team', 'views': 21664, 'rank': 218},
#  {'article': 'John_Ratcliffe_(American_politician)',
#   'views': 21645,
#   'rank': 220},
#  {'article': 'Tom_Cruise', 'views': 21473, 'rank': 221},
#  {'article': 'Mardi_Gras', 'views': 21446, 'rank': 222},
#  {'article': '2020_coronavirus_outbreak_in_Spain',
#   'views': 21395,
#   'rank': 223},
#  {'article': 'Non-binary_gender', 'views': 21365, 'rank': 224},
#  {'article': 'TSG_1899_Hoffenheim', 'views': 21273, 'rank': 225},
#  {'article': 'Wikipedia:Contact_us', 'views': 21120, 'rank': 226},
#  {'article': 'No_Time_to_Die', 'views': 21094, 'rank': 227},
#  {'article': 'Wikipedia:About', 'views': 21001, 'rank': 228},
#  {'article': 'Guns_Akimbo', 'views': 20975, 'rank': 229},
#  {'article': 'Steven_Spielberg', 'views': 20923, 'rank': 230},
#  {'article': 'The_Outsider_(miniseries)', 'views': 20829, 'rank': 231},
#  {'article': 'Sun_Yang', 'views': 20782, 'rank': 232},
#  {'article': 'Son_Ye-jin', 'views': 20733, 'rank': 233},
#  {'article': 'Wuhan', 'views': 20706, 'rank': 234},
#  {'article': 'Dia_Mirza', 'views': 20703, 'rank': 235},
#  {'article': 'Post_Malone', 'views': 20695, 'rank': 236},
#  {'article': 'List_of_Bollywood_films_of_2019', 'views': 20669, 'rank': 237},
#  {'article': 'List_of_presidents_of_the_United_States',
#   'views': 20563,
#   'rank': 238},
#  {'article': 'My_Hero_Academia:_Heroes_Rising', 'views': 20553, 'rank': 239},
#  {'article': 'Rock_music', 'views': 20543, 'rank': 240},
#  {'article': 'Jeff_Bezos', 'views': 20526, 'rank': 241},
#  {'article': 'Rafael_Caro_Quintero', 'views': 20518, 'rank': 242},
#  {'article': 'Facebook', 'views': 20412, 'rank': 243},
#  {'article': 'Godzilla:_King_of_the_Monsters_(2019_film)',
#   'views': 20410,
#   'rank': 244},
#  {'article': 'Taika_Waititi', 'views': 20279, 'rank': 245},
#  {'article': 'Google', 'views': 20268, 'rank': 246},
#  {'article': 'World_War_II', 'views': 20243, 'rank': 247},
#  {'article': 'Marge_in_Chains', 'views': 20121, 'rank': 248},
#  {'article': 'Special:RecentChanges', 'views': 20074, 'rank': 249},
#  {'article': 'COVID-19', 'views': 20053, 'rank': 250},
#  {'article': 'Mark_Wahlberg', 'views': 20045, 'rank': 251},
#  {'article': 'The_World_(archipelago)', 'views': 20024, 'rank': 252},
#  {'article': '2020_Summer_Olympics', 'views': 20006, 'rank': 253},
#  {'article': 'Guenther_Steiner', 'views': 19828, 'rank': 254},
#  {'article': '2020_coronavirus_outbreak_in_Japan',
#   'views': 19810,
#   'rank': 255},
#  {'article': 'Watford_F.C.', 'views': 19749, 'rank': 256},
#  {'article': 'List_of_most-viewed_YouTube_videos',
#   'views': 19702,
#   'rank': 257},
#  {'article': 'The_Irishman', 'views': 19677, 'rank': 258},
#  {'article': "The_World's_Billionaires", 'views': 19671, 'rank': 259},
#  {'article': 'Mahathir_Mohamad', 'views': 19650, 'rank': 260},
#  {'article': 'James_Dean', 'views': 19534, 'rank': 261},
#  {'article': 'Mewtwo_Strikes_Back:_Evolution', 'views': 19512, 'rank': 262},
#  {'article': 'Stephen_Hawking', 'views': 19505, 'rank': 263},
#  {'article': 'The_Witcher_(TV_series)', 'views': 19498, 'rank': 264},
#  {'article': 'War_in_Afghanistan_(2001–present)', 'views': 19440, 'rank': 265},
#  {'article': 'Anthony_S._Fauci', 'views': 19403, 'rank': 266},
#  {'article': 'Taylor_Swift', 'views': 19317, 'rank': 267},
#  {'article': 'Premier_League', 'views': 19283, 'rank': 268},
#  {'article': 'List_of_United_States_cities_by_population',
#   'views': 19151,
#   'rank': 269},
#  {'article': 'Cristiano_Ronaldo', 'views': 19128, 'rank': 270},
#  {'article': 'Bhoot_–_Part_One:_The_Haunted_Ship',
#   'views': 19061,
#   'rank': 271},
#  {'article': 'Charles_Manson', 'views': 19054, 'rank': 272},
#  {'article': 'Hawaii_Five-0_(2010_TV_series)', 'views': 19047, 'rank': 273},
#  {'article': 'Priyanka_Chopra', 'views': 19039, 'rank': 274},
#  {'article': 'Dark_Waters_(2019_film)', 'views': 18996, 'rank': 275},
#  {'article': 'List_of_James_Bond_films', 'views': 18900, 'rank': 276},
#  {'article': 'Sex_Education_(TV_series)', 'views': 18896, 'rank': 277},
#  {'article': 'Scarlett_Johansson', 'views': 18866, 'rank': 278},
#  {'article': 'Terminator:_Dark_Fate', 'views': 18863, 'rank': 279},
#  {'article': 'Nick_Jonas', 'views': 18823, 'rank': 280},
#  {'article': 'Henry_Hill', 'views': 18813, 'rank': 281},
#  {'article': 'Sammy_Davis_Jr.', 'views': 18769, 'rank': 282},
#  {'article': 'China', 'views': 18733, 'rank': 283},
#  {'article': '123Movies', 'views': 18730, 'rank': 284},
#  {'article': 'Malaysian_United_Indigenous_Party', 'views': 18701, 'rank': 285},
#  {'article': 'Pope_Francis', 'views': 18698, 'rank': 286},
#  {'article': 'Bangla_TV', 'views': 18693, 'rank': 287},
#  {'article': 'The_Outsiders_(film)', 'views': 18599, 'rank': 288},
#  {'article': 'The_Magnificent_Seven_(2016_film)', 'views': 18597, 'rank': 289},
#  {'article': 'Operation_Paperclip', 'views': 18571, 'rank': 290},
#  {'article': 'The_Trials_of_Gabriel_Fernandez', 'views': 18530, 'rank': 291},
#  {'article': 'Midway_(2019_film)', 'views': 18483, 'rank': 292},
#  {'article': 'Zodiac', 'views': 18336, 'rank': 293},
#  {'article': 'World_War_I', 'views': 18315, 'rank': 294},
#  {'article': 'Ahmad_Shah_Durrani', 'views': 18307, 'rank': 295},
#  {'article': 'Grim_Sleeper', 'views': 18302, 'rank': 296},
#  {'article': 'MasterChef_India_(season_6)', 'views': 18276, 'rank': 297},
#  {'article': '2020_Democratic_Party_presidential_debates',
#   'views': 18276,
#   'rank': 297},
#  {'article': 'LeBron_James', 'views': 18272, 'rank': 299},
#  {'article': 'Leonardo_DiCaprio', 'views': 18235, 'rank': 300},
#  {'article': 'Helen_Keller', 'views': 18219, 'rank': 301},
#  {'article': 'Luka_Magnotta', 'views': 18214, 'rank': 302},
#  {'article': 'Taapsee_Pannu', 'views': 18198, 'rank': 303},
#  {'article': 'Liverpool_F.C.', 'views': 18188, 'rank': 304},
#  {'article': '2020_in_film', 'views': 18119, 'rank': 305},
#  {'article': 'Alexander_Albon', 'views': 18055, 'rank': 306},
#  {'article': 'Timothée_Chalamet', 'views': 18047, 'rank': 307},
#  {'article': 'Pangolin', 'views': 18047, 'rank': 307},
#  {'article': '2020_coronavirus_outbreak_in_France',
#   'views': 18010,
#   'rank': 309},
#  {'article': 'Anubhav_Sinha', 'views': 17951, 'rank': 310},
#  {'article': 'Pornhub', 'views': 17945, 'rank': 311},
#  {'article': 'Héctor_Luis_Palma_Salazar', 'views': 17863, 'rank': 312},
#  {'article': 'Anne_Hathaway', 'views': 17780, 'rank': 313},
#  {'article': 'Ball_lightning', 'views': 17699, 'rank': 314},
#  {'article': 'Hosni_Mubarak', 'views': 17615, 'rank': 315},
#  {'article': 'New_York_City', 'views': 17544, 'rank': 316},
#  {'article': 'Doctor_Sleep_(2019_film)', 'views': 17527, 'rank': 317},
#  {'article': 'Midsommar_(film)', 'views': 17509, 'rank': 318},
#  {'article': 'List_of_UFC_events', 'views': 17466, 'rank': 319},
#  {'article': 'Molly_Seidel', 'views': 17465, 'rank': 320},
#  {'article': 'Jimmy_Hoffa', 'views': 17439, 'rank': 321},
#  {'article': 'Baaghi_3', 'views': 17395, 'rank': 322},
#  {'article': 'Main_page', 'views': 17333, 'rank': 323},
#  {'article': 'Aaron_Hernandez', 'views': 17324, 'rank': 324},
#  {'article': '2016_United_States_presidential_election',
#   'views': 17293,
#   'rank': 325},
#  {'article': "2020_ICC_Women's_T20_World_Cup", 'views': 17276, 'rank': 326},
#  {'article': 'Little_Women_(2019_film)', 'views': 17241, 'rank': 327},
#  {'article': 'Ariana_Grande', 'views': 17224, 'rank': 328},
#  {'article': 'Bad_Boys_for_Life', 'views': 17204, 'rank': 329},
#  {'article': 'Ted_Bundy', 'views': 17197, 'rank': 330},
#  {'article': 'Henry_Cavill', 'views': 17191, 'rank': 331},
#  {'article': 'Online_dating_service', 'views': 17160, 'rank': 332},
#  {'article': 'Emmanuelle_Seigner', 'views': 17152, 'rank': 333},
#  {'article': 'Roger_Ailes', 'views': 17127, 'rank': 334},
#  {'article': 'Wikipedia:Citation_needed', 'views': 17121, 'rank': 335},
#  {'article': 'Influenza_A_virus_subtype_H1N1', 'views': 17119, 'rank': 336},
#  {'article': 'Find_My_iPhone', 'views': 17114, 'rank': 337},
#  {'article': 'Luxembourg', 'views': 17046, 'rank': 338},
#  {'article': 'Margot_Robbie', 'views': 17021, 'rank': 339},
#  {'article': 'Prince_Philip,_Duke_of_Edinburgh', 'views': 16978, 'rank': 340},
#  {'article': 'Mike_Pence', 'views': 16946, 'rank': 341},
#  {'article': 'Macaulay_Culkin', 'views': 16927, 'rank': 342},
#  {'article': 'Null', 'views': 16925, 'rank': 343},
#  {'article': 'Sadie_Hawkins_Day', 'views': 16913, 'rank': 344},
#  {'article': 'Lent', 'views': 16796, 'rank': 345},
#  {'article': 'TikTok', 'views': 16753, 'rank': 346},
#  {'article': 'Joel_Kinnaman', 'views': 16704, 'rank': 347},
#  {'article': 'Tina_Turner', 'views': 16687, 'rank': 348},
#  {'article': 'Wikipedia:Community_portal', 'views': 16677, 'rank': 349},
#  {'article': 'List_of_American_films_of_2020', 'views': 16677, 'rank': 349},
#  {'article': 'Megyn_Kelly', 'views': 16665, 'rank': 351},
#  {'article': 'Special:Watchlist', 'views': 16638, 'rank': 352},
#  {'article': 'Brad_Pitt', 'views': 16632, 'rank': 353},
#  {'article': '2020_coronavirus_outbreak_in_Iran', 'views': 16568, 'rank': 354},
#  {'article': 'Dakota_Fanning', 'views': 16524, 'rank': 355},
#  {'article': '2020_Players_Championship_(snooker)',
#   'views': 16519,
#   'rank': 356},
#  {'article': 'Michael_Jackson', 'views': 16518, 'rank': 357},
#  {'article': 'Ashton_Kutcher', 'views': 16472, 'rank': 358},
#  {'article': 'Aldis_Hodge', 'views': 16461, 'rank': 359},
#  {'article': 'Jennifer_Aniston', 'views': 16403, 'rank': 360},
#  {'article': 'Eminem', 'views': 16362, 'rank': 361},
#  {'article': 'Wiki', 'views': 16351, 'rank': 362},
#  {'article': 'Katherine_Johnson', 'views': 16333, 'rank': 363},
#  {'article': 'The_Green_Mile_(film)', 'views': 16324, 'rank': 364},
#  {'article': 'Malaysia', 'views': 16308, 'rank': 365},
#  {'article': 'Doordarshan', 'views': 16242, 'rank': 366},
#  {'article': 'Pamela_Smart', 'views': 16205, 'rank': 367},
#  {'article': 'Tyrone_S._Woods', 'views': 16199, 'rank': 368},
#  {'article': 'Bob_Geldof', 'views': 16194, 'rank': 369},
#  {'article': 'Jordan_Peele', 'views': 16194, 'rank': 369},
#  {'article': 'The_Hunt_(2020_film)', 'views': 16146, 'rank': 371},
#  {'article': 'The_Call_of_the_Wild', 'views': 16128, 'rank': 372},
#  {'article': 'Paige_(wrestler)', 'views': 16123, 'rank': 373},
#  {'article': 'North_Sentinel_Island', 'views': 16100, 'rank': 374},
#  {'article': 'Shia_LaBeouf', 'views': 16097, 'rank': 375},
#  {'article': 'Michael_Clarke_Duncan', 'views': 16086, 'rank': 376},
#  {'article': 'Steve_Jobs', 'views': 16034, 'rank': 377},
#  {'article': 'XXXTentacion', 'views': 16015, 'rank': 378},
#  {'article': 'Multiplication', 'views': 16003, 'rank': 379},
#  {'article': '2020_coronavirus_outbreak_in_Asia', 'views': 15989, 'rank': 380},
#  {'article': 'Nicki_Minaj', 'views': 15974, 'rank': 381},
#  {'article': "Baldur's_Gate_III", 'views': 15971, 'rank': 382},
#  {'article': 'Camila_Cabello', 'views': 15929, 'rank': 383},
#  {'article': 'Locke_&_Key', 'views': 15917, 'rank': 384},
#  {'article': 'Harry_Styles', 'views': 15914, 'rank': 385},
#  {'article': 'George_VI', 'views': 15910, 'rank': 386},
#  {'article': 'Elvis_Presley', 'views': 15909, 'rank': 387},
#  {'article': 'Remdesivir', 'views': 15890, 'rank': 388},
#  {'article': 'Canada', 'views': 15878, 'rank': 389},
#  {'article': 'Winston_Churchill', 'views': 15851, 'rank': 390},
#  {'article': 'Chris_Evans_(actor)', 'views': 15845, 'rank': 391},
#  {'article': 'Timeline_of_the_SARS_outbreak', 'views': 15825, 'rank': 392},
#  {'article': 'Index_of_Economic_Freedom', 'views': 15817, 'rank': 393},
#  {'article': 'Céline_Sciamma', 'views': 15805, 'rank': 394},
#  {'article': 'Wladimir_Klitschko', 'views': 15764, 'rank': 395},
#  {'article': 'Ebola_virus_disease', 'views': 15753, 'rank': 396},
#  {'article': 'Griffin_(The_Invisible_Man)', 'views': 15751, 'rank': 397},
#  {'article': 'Star_Wars:_The_Rise_of_Skywalker', 'views': 15739, 'rank': 398},
#  {'article': 'Syrian_civil_war', 'views': 15721, 'rank': 399},
#  {'article': '2003–04_Arsenal_F.C._season', 'views': 15714, 'rank': 400},
#  {'article': 'Wikipedia:Contents', 'views': 15711, 'rank': 401},
#  {'article': 'Candyman_(character)', 'views': 15705, 'rank': 402},
#  {'article': 'Patrick_Swayze', 'views': 15655, 'rank': 403},
#  {'article': 'Outlander_(TV_series)', 'views': 15646, 'rank': 404},
#  {'article': 'File:Flag_of_Brazil.svg', 'views': 15611, 'rank': 405},
#  {'article': 'Corona_(beer)', 'views': 15595, 'rank': 406},
#  {'article': 'UFC_248', 'views': 15581, 'rank': 407},
#  {'article': 'Troy_Deeney', 'views': 15574, 'rank': 408},
#  {'article': 'Business_interruption_insurance', 'views': 15563, 'rank': 409},
#  {'article': 'Virus', 'views': 15556, 'rank': 410},
#  {'article': 'Chernobyl_disaster', 'views': 15518, 'rank': 411},
#  {'article': 'Harrison_Ford', 'views': 15484, 'rank': 412},
#  {'article': 'Daniel_Craig', 'views': 15463, 'rank': 413},
#  {'article': 'Jim_Carrey', 'views': 15436, 'rank': 414},
#  {'article': 'Flag_of_Scotland', 'views': 15418, 'rank': 415},
#  {'article': "Shaquille_O'Neal", 'views': 15409, 'rank': 416},
#  {'article': 'Pop_Smoke', 'views': 15370, 'rank': 417},
#  {'article': 'Gwen_Stefani', 'views': 15362, 'rank': 418},
#  {'article': 'Ivanka_Trump', 'views': 15354, 'rank': 419},
#  {'article': 'Wyatt_Oleff', 'views': 15328, 'rank': 420},
#  {'article': 'Bestgore.com', 'views': 15320, 'rank': 421},
#  {'article': 'Stephen_Baldwin', 'views': 15278, 'rank': 422},
#  {'article': 'Ernesto_Fonseca_Carrillo', 'views': 15278, 'rank': 422},
#  {'article': 'Tony_Todd', 'views': 15251, 'rank': 424},
#  {'article': 'Us_(2019_film)', 'views': 15228, 'rank': 425},
#  {'article': 'Natalie_Wood', 'views': 15223, 'rank': 426},
#  {'article': 'Gabriel_Fernández', 'views': 15223, 'rank': 426},
#  {'article': 'Jason_Momoa', 'views': 15204, 'rank': 428},
#  {'article': 'Logan_Lerman', 'views': 15172, 'rank': 429},
#  {'article': 'Gwyneth_Paltrow', 'views': 15172, 'rank': 429},
#  {'article': 'Waco_siege', 'views': 15130, 'rank': 431},
#  {'article': 'Manson_Family', 'views': 15122, 'rank': 432},
#  {'article': 'Harriet_Tubman', 'views': 15117, 'rank': 433},
#  {'article': 'Patrick_Stewart', 'views': 15114, 'rank': 434},
#  {'article': 'Good_Newwz', 'views': 15097, 'rank': 435},
#  {'article': 'Tony_Romo', 'views': 15082, 'rank': 436},
#  {'article': 'Superman:_Red_Son', 'views': 15006, 'rank': 437},
#  {'article': 'Dolittle_(film)', 'views': 14984, 'rank': 438},
#  {'article': 'Jennifer_Lopez', 'views': 14954, 'rank': 439},
#  {'article': 'BBC', 'views': 14927, 'rank': 440},
#  {'article': 'Afghanistan', 'views': 14908, 'rank': 441},
#  {'article': 'Goodfellas', 'views': 14899, 'rank': 442},
#  {'article': '2019–20_Wuhan_coronavirus_outbreak_by_country_and_territory',
#   'views': 14864,
#   'rank': 443},
#  {'article': "RuPaul's_Drag_Race", 'views': 14848, 'rank': 444},
#  {'article': 'Tom_Selleck', 'views': 14781, 'rank': 445},
#  {'article': 'Fear_Factor:_Khatron_Ke_Khiladi', 'views': 14778, 'rank': 446},
#  {'article': 'Johnny_Depp', 'views': 14765, 'rank': 447},
#  {'article': 'David_Beckham', 'views': 14743, 'rank': 448},
#  {'article': 'The_Invisible_Man_(1933_film)', 'views': 14732, 'rank': 449},
#  {'article': 'File:John_Cena_July_2018.jpg', 'views': 14715, 'rank': 450},
#  {'article': 'Ben_Affleck', 'views': 14692, 'rank': 451},
#  {'article': 'Emma_(2020_film)', 'views': 14688, 'rank': 452},
#  {'article': 'MasterChef_India', 'views': 14674, 'rank': 453},
#  {'article': 'Arnold_Schwarzenegger', 'views': 14666, 'rank': 454},
#  {'article': 'Roddy_Ricch', 'views': 14623, 'rank': 455},
#  {'article': 'Diamond_Princess_(ship)', 'views': 14617, 'rank': 456},
#  {'article': 'Taj_Mahal', 'views': 14612, 'rank': 457},
#  {'article': 'Louis_C.K.', 'views': 14547, 'rank': 458},
#  {'article': 'Jimmy_Fallon', 'views': 14511, 'rank': 459},
#  {'article': 'Mulan_(2020_film)', 'views': 14478, 'rank': 460},
#  {'article': 'Avengers:_Endgame', 'views': 14472, 'rank': 461},
#  {'article': 'Alex_Azar', 'views': 14465, 'rank': 462},
#  {'article': 'John_F._Kennedy', 'views': 14455, 'rank': 463},
#  {'article': 'Knives_Out_(film)', 'views': 14449, 'rank': 464},
#  {'article': 'Storm_Reid', 'views': 14448, 'rank': 465},
#  {'article': 'Queen_Victoria', 'views': 14436, 'rank': 466},
#  {'article': 'Iceland_in_the_Eurovision_Song_Contest_2020',
#   'views': 14412,
#   'rank': 467},
#  {'article': 'Dionne_Warwick', 'views': 14407, 'rank': 468},
#  {'article': 'List_of_S&P_500_companies', 'views': 14401, 'rank': 469},
#  {'article': 'Jean_Seberg', 'views': 14399, 'rank': 470},
#  {'article': 'John_Krasinski', 'views': 14388, 'rank': 471},
#  {'article': 'Edward_VIII', 'views': 14360, 'rank': 472},
#  {'article': 'Timeline_of_the_2019–20_coronavirus_outbreak',
#   'views': 14322,
#   'rank': 473},
#  {'article': 'Kiki_Camarena', 'views': 14321, 'rank': 474},
#  {'article': 'Charles,_Prince_of_Wales', 'views': 14316, 'rank': 475},
#  {'article': 'Kristen_Bell', 'views': 14293, 'rank': 476},
#  {'article': 'Joseph_Benavidez', 'views': 14267, 'rank': 477},
#  {'article': 'Strawberry', 'views': 14257, 'rank': 478},
#  {'article': 'Singapore', 'views': 14251, 'rank': 479},
#  {'article': 'Angelina_Jolie', 'views': 14239, 'rank': 480},
#  {'article': 'Crisis_on_Infinite_Earths_(Arrowverse)',
#   'views': 14200,
#   'rank': 481},
#  {'article': 'Template:Pornography', 'views': 14190, 'rank': 482},
#  {'article': 'Queen_(band)', 'views': 14168, 'rank': 483},
#  {'article': 'Mahatma_Gandhi', 'views': 14162, 'rank': 484},
#  {'article': 'Phil_Spector', 'views': 14154, 'rank': 485},
#  {'article': 'Gretchen_Carlson', 'views': 14134, 'rank': 486},
#  {'article': 'Clint_Eastwood', 'views': 14113, 'rank': 487},
#  {'article': '2020_Republican_Party_presidential_primaries',
#   'views': 14107,
#   'rank': 488},
#  {'article': 'Manchester_United_F.C.', 'views': 14087, 'rank': 489},
#  {'article': "Bridegroom's_Oak", 'views': 14063, 'rank': 490},
#  {'article': 'Tom_Brady', 'views': 14055, 'rank': 491},
#  {'article': 'Splendor_in_the_Grass', 'views': 14045, 'rank': 492},
#  {'article': 'Mia_Khalifa', 'views': 14036, 'rank': 493},
#  {'article': 'Richard_Rishi', 'views': 14007, 'rank': 494},
#  {'article': 'Estonia_in_the_Eurovision_Song_Contest_2020',
#   'views': 13978,
#   'rank': 495},
#  {'article': 'Ricky_Martin', 'views': 13976, 'rank': 496},
#  {'article': 'Ja_Rule', 'views': 13973, 'rank': 497},
#  {'article': 'Malcolm_X', 'views': 13948, 'rank': 498},
#  {'article': 'Gregorian_calendar', 'views': 13947, 'rank': 499},
#  {'article': 'Russia', 'views': 13932, 'rank': 500},
#  {'article': 'John_Mulaney', 'views': 13905, 'rank': 501},
#  {'article': 'Malang_(film)', 'views': 13895, 'rank': 502},
#  {'article': 'Rafael_Aguilar_Guajardo', 'views': 13881, 'rank': 503},
#  {'article': 'Jarrod_Bowen', 'views': 13871, 'rank': 504},
#  {'article': 'A_Quiet_Place_Part_II', 'views': 13866, 'rank': 505},
#  {'article': 'Bong_Joon-ho', 'views': 13865, 'rank': 506},
#  {'article': 'Heath_Ledger', 'views': 13847, 'rank': 507},
#  {'article': 'The_Lighthouse_(2019_film)', 'views': 13814, 'rank': 508},
#  {'article': 'Alexander_the_Great', 'views': 13800, 'rank': 509},
#  {'article': 'Sylvester_Stallone', 'views': 13789, 'rank': 510},
#  {'article': 'Sinaloa_Cartel', 'views': 13745, 'rank': 511},
#  {'article': 'Bruce_Lee', 'views': 13721, 'rank': 512},
#  {'article': 'Narendra_Modi', 'views': 13713, 'rank': 513},
#  {'article': 'Millennials', 'views': 13695, 'rank': 514},
#  {'article': 'Malta', 'views': 13688, 'rank': 515},
#  {'article': 'Love_Aaj_Kal_(2020_film)', 'views': 13685, 'rank': 516},
#  {'article': 'Netflix', 'views': 13678, 'rank': 517},
#  {'article': 'List_of_highest-grossing_films', 'views': 13673, 'rank': 518},
#  {'article': 'Christian_Bale', 'views': 13671, 'rank': 519},
#  {'article': 'Peaky_Blinders_(TV_series)', 'views': 13671, 'rank': 519},
#  {'article': 'Robin_Williams', 'views': 13663, 'rank': 521},
#  {'article': 'Australia', 'views': 13634, 'rank': 522},
#  {'article': 'Dow_Jones_Industrial_Average', 'views': 13602, 'rank': 523},
#  {'article': 'File:Msg_plus.png', 'views': 13594, 'rank': 524},
#  {'article': 'List_of_most-viewed_online_videos_in_the_first_24_hours',
#   'views': 13565,
#   'rank': 525},
#  {'article': 'Philip_II_of_Macedon', 'views': 13554, 'rank': 526},
#  {'article': 'Amy_Klobuchar', 'views': 13495, 'rank': 527},
#  {'article': 'The_Weeknd', 'views': 13485, 'rank': 528},
#  {'article': 'Lionel_Messi', 'views': 13480, 'rank': 529},
#  {'article': 'Residente', 'views': 13477, 'rank': 530},
#  {'article': "Schitt's_Creek", 'views': 13411, 'rank': 531},
#  {'article': 'Better_Call_Saul_(season_5)', 'views': 13398, 'rank': 532},
#  {'article': 'Chris_Pratt', 'views': 13396, 'rank': 533},
#  {'article': 'First_Battle_of_Panipat', 'views': 13376, 'rank': 534},
#  {'article': 'Germany', 'views': 13375, 'rank': 535},
#  {'article': 'Tulsi_Gabbard', 'views': 13373, 'rank': 536},
#  {'article': 'Tom_Hanks', 'views': 13340, 'rank': 537},
#  {'article': 'Radhika_Madan', 'views': 13334, 'rank': 538},
#  {'article': 'Caroline_Flack', 'views': 13305, 'rank': 539},
#  {'article': 'Battle_of_Midway', 'views': 13301, 'rank': 540},
#  {'article': 'Albert_Einstein', 'views': 13294, 'rank': 541},
#  {'article': 'Tupac_Shakur', 'views': 13287, 'rank': 542},
#  {'article': 'Abraham_Lincoln', 'views': 13281, 'rank': 543},
#  {'article': 'Kylie_Jenner', 'views': 13273, 'rank': 544},
#  {'article': 'Severe_acute_respiratory_syndrome-related_coronavirus',
#   'views': 13272,
#   'rank': 545},
#  {'article': 'File:Bono_as_The_Fly_Cleveland_1992.jpg',
#   'views': 13264,
#   'rank': 546},
#  {'article': "Grey's_Anatomy", 'views': 13239, 'rank': 547},
#  {'article': 'River_Phoenix', 'views': 13205, 'rank': 548},
#  {'article': 'Bray_Wyatt', 'views': 13176, 'rank': 549},
#  {'article': 'Tanhaji', 'views': 13168, 'rank': 550},
#  {'article': 'Marvel_Cinematic_Universe', 'views': 13165, 'rank': 551},
#  {'article': 'Grimes_(musician)', 'views': 13160, 'rank': 552},
#  {'article': 'U.S._state', 'views': 13152, 'rank': 553},
#  {'article': 'Sarileru_Neekevvaru', 'views': 13150, 'rank': 554},
#  {'article': 'The_Mandalorian', 'views': 13141, 'rank': 555},
#  {'article': 'Gene_Haas', 'views': 13125, 'rank': 556},
#  {'article': 'Marilyn_Monroe', 'views': 13116, 'rank': 557},
#  {'article': 'Shafali_Verma', 'views': 13113, 'rank': 558},
#  {'article': 'Greg_Wise', 'views': 13112, 'rank': 559},
#  {'article': 'Novak_Djokovic', 'views': 13104, 'rank': 560},
#  {'article': 'Pirates_of_the_Caribbean_(film_series)',
#   'views': 13094,
#   'rank': 561},
#  {'article': 'Swine_influenza', 'views': 13081, 'rank': 562},
#  {'article': 'Pneumonia', 'views': 13079, 'rank': 563},
#  {'article': 'Michael_Dorman', 'views': 13072, 'rank': 564},
#  {'article': 'Will_Smith', 'views': 13047, 'rank': 565},
#  {'article': 'A_Beautiful_Day_in_the_Neighborhood',
#   'views': 13042,
#   'rank': 566},
#  {'article': 'Kareem_Abdul-Jabbar', 'views': 13039, 'rank': 567},
#  {'article': 'HTTP_404', 'views': 13021, 'rank': 568},
#  {'article': '.xxx', 'views': 13020, 'rank': 569},
#  {'article': '2020_Slovak_parliamentary_election',
#   'views': 12968,
#   'rank': 570},
#  {'article': 'Tones_and_I', 'views': 12960, 'rank': 571},
#  {'article': 'Greek_alphabet', 'views': 12935, 'rank': 572},
#  {'article': 'Nick_Lachey', 'views': 12920, 'rank': 573},
#  {'article': 'Turkey', 'views': 12881, 'rank': 574},
#  {'article': 'Al_Jazeera', 'views': 12876, 'rank': 575},
#  {'article': 'Tyra_Banks', 'views': 12871, 'rank': 576},
#  {'article': 'Bill_Gates', 'views': 12838, 'rank': 577},
#  {'article': 'Quentin_Tarantino', 'views': 12824, 'rank': 578},
#  {'article': 'Sam_Elliott', 'views': 12805, 'rank': 579},
#  {'article': 'My_Hero_Academia', 'views': 12784, 'rank': 580},
#  {'article': 'Shincheonji_Church_of_Jesus_the_Temple_of_the_Tabernacle_of_the_Testimony',
#   'views': 12783,
#   'rank': 581},
#  {'article': 'The_Undertaker', 'views': 12779, 'rank': 582},
#  {'article': 'Bobby_Ryan', 'views': 12754, 'rank': 583},
#  {'article': 'Ozzy_Osbourne', 'views': 12743, 'rank': 584},
#  {'article': 'Joseph_Stalin', 'views': 12739, 'rank': 585},
#  {'article': 'Dyson_sphere', 'views': 12726, 'rank': 586},
#  {'article': 'Alex_Caruso', 'views': 12705, 'rank': 587},
#  {'article': 'Pakistan', 'views': 12702, 'rank': 588},
#  {'article': 'James_Burke_(gangster)', 'views': 12696, 'rank': 589},
#  {'article': 'Brooklyn_Nine-Nine', 'views': 12682, 'rank': 590},
#  {'article': 'Japan', 'views': 12647, 'rank': 591},
#  {'article': 'Queen_Sono', 'views': 12646, 'rank': 592},
#  {'article': 'Jeffrey_Dahmer', 'views': 12616, 'rank': 593},
#  {'article': 'Dreyfus_affair', 'views': 12608, 'rank': 594},
#  {'article': 'Robert_De_Niro', 'views': 12597, 'rank': 595},
#  {'article': 'RT_(TV_network)', 'views': 12583, 'rank': 596},
#  {'article': 'Morarji_Desai', 'views': 12557, 'rank': 597},
#  {'article': 'Wernher_von_Braun', 'views': 12543, 'rank': 598},
#  {'article': 'Sasha_Banks', 'views': 12538, 'rank': 599},
#  {'article': 'Allu_Arjun', 'views': 12522, 'rank': 600},
#  {'article': 'September_11_attacks', 'views': 12510, 'rank': 601},
#  {'article': 'Premier_League_records_and_statistics',
#   'views': 12498,
#   'rank': 602},
#  {'article': 'Joshua_Zirkzee', 'views': 12494, 'rank': 603},
#  {'article': 'Shakira', 'views': 12486, 'rank': 604},
#  {'article': 'Ronald_Reagan', 'views': 12478, 'rank': 605},
#  {'article': 'Ryan_Reynolds', 'views': 12477, 'rank': 606},
#  {'article': 'Emily_Blunt', 'views': 12465, 'rank': 607},
#  {'article': 'Marjaavaan', 'views': 12465, 'rank': 607},
#  {'article': 'World_Health_Organization', 'views': 12456, 'rank': 609},
#  {'article': 'Smriti_Mandhana', 'views': 12455, 'rank': 610},
#  {'article': 'Monster_Hunter_(film)', 'views': 12431, 'rank': 611},
#  {'article': 'Michael_Crichton', 'views': 12414, 'rank': 612},
#  {'article': 'Zooey_Deschanel', 'views': 12402, 'rank': 613},
#  {'article': 'George_Washington', 'views': 12393, 'rank': 614},
#  {'article': 'List_of_Star_Wars_films', 'views': 12355, 'rank': 615},
#  {'article': 'Garth_Brooks', 'views': 12338, 'rank': 616},
#  {'article': 'Lennox_Lewis', 'views': 12305, 'rank': 617},
#  {'article': 'William_Shakespeare', 'views': 12282, 'rank': 618},
#  {'article': 'Global_warming', 'views': 12235, 'rank': 619},
#  {'article': 'RMS_Titanic', 'views': 12224, 'rank': 620},
#  {'article': 'Tom_Hardy', 'views': 12221, 'rank': 621},
#  {'article': 'List_of_states_and_territories_of_the_United_States',
#   'views': 12182,
#   'rank': 622},
#  {'article': 'Franklin_D._Roosevelt', 'views': 12181, 'rank': 623},
#  {'article': 'Ash_Wednesday', 'views': 12172, 'rank': 624},
#  {'article': 'Daniel_Ricciardo', 'views': 12171, 'rank': 625},
#  {'article': 'Bradley_Cooper', 'views': 12162, 'rank': 626},
#  {'article': 'Ric_Ocasek', 'views': 12156, 'rank': 627},
#  {'article': 'Prince_(musician)', 'views': 12144, 'rank': 628},
#  {'article': 'Bhad_Bhabie', 'views': 12135, 'rank': 629},
#  {'article': 'Snowpiercer', 'views': 12119, 'rank': 630},
#  {'article': 'Zoë_Kravitz', 'views': 12106, 'rank': 631},
#  {'article': 'Mary,_Queen_of_Scots', 'views': 12103, 'rank': 632},
#  {'article': 'The_Sinner_(TV_series)', 'views': 12095, 'rank': 633},
#  {'article': 'Vietnam_War', 'views': 12093, 'rank': 634},
#  {'article': 'Anthony_Mackie', 'views': 12084, 'rank': 635},
#  {'article': 'List_of_countries_by_GDP_(nominal)',
#   'views': 12069,
#   'rank': 636},
#  {'article': 'Nico_Hülkenberg', 'views': 12056, 'rank': 637},
#  {'article': 'Tejasswi_Prakash', 'views': 12053, 'rank': 638},
#  {'article': '24_Hours_of_Le_Mans', 'views': 12051, 'rank': 639},
#  {'article': 'The_Walking_Dead_(TV_series)', 'views': 12042, 'rank': 640},
#  {'article': 'The_Masked_Singer_(American_season_3)',
#   'views': 12036,
#   'rank': 641},
#  {'article': 'Tamil_language', 'views': 12035, 'rank': 642},
#  {'article': 'Kristen_Stewart', 'views': 12021, 'rank': 643},
#  {'article': 'Seven_deadly_sins', 'views': 12001, 'rank': 644},
#  {'article': 'The_Beatles', 'views': 11996, 'rank': 645},
#  {'article': 'WhatsApp', 'views': 11972, 'rank': 646},
#  {'article': 'Yahya_Abdul-Mateen_II', 'views': 11964, 'rank': 647},
#  {'article': 'Sam_Rockwell', 'views': 11962, 'rank': 648},
#  {'article': 'U2', 'views': 11944, 'rank': 649},
#  {'article': 'Amazon_(company)', 'views': 11940, 'rank': 650},
#  {'article': 'Bobby_Shmurda', 'views': 11936, 'rank': 651},
#  {'article': 'John_Wick:_Chapter_3_–_Parabellum', 'views': 11912, 'rank': 652},
#  {'article': 'Vin_Diesel', 'views': 11878, 'rank': 653},
#  {'article': 'Comparison_of_online_dating_services',
#   'views': 11866,
#   'rank': 654},
#  {'article': 'Niki_Lauda', 'views': 11856, 'rank': 655},
#  {'article': 'Drew_Peterson', 'views': 11846, 'rank': 656},
#  {'article': "Finneas_O'Connell", 'views': 11839, 'rank': 657},
#  {'article': 'Awkwafina', 'views': 11839, 'rank': 657},
#  {'article': 'Harriet_(film)', 'views': 11810, 'rank': 659},
#  {'article': 'June_Carter_Cash', 'views': 11805, 'rank': 660},
#  {'article': 'Kim_Kardashian', 'views': 11784, 'rank': 661},
#  {'article': 'Harrow_(TV_series)', 'views': 11777, 'rank': 662},
#  {'article': 'Generation_Z', 'views': 11771, 'rank': 663},
#  {'article': 'Darth_Vader', 'views': 11764, 'rank': 664},
#  {'article': 'Nigel_Pearson', 'views': 11764, 'rank': 664},
#  {'article': 'Jon_Bon_Jovi', 'views': 11757, 'rank': 666},
#  {'article': 'Francesca_Annis', 'views': 11752, 'rank': 667},
#  {'article': 'The_dress', 'views': 11752, 'rank': 667},
#  {'article': 'Website', 'views': 11715, 'rank': 669},
#  {'article': 'Galen_Rupp', 'views': 11705, 'rank': 670},
#  {'article': 'Warren_Beatty', 'views': 11704, 'rank': 671},
#  {'article': 'Kapil_Mishra', 'views': 11689, 'rank': 672},
#  {'article': 'McMillions', 'views': 11685, 'rank': 673},
#  {'article': 'Juice_Wrld', 'views': 11683, 'rank': 674},
#  {'article': 'Vanessa_Lachey', 'views': 11654, 'rank': 675},
#  {'article': 'Takeshi_Kovacs', 'views': 11614, 'rank': 676},
#  {'article': 'France', 'views': 11607, 'rank': 677},
#  {'article': 'Mexico', 'views': 11601, 'rank': 678},
#  {'article': 'List_of_WWE_pay-per-view_and_WWE_Network_events',
#   'views': 11586,
#   'rank': 679},
#  {'article': 'Charlie_Hunnam', 'views': 11585, 'rank': 680},
#  {'article': 'Anna_Kendrick', 'views': 11558, 'rank': 681},
#  {'article': 'Pope_Benedict_XVI', 'views': 11543, 'rank': 682},
#  {'article': "Grey's_Anatomy_(season_16)", 'views': 11540, 'rank': 683},
#  {'article': 'Anya_Taylor-Joy', 'views': 11535, 'rank': 684},
#  {'article': 'Dean_Koontz', 'views': 11526, 'rank': 685},
#  {'article': 'Charlize_Theron', 'views': 11526, 'rank': 685},
#  {'article': 'Yoel_Romero', 'views': 11525, 'rank': 687},
#  {'article': 'Major_League_Soccer', 'views': 11514, 'rank': 688},
#  {'article': 'Bex_Taylor-Klaus', 'views': 11502, 'rank': 689},
#  {'article': 'Soviet_Union', 'views': 11499, 'rank': 690},
#  {'article': 'Index_of_law_articles', 'views': 11488, 'rank': 691},
#  {'article': 'XXX:_State_of_the_Union', 'views': 11476, 'rank': 692},
#  {'article': 'States_and_union_territories_of_India',
#   'views': 11438,
#   'rank': 693},
#  {'article': 'Pet_Sematary_(2019_film)', 'views': 11422, 'rank': 694},
#  {'article': 'Melodifestivalen_2020', 'views': 11407, 'rank': 695},
#  {'article': 'Alec_Baldwin', 'views': 11384, 'rank': 696},
#  {'article': 'Stephen_Curry', 'views': 11377, 'rank': 697},
#  {'article': 'Pooja_Hegde', 'views': 11366, 'rank': 698},
#  {'article': 'Brahms:_The_Boy_II', 'views': 11353, 'rank': 699},
#  {'article': 'Rebel_Without_a_Cause', 'views': 11349, 'rank': 700},
#  {'article': 'Sexual_intercourse', 'views': 11339, 'rank': 701},
#  {'article': 'Stephen_Mulhern', 'views': 11339, 'rank': 701},
#  {'article': '2020_coronavirus_outbreak_in_Canada',
#   'views': 11335,
#   'rank': 703},
#  {'article': 'Template:Syrian_Civil_War_detailed_map',
#   'views': 11327,
#   'rank': 704},
#  {'article': 'Breakthrough_(2019_film)', 'views': 11325, 'rank': 705},
#  {'article': 'California', 'views': 11315, 'rank': 706},
#  {'article': 'Instagram', 'views': 11309, 'rank': 707},
#  {'article': 'O._J._Simpson', 'views': 11302, 'rank': 708},
#  {'article': 'Rangers_F.C.', 'views': 11297, 'rank': 709},
#  {'article': 'Star_Wars', 'views': 11277, 'rank': 710},
#  {'article': 'Will_Arnett', 'views': 11266, 'rank': 711},
#  {'article': 'Rashmika_Mandanna', 'views': 11261, 'rank': 712},
#  {'article': 'File:TVASports.svg', 'views': 11256, 'rank': 713},
#  {'article': 'Liza_Minnelli', 'views': 11245, 'rank': 714},
#  {'article': 'Henry_VIII_of_England', 'views': 11241, 'rank': 715},
#  {'article': 'UEFA_Euro_2020', 'views': 11237, 'rank': 716},
#  {'article': 'Erling_Braut_Håland', 'views': 11232, 'rank': 717},
#  {'article': 'Horse_Girl', 'views': 11225, 'rank': 718},
#  {'article': 'The_Holocaust', 'views': 11224, 'rank': 719},
#  {'article': 'Whitney_Houston', 'views': 11216, 'rank': 720},
#  {'article': 'F5_Networks', 'views': 11202, 'rank': 721},
#  {'article': 'Martin_Luther_King_Jr.', 'views': 11159, 'rank': 722},
#  {'article': 'Solar_System', 'views': 11152, 'rank': 723},
#  {'article': 'Suicide_methods', 'views': 11147, 'rank': 724},
#  {'article': 'Harvey_Weinstein_sexual_abuse_cases',
#   'views': 11144,
#   'rank': 725},
#  {'article': 'Academy_Award_for_Best_Picture', 'views': 11107, 'rank': 726},
#  {'article': 'Nicole_Scherzinger', 'views': 11106, 'rank': 727},
#  {'article': 'Fasting_and_abstinence_in_the_Catholic_Church',
#   'views': 11106,
#   'rank': 727},
#  {'article': 'Mandy_Moore', 'views': 11104, 'rank': 729},
#  {'article': 'Amber_Heard', 'views': 11104, 'rank': 729},
#  {'article': 'Cher', 'views': 11094, 'rank': 731},
#  {'article': 'Hilary_Duff', 'views': 11093, 'rank': 732},
#  {'article': 'Alexander_Hamilton', 'views': 11090, 'rank': 733},
#  {'article': 'John_Lennon', 'views': 11087, 'rank': 734},
#  {'article': 'Wikipedia:General_disclaimer', 'views': 11084, 'rank': 735},
#  {'article': 'Zodiac_Killer', 'views': 11080, 'rank': 736},
#  {'article': 'Leap_Year_(2010_film)', 'views': 11077, 'rank': 737},
#  {'article': 'Timeline_of_the_2019–20_coronavirus_outbreak_in_February_2020',
#   'views': 11073,
#   'rank': 738},
#  {'article': "To_All_the_Boys_I've_Loved_Before_(film)",
#   'views': 11072,
#   'rank': 739},
#  {'article': 'Beyoncé', 'views': 11065, 'rank': 740},
#  {'article': 'Riverdale_(2017_TV_series)', 'views': 11063, 'rank': 741},
#  {'article': 'Steve_McQueen', 'views': 11053, 'rank': 742},
#  {'article': 'Elizabeth_I_of_England', 'views': 11053, 'rank': 742},
#  {'article': 'Philippines', 'views': 11053, 'rank': 742},
#  {'article': 'Kirk_Douglas', 'views': 11024, 'rank': 745},
# ...
#  {'article': 'Big_Brother_(2020_film)', 'views': 10989, 'rank': 753},
#  {'article': 'Ade_Edmondson', 'views': 10982, 'rank': 754},
#  {'article': 'South_Africa', 'views': 10981, 'rank': 755},
#  {'article': 'The_Gentlemen_(2019_film)', 'views': 10977, 'rank': 756},
#  {'article': 'Bernie_Taupin', 'views': 10976, 'rank': 757},
#  {'article': 'Friends', 'views': 10967, 'rank': 758},
#  {'article': 'Shameless_(U.S._TV_series)', 'views': 10954, 'rank': 759},
#  {'article': 'SAP_SE', 'views': 10950, 'rank': 760},
#  {'article': 'Diana,_Princess_of_Wales', 'views': 10949, 'rank': 761},
#  {'article': '92nd_Academy_Awards', 'views': 10937, 'rank': 762},
#  {'article': 'You_(TV_series)', 'views': 10924, 'rank': 763},
#  {'article': 'Battle_of_Panipat', 'views': 10907, 'rank': 764},
#  {'article': 'Salma_Hayek', 'views': 10892, 'rank': 765},
#  {'article': 'Fear_Factor:_Khatron_Ke_Khiladi_10',
#   'views': 10878,
#   'rank': 766},
#  {'article': 'Leigh_Whannell', 'views': 10870, 'rank': 767},
#  {'article': 'Sooryavanshi', 'views': 10847, 'rank': 768},
#  {'article': 'Italy', 'views': 10844, 'rank': 769},
#  {'article': 'Dakota_Johnson', 'views': 10838, 'rank': 770},
#  {'article': 'Marin_County_Civic_Center_attacks', 'views': 10822, 'rank': 771},
#  {'article': 'Fingerprint_(computing)', 'views': 10821, 'rank': 772},
#  {'article': 'Akira_(1988_film)', 'views': 10819, 'rank': 773},
#  {'article': 'Jennifer_Garner', 'views': 10801, 'rank': 774},
#  {'article': 'Charlie_Sheen', 'views': 10800, 'rank': 775},
#  {'article': 'Wikipedia:Protection_policy', 'views': 10789, 'rank': 776},
#  {'article': 'Tiger_Shroff', 'views': 10784, 'rank': 777},
#  {'article': 'Meg_Johnson_(poet)', 'views': 10774, 'rank': 778},
#  {'article': 'Ottoman_Empire', 'views': 10770, 'rank': 779},
#  {'article': 'Robert_Downey_Jr.', 'views': 10767, 'rank': 780},
#  {'article': 'Ayushmann_Khurrana', 'views': 10762, 'rank': 781},
#  {'article': 'Academy_Awards', 'views': 10761, 'rank': 782},
#  {'article': 'I_Still_Believe_(film)', 'views': 10760, 'rank': 783},
#  {'article': 'Tate–LaBianca_murders', 'views': 10754, 'rank': 784},
#  {'article': 'Lisa_Bonet', 'views': 10753, 'rank': 785},
#  {'article': 'Selena_Gomez', 'views': 10745, 'rank': 786},
#  {'article': 'Jackie_Chan', 'views': 10740, 'rank': 787},
#  {'article': 'Israel', 'views': 10729, 'rank': 788},
#  {'article': 'Lucifer_(TV_series)', 'views': 10729, 'rank': 788},
#  {'article': 'Harriet_Dyer', 'views': 10714, 'rank': 790},
#  {'article': 'List_of_Star_Wars:_The_Clone_Wars_episodes',
#   'views': 10711,
#   'rank': 791},
#  {'article': 'Open_primaries_in_the_United_States',
#   'views': 10707,
#   'rank': 792},
#  {'article': 'William_Shatner', 'views': 10694, 'rank': 793},
#  {'article': 'WrestleMania_35', 'views': 10692, 'rank': 794},
#  {'article': 'Amy_Adams', 'views': 10671, 'rank': 795},
#  {'article': 'ADX_Florence', 'views': 10653, 'rank': 796},
#  {'article': 'Zendaya', 'views': 10645, 'rank': 797},
#  {'article': 'Indonesia', 'views': 10639, 'rank': 798},
#  {'article': 'Ford_GT40', 'views': 10635, 'rank': 799},
#  {'article': 'Lee_Iacocca', 'views': 10635, 'rank': 799},
#  {'article': 'Roman_Reigns', 'views': 10633, 'rank': 801},
#  {'article': 'Broken_Angels_(novel)', 'views': 10626, 'rank': 802},
#  {'article': 'List_of_most-followed_TikTok_accounts',
#   'views': 10623,
#   'rank': 803},
#  {'article': 'List_of_Walt_Disney_Pictures_films',
#   'views': 10617,
#   'rank': 804},
#  {'article': 'Jeremy_Camp', 'views': 10617, 'rank': 804},
#  {'article': 'Ritesh_Agarwal', 'views': 10613, 'rank': 806},
#  {'article': 'Spies_in_Disguise', 'views': 10613, 'rank': 806},
#  {'article': 'Lewis_Capaldi', 'views': 10608, 'rank': 808},
#  {'article': 'Blake_Lively', 'views': 10605, 'rank': 809},
#  {'article': 'Sal_Mineo', 'views': 10599, 'rank': 810},
#  {'article': 'Gaslighting', 'views': 10598, 'rank': 811},
#  {'article': 'American_Horror_Story', 'views': 10585, 'rank': 812},
#  {'article': 'Color_Out_of_Space_(film)', 'views': 10581, 'rank': 813},
#  {'article': 'Pakatan_Harapan', 'views': 10580, 'rank': 814},
#  {'article': 'Bridget_Moynahan', 'views': 10562, 'rank': 815},
#  {'article': '2020_coronavirus_outbreak_in_the_Philippines',
#   'views': 10560,
#   'rank': 816},
#  {'article': 'South_Korea', 'views': 10549, 'rank': 817},
#  {'article': 'Earth', 'views': 10545, 'rank': 818},
#  {'article': 'Madonna_(entertainer)', 'views': 10525, 'rank': 819},
#  {'article': 'Frank_Sheeran', 'views': 10523, 'rank': 820},
#  {'article': 'South_Carolina', 'views': 10515, 'rank': 821},
#  {'article': 'Julia_Roberts', 'views': 10504, 'rank': 822},
#  {'article': 'RuPaul', 'views': 10501, 'rank': 823},
#  {'article': 'Help:Maintenance_template_removal', 'views': 10485, 'rank': 824},
#  {'article': 'Iran', 'views': 10483, 'rank': 825},
#  {'article': 'Chris_Hemsworth', 'views': 10483, 'rank': 825},
#  {'article': 'Jake_Gyllenhaal', 'views': 10479, 'rank': 827},
#  {'article': 'Emma_Watson', 'views': 10477, 'rank': 828},
#  {'article': 'Napoleon', 'views': 10467, 'rank': 829},
#  {'article': 'Rajya_Sabha_TV', 'views': 10463, 'rank': 830},
#  {'article': 'Arsenal_F.C.', 'views': 10463, 'rank': 830},
#  {'article': 'Matthew_McConaughey', 'views': 10450, 'rank': 832},
#  {'article': 'La_Bougie_du_Sapeur', 'views': 10425, 'rank': 833},
#  {'article': 'Sexy', 'views': 10421, 'rank': 834},
#  {'article': 'Reese_Witherspoon', 'views': 10419, 'rank': 835},
#  {'article': 'David_Bowie', 'views': 10401, 'rank': 836},
#  {'article': 'The_Walking_Dead_(season_10)', 'views': 10390, 'rank': 837},
#  {'article': 'Leylah_Annie_Fernandez', 'views': 10384, 'rank': 838},
#  {'article': 'Marcos_Alonso_(footballer,_born_1990)',
#   'views': 10379,
#   'rank': 839},
#  {'article': 'List_of_most-followed_Instagram_accounts',
#   'views': 10349,
#   'rank': 840},
#  {'article': 'Fuck_for_the_heir_Puppy_Bear!', 'views': 10348, 'rank': 841},
#  {'article': 'Titanic_(1997_film)', 'views': 10334, 'rank': 842},
#  {'article': 'New_Zealand', 'views': 10332, 'rank': 843},
#  {'article': '2020_Pakistan_Super_League', 'views': 10330, 'rank': 844},
#  {'article': 'Breaking_Bad', 'views': 10329, 'rank': 845},
#  {'article': 'Pierre_Gasly', 'views': 10325, 'rank': 846},
#  {'article': 'Alison_Brie', 'views': 10317, 'rank': 847},
#  {'article': 'Karen_Gillan', 'views': 10310, 'rank': 848},
#  {'article': 'Adam_Sandler', 'views': 10308, 'rank': 849},
#  {'article': 'North_Korea', 'views': 10302, 'rank': 850},
#  {'article': 'Index_of_underwater_diving', 'views': 10290, 'rank': 851},
#  {'article': 'Bob_Marley', 'views': 10287, 'rank': 852},
#  {'article': 'Richard_Halsey_Best', 'views': 10285, 'rank': 853},
#  {'article': 'Sean_Connery', 'views': 10282, 'rank': 854},
#  {'article': 'The_Shawshank_Redemption', 'views': 10272, 'rank': 855},
#  {'article': 'Sentinelese', 'views': 10271, 'rank': 856},
#  {'article': 'WWE_Universal_Championship', 'views': 10270, 'rank': 857},
#  {'article': 'Jon_Favreau', 'views': 10268, 'rank': 858},
#  {'article': 'Adam_Driver', 'views': 10260, 'rank': 859},
#  {'article': 'FC_Bayern_Munich', 'views': 10257, 'rank': 860},
#  {'article': 'Netherlands', 'views': 10256, 'rank': 861},
#  {'article': 'Emma_Thompson', 'views': 10255, 'rank': 862},
#  {'article': 'George_V', 'views': 10253, 'rank': 863},
#  {'article': 'Northwestern_Syria_offensive_(December_2019–present)',
#   'views': 10244,
#   'rank': 864},
#  {'article': 'Tacko_Fall', 'views': 10240, 'rank': 865},
#  {'article': 'Barry_Sanders', 'views': 10227, 'rank': 866},
#  {'article': 'Hamilton_(musical)', 'views': 10210, 'rank': 867},
#  {'article': 'Ryan_Gosling', 'views': 10201, 'rank': 868},
#  {'article': 'Warren_Buffett', 'views': 10195, 'rank': 869},
#  {'article': 'Rihanna', 'views': 10181, 'rank': 870},
#  {'article': 'Bubonic_plague', 'views': 10174, 'rank': 871},
#  {'article': 'Harry_Potter_(film_series)', 'views': 10160, 'rank': 872},
#  {'article': 'Red_Bull_Racing', 'views': 10159, 'rank': 873},
#  {'article': 'Kim_Jong-un', 'views': 10154, 'rank': 874},
#  {'article': 'Richard_Armitage_(actor)', 'views': 10148, 'rank': 875},
#  {'article': 'Neil_Armstrong', 'views': 10148, 'rank': 875},
#  {'article': 'Influenza_pandemic', 'views': 10146, 'rank': 877},
#  {'article': 'Robert_Pattinson', 'views': 10136, 'rank': 878},
#  {'article': 'The_Body_(2019_film)', 'views': 10136, 'rank': 878},
#  {'article': 'President_of_the_United_States', 'views': 10124, 'rank': 880},
#  {'article': 'Danny_Masterson', 'views': 10105, 'rank': 881},
#  {'article': 'Nicole_Kidman', 'views': 10103, 'rank': 882},
#  {'article': 'Formula_One', 'views': 10098, 'rank': 883},
#  {'article': 'Windows_10_version_history', 'views': 10097, 'rank': 884},
#  {'article': 'SARS-CoV-2', 'views': 10095, 'rank': 885},
#  {'article': 'Anne_Bancroft', 'views': 10093, 'rank': 886},
#  {'article': 'List_of_most-subscribed_YouTube_channels',
#   'views': 10089,
#   'rank': 887},
#  {'article': 'Benjamín_Arellano_Félix', 'views': 10088, 'rank': 888},
#  {'article': 'Fifth_Harmony', 'views': 10079, 'rank': 889},
#  {'article': 'Christina_El_Moussa', 'views': 10075, 'rank': 890},
#  {'article': 'Naomi_Scott', 'views': 10072, 'rank': 891},
#  {'article': 'Minecraft', 'views': 10072, 'rank': 891},
#  {'article': 'The_Magnificent_Seven', 'views': 10072, 'rank': 891},
#  {'article': 'Morgane_Polanski', 'views': 10049, 'rank': 894},
#  {'article': 'James_Harden', 'views': 10042, 'rank': 895},
#  {'article': 'Four_Horsemen_of_the_Apocalypse', 'views': 10040, 'rank': 896},
#  {'article': 'Canadian_Broadcasting_Corporation', 'views': 10040, 'rank': 896},
#  {'article': 'Rose_McGowan', 'views': 10035, 'rank': 898},
#  {'article': 'The_Revenant_(2015_film)', 'views': 10035, 'rank': 898},
#  {'article': 'Library_Genesis', 'views': 10035, 'rank': 898},
#  {'article': 'Impractical_Jokers:_The_Movie', 'views': 10016, 'rank': 901},
#  {'article': 'Westworld_(TV_series)', 'views': 10009, 'rank': 902},
#  {'article': 'To_All_the_Boys:_P.S._I_Still_Love_You',
#   'views': 10006,
#   'rank': 903},
#  {'article': '2019–20_coronavirus_outbreak_in_Mainland_China',
#   'views': 10000,
#   'rank': 904},
#  {'article': 'Apple_Inc.', 'views': 9999, 'rank': 905},
#  {'article': 'Rachel_McAdams', 'views': 9998, 'rank': 906},
#  {'article': 'Pierce_Brosnan', 'views': 9991, 'rank': 907},
#  {'article': 'Tijuana_Cartel', 'views': 9991, 'rank': 907},
#  {'article': 'Pokémon:_The_First_Movie', 'views': 9974, 'rank': 909},
#  {'article': 'Sam_Smith', 'views': 9968, 'rank': 910},
#  {'article': 'Woken_Furies', 'views': 9965, 'rank': 911},
#  {'article': 'Daniel_Radcliffe', 'views': 9961, 'rank': 912},
#  {'article': 'Rian_Johnson', 'views': 9958, 'rank': 913},
#  {'article': 'Andy_Gibb', 'views': 9952, 'rank': 914},
#  {'article': 'The_Favourite', 'views': 9951, 'rank': 915},
#  {'article': '2020_coronavirus_outbreak_in_Switzerland',
#   'views': 9950,
#   'rank': 916},
#  {'article': 'Hand_sanitizer', 'views': 9950, 'rank': 916},
#  {'article': 'Luka_Dončić', 'views': 9948, 'rank': 918},
#  {'article': 'Survivor:_Winners_at_War', 'views': 9937, 'rank': 919},
#  {'article': 'Natalie_Portman', 'views': 9934, 'rank': 920},
#  {'article': 'Beanie_Feldstein', 'views': 9931, 'rank': 921},
#  {'article': 'Gordon_Ramsay', 'views': 9925, 'rank': 922},
#  {'article': 'List_of_Knowing_Bros_episodes', 'views': 9924, 'rank': 923},
#  {'article': 'Darbar_(film)', 'views': 9916, 'rank': 924},
#  {'article': 'List_of_largest_daily_changes_in_the_Dow_Jones_Industrial_Average',
#   'views': 9907,
#   'rank': 925},
#  {'article': 'European_Union', 'views': 9894, 'rank': 926},
#  {'article': 'Maggie_Baird', 'views': 9882, 'rank': 927},
#  {'article': 'The_Andromeda_Strain', 'views': 9873, 'rank': 928},
#  {'article': 'The_Good_Place', 'views': 9871, 'rank': 929},
#  {'article': 'Ronan_Farrow', 'views': 9862, 'rank': 930},
#  {'article': 'The_Masked_Singer_(American_TV_series)',
#   'views': 9832,
#   'rank': 931},
#  {'article': 'London', 'views': 9825, 'rank': 932},
#  {'article': 'Nicolas_Cage', 'views': 9824, 'rank': 933},
#  {'article': 'Julius_Caesar', 'views': 9801, 'rank': 934},
#  {'article': 'American_Civil_War', 'views': 9798, 'rank': 935},
#  {'article': '2020_ATP_Tour', 'views': 9792, 'rank': 936},
#  {'article': 'The_Good_Doctor_(TV_series)', 'views': 9782, 'rank': 937},
#  {'article': 'Frank_Sinatra', 'views': 9771, 'rank': 938},
#  {'article': 'Jumanji:_Welcome_to_the_Jungle', 'views': 9763, 'rank': 939},
#  {'article': 'Superdelegate', 'views': 9756, 'rank': 940},
#  {'article': 'Citizenship_Amendment_Act_protests', 'views': 9754, 'rank': 941},
#  {'article': 'Millie_Bobby_Brown', 'views': 9748, 'rank': 942},
#  {'article': 'Dan_Levy_(Canadian_actor)', 'views': 9747, 'rank': 943},
#  {'article': '2020_coronavirus_outbreak_on_cruise_ships',
#   'views': 9739,
#   'rank': 944},
#  {'article': 'Train_to_Busan', 'views': 9721, 'rank': 945},
#  {'article': 'Spider-Man:_Far_From_Home', 'views': 9717, 'rank': 946},
#  {'article': 'Travis_Scott', 'views': 9716, 'rank': 947},
#  {'article': 'George_W._Bush', 'views': 9712, 'rank': 948},
#  {'article': 'Harry_Potter', 'views': 9711, 'rank': 949},
#  {'article': 'Georgia_Guidestones', 'views': 9710, 'rank': 950},
#  {'article': 'Zion_Williamson', 'views': 9708, 'rank': 951},
#  {'article': 'Anne,_Queen_of_Great_Britain', 'views': 9706, 'rank': 952},
#  {'article': '45th_César_Awards', 'views': 9705, 'rank': 953},
#  {'article': 'The_Buck_Sexton_Show', 'views': 9700, 'rank': 954},
#  {'article': 'Gretel_&_Hansel', 'views': 9678, 'rank': 955},
#  {'article': 'Bangladesh', 'views': 9670, 'rank': 956},
#  {'article': 'Floyd_Mayweather_Jr.', 'views': 9670, 'rank': 956},
#  {'article': 'Matt_Damon', 'views': 9663, 'rank': 958},
#  {'article': 'Milla_Jovovich', 'views': 9657, 'rank': 959},
#  {'article': 'Casino_Royale_(2006_film)', 'views': 9652, 'rank': 960},
#  {'article': 'Wonder_(film)', 'views': 9648, 'rank': 961},
#  {'article': 'Florence_Pugh', 'views': 9636, 'rank': 962},
#  {'article': 'Los_Angeles', 'views': 9634, 'rank': 963},
#  {'article': 'Donald_Trump_Jr.', 'views': 9630, 'rank': 964},
#  {'article': 'Dr._Romantic_2', 'views': 9629, 'rank': 965},
#  {'article': 'John_Wayne', 'views': 9627, 'rank': 966},
#  {'article': 'Sambhaji', 'views': 9624, 'rank': 967},
#  {'article': 'Carol_Kane', 'views': 9617, 'rank': 968},
#  {'article': 'Xenophobia_and_racism_related_to_the_2019–20_coronavirus_outbreak',
#   'views': 9613,
#   'rank': 969},
#  {'article': 'Kevin_Hart', 'views': 9611, 'rank': 970},
#  {'article': 'List_of_the_verified_oldest_people', 'views': 9609, 'rank': 971},
#  {'article': 'Joni_Mitchell', 'views': 9608, 'rank': 972},
#  {'article': 'Goldie_Hawn', 'views': 9605, 'rank': 973},
#  {'article': 'Jack_Nicholson', 'views': 9592, 'rank': 974},
#  {'article': 'Katharine_Ross', 'views': 9585, 'rank': 975},
#  {'article': 'Street_Dancer_3D', 'views': 9584, 'rank': 976},
#  {'article': "Crohn's_disease", 'views': 9571, 'rank': 977},
#  {'article': '2019–20_UEFA_Europa_League', 'views': 9560, 'rank': 978},
#  {'article': 'Telugu_language', 'views': 9555, 'rank': 979},
#  {'article': 'Snoop_Dogg', 'views': 9551, 'rank': 980},
#  {'article': 'The_Witcher', 'views': 9539, 'rank': 981},
#  {'article': 'Meghan,_Duchess_of_Sussex', 'views': 9516, 'rank': 982},
#  {'article': 'Switzerland', 'views': 9510, 'rank': 983},
#  {'article': 'Nasdaq', 'views': 9498, 'rank': 984},
#  {'article': 'Danny_DeVito', 'views': 9494, 'rank': 985},
#  {'article': 'Tony_Robbins', 'views': 9483, 'rank': 986},
#  {'article': 'Renée_Zellweger', 'views': 9482, 'rank': 987},
#  {'article': 'Generation_X', 'views': 9479, 'rank': 988},
#  {'article': '2020', 'views': 9473, 'rank': 989},
#  {'article': 'Socialism', 'views': 9472, 'rank': 990},
#  {'article': 'Britney_Spears', 'views': 9472, 'rank': 990},
#  {'article': 'Paulina_Porizkova', 'views': 9469, 'rank': 992},
#  {'article': 'Hong_Kong', 'views': 9468, 'rank': 993},
#  {'article': 'Idina_Menzel', 'views': 9463, 'rank': 994},
#  {'article': "The_Handmaid's_Tale_(TV_series)", 'views': 9461, 'rank': 995},
#  {'article': 'R._Sundarrajan_(director)', 'views': 9439, 'rank': 996},
#  {'article': 'China_Global_Television_Network', 'views': 9437, 'rank': 997},
#  {'article': 'Pablo_Picasso', 'views': 9423, 'rank': 998},
#  {'article': 'Rami_Malek', 'views': 9420, 'rank': 999},
#  {'article': 'Bloodshot_(film)', 'views': 9414, 'rank': 1000}]

# %%
MW_API_URL = 'https://{lang}.{project}.org/w/api.php?'
PREFIXES = ['Special', 'Template', 'Sp?cial', 'Project']

def get_wiki_info(lang, project):
    '''\
    Get the mainpage title and local namespace map.
    '''
    url = MW_API_URL.format(lang=lang, project=project)
    params = {'action': 'query',
              'meta': 'siteinfo',
              'format': 'json',
              'siprop': 'general|namespaces'}
    resp = urllib2.urlopen(url + urlencode(params))
    data = json.loads(resp.read())
    mainpage = data['query']['general']['mainpage'].replace(' ', '_')
    namespaces = [ns_info['*'].replace(' ', '_') for ns_id, ns_info in
                  data['query']['namespaces'].items() if ns_id is not 0]
    return {'mainpage': mainpage, 'namespaces': namespaces}
# Out:
# <>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-4-d3fd4ef3e09a>:17: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   data['query']['namespaces'].items() if ns_id is not 0]

# %%
def is_article(title, wiki_info):
    '''\
    Is it an article, or some other sort of page? We'll want to filter out the
    search page (Special:Search in English, etc) and similar pages appearing
    inconveniently in the traffic report.
    Skip xhamster. There are a few clues this Wikipedia traffic is artificial.
    See https://en.wikipedia.org/w/index.php?title=XHamster&diff=701682670&oldid=700826198
    '''
    skip = ['-', '404.php', 'XHamster'] + [wiki_info['mainpage']]
    prefixes = PREFIXES + wiki_info['namespaces']
    if title in skip:
        return False
    if title == "Media":
        return False
    if title == "Wikipedia":
        return False
    if title == "United_States_Senate":
        return False
    for prefix in prefixes:
        if title.startswith(prefix + ':'):
            return False
    return True

# %%
wiki_info = get_wiki_info('en', 'wikipedia')
raw_traffic = get_traffic('2020', '02', '29')
articles = [a for a in raw_traffic if is_article(a['article'], wiki_info)]

# %%
len(articles[:25])
articles
# Out:
# [{'article': 'February_29', 'views': 449520, 'rank': 4},
#  {'article': '2019–20_coronavirus_outbreak', 'views': 401916, 'rank': 5},
#  {'article': 'The_Invisible_Man_(2020_film)', 'views': 275387, 'rank': 6},
#  {'article': 'Coronavirus', 'views': 268392, 'rank': 7},
#  {'article': 'Carlton_Tavern,_Kilburn', 'views': 244195, 'rank': 8},
#  {'article': '2019–20_coronavirus_outbreak_by_country_and_territory',
#   'views': 158829,
#   'rank': 9},
#  {'article': 'Boris_Johnson', 'views': 143594, 'rank': 10},
#  {'article': 'Mila_Kunis', 'views': 142252, 'rank': 11},
#  {'article': 'Leap_year', 'views': 139097, 'rank': 12},
#  {'article': 'Roman_Polanski', 'views': 138395, 'rank': 13},
#  {'article': 'Zhong_Nanshan', 'views': 126388, 'rank': 14},
#  {'article': 'Muhyiddin_Yassin', 'views': 124799, 'rank': 15},
#  {'article': 'Bible', 'views': 118980, 'rank': 16},
#  {'article': 'Spanish_flu', 'views': 115849, 'rank': 17},
#  {'article': 'WrestleMania_36', 'views': 104952, 'rank': 18},
#  {'article': 'Parasite_(2019_film)', 'views': 104200, 'rank': 19},
#  {'article': 'Third_Battle_of_Panipat', 'views': 103669, 'rank': 20},
#  {'article': 'Deaths_in_2020', 'views': 96759, 'rank': 21},
#  {'article': 'Altered_Carbon_(TV_series)', 'views': 94884, 'rank': 22},
#  {'article': 'Benjaman_Kyle', 'views': 93062, 'rank': 23},
#  {'article': 'Elimination_Chamber_(2020)', 'views': 91071, 'rank': 24},
#  {'article': 'Dietmar_Hopp', 'views': 90152, 'rank': 25},
#  {'article': 'Richard_Ramirez', 'views': 88824, 'rank': 26},
#  {'article': '2020_coronavirus_outbreak_in_Italy', 'views': 88503, 'rank': 27},
#  {'article': 'Coronavirus_disease_2019', 'views': 84038, 'rank': 28},
#  {'article': 'Carrie_Symonds', 'views': 79804, 'rank': 29},
#  {'article': 'Ken_Miles', 'views': 79648, 'rank': 30},
#  {'article': 'Miguel_Ángel_Félix_Gallardo', 'views': 77643, 'rank': 31},
#  {'article': 'Tyson_Fury', 'views': 72478, 'rank': 32},
#  {'article': 'Super_Tuesday', 'views': 70674, 'rank': 33},
#  {'article': '2020_Democratic_Party_presidential_primaries',
#   'views': 69040,
#   'rank': 34},
#  {'article': 'Freeman_Dyson', 'views': 68192, 'rank': 35},
#  {'article': "RuPaul's_Drag_Race_(season_12)", 'views': 67656, 'rank': 36},
#  {'article': 'Michael_Bloomberg', 'views': 66581, 'rank': 37},
#  {'article': 'The_Eyes_of_Darkness', 'views': 65776, 'rank': 38},
#  {'article': 'Bernie_Sanders', 'views': 64803, 'rank': 39},
#  {'article': 'Knives_Out', 'views': 64782, 'rank': 41},
#  {'article': 'Love_Is_Blind_(TV_series)', 'views': 63344, 'rank': 42},
#  {'article': 'BBC_World_Service', 'views': 62838, 'rank': 43},
#  {'article': 'Hunters_(2020_TV_series)', 'views': 61337, 'rank': 44},
#  {'article': 'North_East_Delhi_riots', 'views': 59893, 'rank': 45},
#  {'article': 'Priti_Patel', 'views': 59658, 'rank': 46},
#  {'article': 'Maria_Sharapova', 'views': 55930, 'rank': 48},
#  {'article': 'Crash_Landing_on_You', 'views': 54442, 'rank': 49},
#  {'article': 'I_Am_Not_Okay_with_This', 'views': 54126, 'rank': 50},
#  {'article': 'Donald_Trump', 'views': 54048, 'rank': 51},
#  {'article': '2020_South_Carolina_Democratic_primary',
#   'views': 53588,
#   'rank': 52},
#  {'article': 'Donald_trump', 'views': 53413, 'rank': 54},
#  {'article': 'Candyman_(1992_film)', 'views': 53047, 'rank': 55},
#  {'article': 'All_the_Bright_Places_(film)', 'views': 52418, 'rank': 56},
#  {'article': 'Pete_Davidson', 'views': 52148, 'rank': 57},
#  {'article': '2019–20_Wuhan_coronavirus_outbreak', 'views': 51843, 'rank': 58},
#  {'article': '2009_flu_pandemic', 'views': 50963, 'rank': 59},
#  {'article': "Kepler's_Supernova", 'views': 49568, 'rank': 60},
#  {'article': 'Alexandria_Ocasio-Cortez', 'views': 49532, 'rank': 61},
#  {'article': 'Onward_(film)', 'views': 48817, 'rank': 62},
#  {'article': 'Eurovision_Song_Contest_2020', 'views': 48202, 'rank': 63},
#  {'article': 'Rich_Energy', 'views': 47958, 'rank': 64},
#  {'article': 'Roman_Polanski_sexual_abuse_case', 'views': 47908, 'rank': 65},
#  {'article': 'Thappad', 'views': 47735, 'rank': 66},
#  {'article': 'Kobe_Bryant', 'views': 45782, 'rank': 67},
#  {'article': 'Microsoft_Office', 'views': 45692, 'rank': 68},
#  {'article': 'Philip_Rutnam', 'views': 45425, 'rank': 69},
#  {'article': 'Super_ShowDown_(2020)', 'views': 45235, 'rank': 70},
#  {'article': 'Ted_Kaczynski', 'views': 44833, 'rank': 71},
#  {'article': 'XXXX', 'views': 44758, 'rank': 72},
#  {'article': 'Achtung_Baby', 'views': 44732, 'rank': 73},
#  {'article': 'Ismaïla_Sarr', 'views': 44194, 'rank': 74},
#  {'article': 'Sonic_the_Hedgehog_(film)', 'views': 43648, 'rank': 75},
#  {'article': 'Taliban', 'views': 43386, 'rank': 76},
#  {'article': 'Joe_Coulombe', 'views': 43100, 'rank': 77},
#  {'article': 'Concert_tour', 'views': 42999, 'rank': 78},
#  {'article': 'Doja_Cat', 'views': 42771, 'rank': 79},
#  {'article': '1996_California_Proposition_218', 'views': 42600, 'rank': 80},
#  {'article': 'Sex', 'views': 41830, 'rank': 81},
#  {'article': 'List_of_Bollywood_films_of_2020', 'views': 41750, 'rank': 82},
#  {'article': 'Billie_Eilish', 'views': 41268, 'rank': 83},
#  {'article': 'All_the_Bright_Places', 'views': 41252, 'rank': 84},
#  {'article': 'Candyman_(2020_film)', 'views': 40971, 'rank': 85},
#  {'article': 'Sharon_Tate', 'views': 40935, 'rank': 86},
#  {'article': 'Daniel_Andreas_San_Diego', 'views': 40579, 'rank': 87},
#  {'article': 'Adèle_Haenel', 'views': 40568, 'rank': 88},
#  {'article': 'Anne-Marie_(singer)', 'views': 40346, 'rank': 89},
#  {'article': 'Jojo_Rabbit', 'views': 40167, 'rank': 90},
#  {'article': 'UFC_Fight_Night:_Benavidez_vs._Figueiredo',
#   'views': 39476,
#   'rank': 91},
#  {'article': 'XFL_(2020)', 'views': 39290, 'rank': 92},
#  {'article': 'Severe_acute_respiratory_syndrome', 'views': 39257, 'rank': 93},
#  {'article': 'Amado_Carrillo_Fuentes', 'views': 38858, 'rank': 94},
#  {'article': 'The_Invincibles_(football)', 'views': 38688, 'rank': 95},
#  {'article': '2020_coronavirus_outbreak_in_Europe',
#   'views': 38553,
#   'rank': 96},
#  {'article': 'John_Tenniel', 'views': 38392, 'rank': 97},
#  {'article': 'United_States', 'views': 38256, 'rank': 98},
#  {'article': 'Pandemic', 'views': 38256, 'rank': 98},
#  {'article': 'Hailey_Baldwin', 'views': 38142, 'rank': 100},
#  {'article': 'Tom_Steyer', 'views': 37807, 'rank': 101},
#  {'article': 'Elton_John', 'views': 37306, 'rank': 102},
#  {'article': 'Sophia_Lillis', 'views': 37011, 'rank': 103},
#  {'article': '2019_Formula_One_World_Championship',
#   'views': 36676,
#   'rank': 104},
#  {'article': 'Ala_Vaikunthapurramuloo', 'views': 36285, 'rank': 105},
#  {'article': 'Birds_of_Prey_(2020_film)', 'views': 35908, 'rank': 106},
#  {'article': 'NXT_TakeOver:_Tampa_Bay', 'views': 35378, 'rank': 107},
#  {'article': 'Judy_Garland', 'views': 35134, 'rank': 108},
#  {'article': 'Severe_acute_respiratory_syndrome_coronavirus_2',
#   'views': 35051,
#   'rank': 109},
#  {'article': 'Dua_Lipa', 'views': 34908, 'rank': 110},
#  {'article': 'Black_Death', 'views': 34670, 'rank': 111},
#  {'article': 'Elisabeth_Moss', 'views': 34645, 'rank': 112},
#  {'article': 'Distribution_resource_planning', 'views': 34523, 'rank': 113},
#  {'article': 'Lady_Gaga', 'views': 34170, 'rank': 114},
#  {'article': 'Fred_Rogers', 'views': 33843, 'rank': 115},
#  {'article': 'Star_Trek:_Picard', 'views': 33837, 'rank': 116},
#  {'article': 'Pete_Buttigieg', 'views': 33810, 'rank': 117},
#  {'article': 'YouTube', 'views': 33434, 'rank': 118},
#  {'article': 'Joker_(2019_film)', 'views': 33408, 'rank': 119},
#  {'article': 'John_Cena', 'views': 33353, 'rank': 120},
#  {'article': 'Fantasy_Island_(film)', 'views': 33275, 'rank': 121},
#  {'article': '2020_coronavirus_outbreak_in_Germany',
#   'views': 33012,
#   'rank': 122},
#  {'article': 'Pablo_Acosta_Villarreal', 'views': 32686, 'rank': 123},
#  {'article': 'Once_Upon_a_Time_in_Hollywood', 'views': 32603, 'rank': 124},
#  {'article': 'Panipat_(film)', 'views': 32527, 'rank': 125},
#  {'article': 'Elizabeth_II', 'views': 32412, 'rank': 126},
#  {'article': 'Anthony_Joshua', 'views': 32251, 'rank': 127},
#  {'article': '2020_coronavirus_outbreak_in_South_Korea',
#   'views': 31584,
#   'rank': 128},
#  {'article': 'Mike_Tyson', 'views': 31542, 'rank': 129},
#  {'article': 'The_Pirate_Bay', 'views': 31533, 'rank': 130},
#  {'article': 'Harvey_Weinstein', 'views': 31466, 'rank': 131},
#  {'article': 'Bad_Bunny', 'views': 31313, 'rank': 132},
#  {'article': 'Bombshell_(2019_film)', 'views': 31067, 'rank': 133},
#  {'article': 'Locke_&_Key_(TV_series)', 'views': 31058, 'rank': 134},
#  {'article': 'Periodic_table', 'views': 30927, 'rank': 135},
#  {'article': 'Giannis_Antetokounmpo', 'views': 30642, 'rank': 136},
#  {'article': 'Apple_Network_Server', 'views': 30564, 'rank': 137},
#  {'article': 'Elon_Musk', 'views': 30259, 'rank': 138},
#  {'article': 'Citizenship_(Amendment)_Act,_2019', 'views': 30163, 'rank': 139},
#  {'article': "Charlie's_Angels_(2019_film)", 'views': 29916, 'rank': 140},
#  {'article': 'Zoo_TV_Tour', 'views': 29887, 'rank': 141},
#  {'article': 'Joaquín_"El_Chapo"_Guzmán', 'views': 29520, 'rank': 142},
#  {'article': '1917_(2019_film)', 'views': 29091, 'rank': 144},
#  {'article': 'Coca-Cola', 'views': 29024, 'rank': 145},
#  {'article': 'Ford_v_Ferrari', 'views': 28984, 'rank': 146},
#  {'article': 'The_Stranger_(British_TV_series)', 'views': 28701, 'rank': 147},
#  {'article': 'Narcos:_Mexico', 'views': 28461, 'rank': 148},
#  {'article': 'India', 'views': 28448, 'rank': 149},
#  {'article': 'Carroll_Shelby', 'views': 28384, 'rank': 150},
#  {'article': 'The_Invisible_Man', 'views': 28263, 'rank': 151},
#  {'article': "Bachelor's_Day_(tradition)", 'views': 28260, 'rank': 152},
#  {'article': 'Freddie_Mercury', 'views': 27999, 'rank': 153},
#  {'article': 'Superman:_Red_Son_(film)', 'views': 27813, 'rank': 154},
#  {'article': 'Hyun_Bin', 'views': 27807, 'rank': 155},
#  {'article': 'Justin_Bieber', 'views': 27789, 'rank': 156},
#  {'article': 'Marina_Wheeler', 'views': 27734, 'rank': 157},
#  {'article': 'Brooklyn', 'views': 27650, 'rank': 158},
#  {'article': '2020_coronavirus_outbreak_in_the_United_States',
#   'views': 27596,
#   'rank': 159},
#  {'article': 'Uncut_Gems', 'views': 27486, 'rank': 160},
#  {'article': 'Frozen_II', 'views': 27462, 'rank': 161},
#  {'article': 'AEW_Revolution', 'views': 27458, 'rank': 162},
#  {'article': 'Ana_de_Armas', 'views': 27128, 'rank': 163},
#  {'article': 'List_of_Marvel_Cinematic_Universe_films',
#   'views': 26856,
#   'rank': 164},
#  {'article': 'Inter_Miami_CF', 'views': 26774, 'rank': 165},
#  {'article': 'BTS_(band)', 'views': 26659, 'rank': 166},
#  {'article': "Trader_Joe's", 'views': 26433, 'rank': 167},
#  {'article': 'Itaewon_Class', 'views': 26349, 'rank': 168},
#  {'article': 'Barack_Obama', 'views': 26160, 'rank': 169},
#  {'article': 'Sadashivrao_Bhau', 'views': 25931, 'rank': 170},
#  {'article': 'Aileen_Wuornos', 'views': 25930, 'rank': 171},
#  {'article': 'An_Officer_and_a_Spy_(film)', 'views': 25761, 'rank': 172},
#  {'article': 'Michael_Jordan', 'views': 25739, 'rank': 173},
#  {'article': 'Johnny_Cash', 'views': 25723, 'rank': 174},
#  {'article': 'Index_of_Windows_games_(S)', 'views': 25719, 'rank': 175},
#  {'article': 'Deontay_Wilder', 'views': 25405, 'rank': 176},
#  {'article': 'List_of_epidemics', 'views': 25389, 'rank': 177},
#  {'article': 'The_Suicide_Squad_(film)', 'views': 25342, 'rank': 178},
#  {'article': 'Elle_Fanning', 'views': 25175, 'rank': 179},
#  {'article': 'Pablo_Escobar', 'views': 25125, 'rank': 180},
#  {'article': 'Jumanji:_The_Next_Level', 'views': 25093, 'rank': 181},
#  {'article': 'Christian_Horner', 'views': 24954, 'rank': 182},
#  {'article': 'Joaquin_Phoenix', 'views': 24950, 'rank': 183},
#  {'article': 'Oliver_Jackson-Cohen', 'views': 24929, 'rank': 184},
#  {'article': 'A_Quiet_Place_(film)', 'views': 24871, 'rank': 185},
#  {'article': 'Elizabeth_Warren', 'views': 24864, 'rank': 186},
#  {'article': 'Better_Call_Saul', 'views': 24721, 'rank': 187},
#  {'article': 'Keanu_Reeves', 'views': 24700, 'rank': 188},
#  {'article': 'Geri_Halliwell', 'views': 24557, 'rank': 189},
#  {'article': 'Lewis_Hamilton', 'views': 24227, 'rank': 190},
#  {'article': 'Contagion_(2011_film)', 'views': 24139, 'rank': 191},
#  {'article': 'Bill_Goldberg', 'views': 23918, 'rank': 192},
#  {'article': 'Greta_Thunberg', 'views': 23879, 'rank': 193},
#  {'article': 'Melania_Trump', 'views': 23775, 'rank': 194},
#  {'article': 'Halsey_(singer)', 'views': 23569, 'rank': 195},
#  {'article': 'Stupid_Love_(Lady_Gaga_song)', 'views': 23554, 'rank': 196},
#  {'article': 'Influenza', 'views': 23238, 'rank': 197},
#  {'article': 'Al_Pacino', 'views': 23230, 'rank': 198},
#  {'article': 'Altered_Carbon', 'views': 23114, 'rank': 199},
#  {'article': 'The_Call_of_the_Wild_(2020_film)', 'views': 23073, 'rank': 200},
#  {'article': 'Muhammad_Ali', 'views': 23065, 'rank': 201},
#  {'article': 'Prime_Minister_of_Malaysia', 'views': 22999, 'rank': 202},
#  {'article': 'Adolf_Hitler', 'views': 22851, 'rank': 203},
#  {'article': 'Dwayne_Johnson', 'views': 22811, 'rank': 204},
#  {'article': 'Kannum_Kannum_Kollaiyadithaal', 'views': 22799, 'rank': 205},
#  {'article': 'Draupathi_(2020_film)', 'views': 22728, 'rank': 206},
#  {'article': '2020_Formula_One_World_Championship',
#   'views': 22702,
#   'rank': 207},
#  {'article': '2020_United_States_presidential_election',
#   'views': 22429,
#   'rank': 208},
#  {'article': 'United_Kingdom', 'views': 22388, 'rank': 209},
#  {'article': 'Princess_Margaret,_Countess_of_Snowdon',
#   'views': 22201,
#   'rank': 210},
#  {'article': 'Justice_Smith', 'views': 22102, 'rank': 211},
#  {'article': 'Girl_on_the_Third_Floor', 'views': 22057, 'rank': 212},
#  {'article': 'Joe_Biden', 'views': 21819, 'rank': 214},
#  {'article': 'Portrait_of_a_Lady_on_Fire', 'views': 21800, 'rank': 215},
#  {'article': 'The_Last_Thing_He_Wanted_(film)', 'views': 21694, 'rank': 216},
#  {'article': 'Shubh_Mangal_Zyada_Saavdhan', 'views': 21689, 'rank': 217},
#  {'article': 'Haas_F1_Team', 'views': 21664, 'rank': 218},
#  {'article': 'John_Ratcliffe_(American_politician)',
#   'views': 21645,
#   'rank': 220},
#  {'article': 'Tom_Cruise', 'views': 21473, 'rank': 221},
#  {'article': 'Mardi_Gras', 'views': 21446, 'rank': 222},
#  {'article': '2020_coronavirus_outbreak_in_Spain',
#   'views': 21395,
#   'rank': 223},
#  {'article': 'Non-binary_gender', 'views': 21365, 'rank': 224},
#  {'article': 'TSG_1899_Hoffenheim', 'views': 21273, 'rank': 225},
#  {'article': 'No_Time_to_Die', 'views': 21094, 'rank': 227},
#  {'article': 'Guns_Akimbo', 'views': 20975, 'rank': 229},
#  {'article': 'Steven_Spielberg', 'views': 20923, 'rank': 230},
#  {'article': 'The_Outsider_(miniseries)', 'views': 20829, 'rank': 231},
#  {'article': 'Sun_Yang', 'views': 20782, 'rank': 232},
#  {'article': 'Son_Ye-jin', 'views': 20733, 'rank': 233},
#  {'article': 'Wuhan', 'views': 20706, 'rank': 234},
#  {'article': 'Dia_Mirza', 'views': 20703, 'rank': 235},
#  {'article': 'Post_Malone', 'views': 20695, 'rank': 236},
#  {'article': 'List_of_Bollywood_films_of_2019', 'views': 20669, 'rank': 237},
#  {'article': 'List_of_presidents_of_the_United_States',
#   'views': 20563,
#   'rank': 238},
#  {'article': 'My_Hero_Academia:_Heroes_Rising', 'views': 20553, 'rank': 239},
#  {'article': 'Rock_music', 'views': 20543, 'rank': 240},
#  {'article': 'Jeff_Bezos', 'views': 20526, 'rank': 241},
#  {'article': 'Rafael_Caro_Quintero', 'views': 20518, 'rank': 242},
#  {'article': 'Facebook', 'views': 20412, 'rank': 243},
#  {'article': 'Godzilla:_King_of_the_Monsters_(2019_film)',
#   'views': 20410,
#   'rank': 244},
#  {'article': 'Taika_Waititi', 'views': 20279, 'rank': 245},
#  {'article': 'Google', 'views': 20268, 'rank': 246},
#  {'article': 'World_War_II', 'views': 20243, 'rank': 247},
#  {'article': 'Marge_in_Chains', 'views': 20121, 'rank': 248},
#  {'article': 'COVID-19', 'views': 20053, 'rank': 250},
#  {'article': 'Mark_Wahlberg', 'views': 20045, 'rank': 251},
#  {'article': 'The_World_(archipelago)', 'views': 20024, 'rank': 252},
#  {'article': '2020_Summer_Olympics', 'views': 20006, 'rank': 253},
#  {'article': 'Guenther_Steiner', 'views': 19828, 'rank': 254},
#  {'article': '2020_coronavirus_outbreak_in_Japan',
#   'views': 19810,
#   'rank': 255},
#  {'article': 'Watford_F.C.', 'views': 19749, 'rank': 256},
#  {'article': 'List_of_most-viewed_YouTube_videos',
#   'views': 19702,
#   'rank': 257},
#  {'article': 'The_Irishman', 'views': 19677, 'rank': 258},
#  {'article': "The_World's_Billionaires", 'views': 19671, 'rank': 259},
#  {'article': 'Mahathir_Mohamad', 'views': 19650, 'rank': 260},
#  {'article': 'James_Dean', 'views': 19534, 'rank': 261},
#  {'article': 'Mewtwo_Strikes_Back:_Evolution', 'views': 19512, 'rank': 262},
#  {'article': 'Stephen_Hawking', 'views': 19505, 'rank': 263},
#  {'article': 'The_Witcher_(TV_series)', 'views': 19498, 'rank': 264},
#  {'article': 'War_in_Afghanistan_(2001–present)', 'views': 19440, 'rank': 265},
#  {'article': 'Anthony_S._Fauci', 'views': 19403, 'rank': 266},
#  {'article': 'Taylor_Swift', 'views': 19317, 'rank': 267},
#  {'article': 'Premier_League', 'views': 19283, 'rank': 268},
#  {'article': 'List_of_United_States_cities_by_population',
#   'views': 19151,
#   'rank': 269},
#  {'article': 'Cristiano_Ronaldo', 'views': 19128, 'rank': 270},
#  {'article': 'Bhoot_–_Part_One:_The_Haunted_Ship',
#   'views': 19061,
#   'rank': 271},
#  {'article': 'Charles_Manson', 'views': 19054, 'rank': 272},
#  {'article': 'Hawaii_Five-0_(2010_TV_series)', 'views': 19047, 'rank': 273},
#  {'article': 'Priyanka_Chopra', 'views': 19039, 'rank': 274},
#  {'article': 'Dark_Waters_(2019_film)', 'views': 18996, 'rank': 275},
#  {'article': 'List_of_James_Bond_films', 'views': 18900, 'rank': 276},
#  {'article': 'Sex_Education_(TV_series)', 'views': 18896, 'rank': 277},
#  {'article': 'Scarlett_Johansson', 'views': 18866, 'rank': 278},
#  {'article': 'Terminator:_Dark_Fate', 'views': 18863, 'rank': 279},
#  {'article': 'Nick_Jonas', 'views': 18823, 'rank': 280},
#  {'article': 'Henry_Hill', 'views': 18813, 'rank': 281},
#  {'article': 'Sammy_Davis_Jr.', 'views': 18769, 'rank': 282},
#  {'article': 'China', 'views': 18733, 'rank': 283},
#  {'article': '123Movies', 'views': 18730, 'rank': 284},
#  {'article': 'Malaysian_United_Indigenous_Party', 'views': 18701, 'rank': 285},
#  {'article': 'Pope_Francis', 'views': 18698, 'rank': 286},
#  {'article': 'Bangla_TV', 'views': 18693, 'rank': 287},
#  {'article': 'The_Outsiders_(film)', 'views': 18599, 'rank': 288},
#  {'article': 'The_Magnificent_Seven_(2016_film)', 'views': 18597, 'rank': 289},
#  {'article': 'Operation_Paperclip', 'views': 18571, 'rank': 290},
#  {'article': 'The_Trials_of_Gabriel_Fernandez', 'views': 18530, 'rank': 291},
#  {'article': 'Midway_(2019_film)', 'views': 18483, 'rank': 292},
#  {'article': 'Zodiac', 'views': 18336, 'rank': 293},
#  {'article': 'World_War_I', 'views': 18315, 'rank': 294},
#  {'article': 'Ahmad_Shah_Durrani', 'views': 18307, 'rank': 295},
#  {'article': 'Grim_Sleeper', 'views': 18302, 'rank': 296},
#  {'article': 'MasterChef_India_(season_6)', 'views': 18276, 'rank': 297},
#  {'article': '2020_Democratic_Party_presidential_debates',
#   'views': 18276,
#   'rank': 297},
#  {'article': 'LeBron_James', 'views': 18272, 'rank': 299},
#  {'article': 'Leonardo_DiCaprio', 'views': 18235, 'rank': 300},
#  {'article': 'Helen_Keller', 'views': 18219, 'rank': 301},
#  {'article': 'Luka_Magnotta', 'views': 18214, 'rank': 302},
#  {'article': 'Taapsee_Pannu', 'views': 18198, 'rank': 303},
#  {'article': 'Liverpool_F.C.', 'views': 18188, 'rank': 304},
#  {'article': '2020_in_film', 'views': 18119, 'rank': 305},
#  {'article': 'Alexander_Albon', 'views': 18055, 'rank': 306},
#  {'article': 'Timothée_Chalamet', 'views': 18047, 'rank': 307},
#  {'article': 'Pangolin', 'views': 18047, 'rank': 307},
#  {'article': '2020_coronavirus_outbreak_in_France',
#   'views': 18010,
#   'rank': 309},
#  {'article': 'Anubhav_Sinha', 'views': 17951, 'rank': 310},
#  {'article': 'Pornhub', 'views': 17945, 'rank': 311},
#  {'article': 'Héctor_Luis_Palma_Salazar', 'views': 17863, 'rank': 312},
#  {'article': 'Anne_Hathaway', 'views': 17780, 'rank': 313},
#  {'article': 'Ball_lightning', 'views': 17699, 'rank': 314},
#  {'article': 'Hosni_Mubarak', 'views': 17615, 'rank': 315},
#  {'article': 'New_York_City', 'views': 17544, 'rank': 316},
#  {'article': 'Doctor_Sleep_(2019_film)', 'views': 17527, 'rank': 317},
#  {'article': 'Midsommar_(film)', 'views': 17509, 'rank': 318},
#  {'article': 'List_of_UFC_events', 'views': 17466, 'rank': 319},
#  {'article': 'Molly_Seidel', 'views': 17465, 'rank': 320},
#  {'article': 'Jimmy_Hoffa', 'views': 17439, 'rank': 321},
#  {'article': 'Baaghi_3', 'views': 17395, 'rank': 322},
#  {'article': 'Main_page', 'views': 17333, 'rank': 323},
#  {'article': 'Aaron_Hernandez', 'views': 17324, 'rank': 324},
#  {'article': '2016_United_States_presidential_election',
#   'views': 17293,
#   'rank': 325},
#  {'article': "2020_ICC_Women's_T20_World_Cup", 'views': 17276, 'rank': 326},
#  {'article': 'Little_Women_(2019_film)', 'views': 17241, 'rank': 327},
#  {'article': 'Ariana_Grande', 'views': 17224, 'rank': 328},
#  {'article': 'Bad_Boys_for_Life', 'views': 17204, 'rank': 329},
#  {'article': 'Ted_Bundy', 'views': 17197, 'rank': 330},
#  {'article': 'Henry_Cavill', 'views': 17191, 'rank': 331},
#  {'article': 'Online_dating_service', 'views': 17160, 'rank': 332},
#  {'article': 'Emmanuelle_Seigner', 'views': 17152, 'rank': 333},
#  {'article': 'Roger_Ailes', 'views': 17127, 'rank': 334},
#  {'article': 'Influenza_A_virus_subtype_H1N1', 'views': 17119, 'rank': 336},
#  {'article': 'Find_My_iPhone', 'views': 17114, 'rank': 337},
#  {'article': 'Luxembourg', 'views': 17046, 'rank': 338},
#  {'article': 'Margot_Robbie', 'views': 17021, 'rank': 339},
#  {'article': 'Prince_Philip,_Duke_of_Edinburgh', 'views': 16978, 'rank': 340},
#  {'article': 'Mike_Pence', 'views': 16946, 'rank': 341},
#  {'article': 'Macaulay_Culkin', 'views': 16927, 'rank': 342},
#  {'article': 'Null', 'views': 16925, 'rank': 343},
#  {'article': 'Sadie_Hawkins_Day', 'views': 16913, 'rank': 344},
#  {'article': 'Lent', 'views': 16796, 'rank': 345},
#  {'article': 'TikTok', 'views': 16753, 'rank': 346},
#  {'article': 'Joel_Kinnaman', 'views': 16704, 'rank': 347},
#  {'article': 'Tina_Turner', 'views': 16687, 'rank': 348},
#  {'article': 'List_of_American_films_of_2020', 'views': 16677, 'rank': 349},
#  {'article': 'Megyn_Kelly', 'views': 16665, 'rank': 351},
#  {'article': 'Brad_Pitt', 'views': 16632, 'rank': 353},
#  {'article': '2020_coronavirus_outbreak_in_Iran', 'views': 16568, 'rank': 354},
#  {'article': 'Dakota_Fanning', 'views': 16524, 'rank': 355},
#  {'article': '2020_Players_Championship_(snooker)',
#   'views': 16519,
#   'rank': 356},
#  {'article': 'Michael_Jackson', 'views': 16518, 'rank': 357},
#  {'article': 'Ashton_Kutcher', 'views': 16472, 'rank': 358},
#  {'article': 'Aldis_Hodge', 'views': 16461, 'rank': 359},
#  {'article': 'Jennifer_Aniston', 'views': 16403, 'rank': 360},
#  {'article': 'Eminem', 'views': 16362, 'rank': 361},
#  {'article': 'Wiki', 'views': 16351, 'rank': 362},
#  {'article': 'Katherine_Johnson', 'views': 16333, 'rank': 363},
#  {'article': 'The_Green_Mile_(film)', 'views': 16324, 'rank': 364},
#  {'article': 'Malaysia', 'views': 16308, 'rank': 365},
#  {'article': 'Doordarshan', 'views': 16242, 'rank': 366},
#  {'article': 'Pamela_Smart', 'views': 16205, 'rank': 367},
#  {'article': 'Tyrone_S._Woods', 'views': 16199, 'rank': 368},
#  {'article': 'Bob_Geldof', 'views': 16194, 'rank': 369},
#  {'article': 'Jordan_Peele', 'views': 16194, 'rank': 369},
#  {'article': 'The_Hunt_(2020_film)', 'views': 16146, 'rank': 371},
#  {'article': 'The_Call_of_the_Wild', 'views': 16128, 'rank': 372},
#  {'article': 'Paige_(wrestler)', 'views': 16123, 'rank': 373},
#  {'article': 'North_Sentinel_Island', 'views': 16100, 'rank': 374},
#  {'article': 'Shia_LaBeouf', 'views': 16097, 'rank': 375},
#  {'article': 'Michael_Clarke_Duncan', 'views': 16086, 'rank': 376},
#  {'article': 'Steve_Jobs', 'views': 16034, 'rank': 377},
#  {'article': 'XXXTentacion', 'views': 16015, 'rank': 378},
#  {'article': 'Multiplication', 'views': 16003, 'rank': 379},
#  {'article': '2020_coronavirus_outbreak_in_Asia', 'views': 15989, 'rank': 380},
#  {'article': 'Nicki_Minaj', 'views': 15974, 'rank': 381},
#  {'article': "Baldur's_Gate_III", 'views': 15971, 'rank': 382},
#  {'article': 'Camila_Cabello', 'views': 15929, 'rank': 383},
#  {'article': 'Locke_&_Key', 'views': 15917, 'rank': 384},
#  {'article': 'Harry_Styles', 'views': 15914, 'rank': 385},
#  {'article': 'George_VI', 'views': 15910, 'rank': 386},
#  {'article': 'Elvis_Presley', 'views': 15909, 'rank': 387},
#  {'article': 'Remdesivir', 'views': 15890, 'rank': 388},
#  {'article': 'Canada', 'views': 15878, 'rank': 389},
#  {'article': 'Winston_Churchill', 'views': 15851, 'rank': 390},
#  {'article': 'Chris_Evans_(actor)', 'views': 15845, 'rank': 391},
#  {'article': 'Timeline_of_the_SARS_outbreak', 'views': 15825, 'rank': 392},
#  {'article': 'Index_of_Economic_Freedom', 'views': 15817, 'rank': 393},
#  {'article': 'Céline_Sciamma', 'views': 15805, 'rank': 394},
#  {'article': 'Wladimir_Klitschko', 'views': 15764, 'rank': 395},
#  {'article': 'Ebola_virus_disease', 'views': 15753, 'rank': 396},
#  {'article': 'Griffin_(The_Invisible_Man)', 'views': 15751, 'rank': 397},
#  {'article': 'Star_Wars:_The_Rise_of_Skywalker', 'views': 15739, 'rank': 398},
#  {'article': 'Syrian_civil_war', 'views': 15721, 'rank': 399},
#  {'article': '2003–04_Arsenal_F.C._season', 'views': 15714, 'rank': 400},
#  {'article': 'Candyman_(character)', 'views': 15705, 'rank': 402},
#  {'article': 'Patrick_Swayze', 'views': 15655, 'rank': 403},
#  {'article': 'Outlander_(TV_series)', 'views': 15646, 'rank': 404},
#  {'article': 'Corona_(beer)', 'views': 15595, 'rank': 406},
#  {'article': 'UFC_248', 'views': 15581, 'rank': 407},
#  {'article': 'Troy_Deeney', 'views': 15574, 'rank': 408},
#  {'article': 'Business_interruption_insurance', 'views': 15563, 'rank': 409},
#  {'article': 'Virus', 'views': 15556, 'rank': 410},
#  {'article': 'Chernobyl_disaster', 'views': 15518, 'rank': 411},
#  {'article': 'Harrison_Ford', 'views': 15484, 'rank': 412},
#  {'article': 'Daniel_Craig', 'views': 15463, 'rank': 413},
#  {'article': 'Jim_Carrey', 'views': 15436, 'rank': 414},
#  {'article': 'Flag_of_Scotland', 'views': 15418, 'rank': 415},
#  {'article': "Shaquille_O'Neal", 'views': 15409, 'rank': 416},
#  {'article': 'Pop_Smoke', 'views': 15370, 'rank': 417},
#  {'article': 'Gwen_Stefani', 'views': 15362, 'rank': 418},
#  {'article': 'Ivanka_Trump', 'views': 15354, 'rank': 419},
#  {'article': 'Wyatt_Oleff', 'views': 15328, 'rank': 420},
#  {'article': 'Bestgore.com', 'views': 15320, 'rank': 421},
#  {'article': 'Stephen_Baldwin', 'views': 15278, 'rank': 422},
#  {'article': 'Ernesto_Fonseca_Carrillo', 'views': 15278, 'rank': 422},
#  {'article': 'Tony_Todd', 'views': 15251, 'rank': 424},
#  {'article': 'Us_(2019_film)', 'views': 15228, 'rank': 425},
#  {'article': 'Natalie_Wood', 'views': 15223, 'rank': 426},
#  {'article': 'Gabriel_Fernández', 'views': 15223, 'rank': 426},
#  {'article': 'Jason_Momoa', 'views': 15204, 'rank': 428},
#  {'article': 'Logan_Lerman', 'views': 15172, 'rank': 429},
#  {'article': 'Gwyneth_Paltrow', 'views': 15172, 'rank': 429},
#  {'article': 'Waco_siege', 'views': 15130, 'rank': 431},
#  {'article': 'Manson_Family', 'views': 15122, 'rank': 432},
#  {'article': 'Harriet_Tubman', 'views': 15117, 'rank': 433},
#  {'article': 'Patrick_Stewart', 'views': 15114, 'rank': 434},
#  {'article': 'Good_Newwz', 'views': 15097, 'rank': 435},
#  {'article': 'Tony_Romo', 'views': 15082, 'rank': 436},
#  {'article': 'Superman:_Red_Son', 'views': 15006, 'rank': 437},
#  {'article': 'Dolittle_(film)', 'views': 14984, 'rank': 438},
#  {'article': 'Jennifer_Lopez', 'views': 14954, 'rank': 439},
#  {'article': 'BBC', 'views': 14927, 'rank': 440},
#  {'article': 'Afghanistan', 'views': 14908, 'rank': 441},
#  {'article': 'Goodfellas', 'views': 14899, 'rank': 442},
#  {'article': '2019–20_Wuhan_coronavirus_outbreak_by_country_and_territory',
#   'views': 14864,
#   'rank': 443},
#  {'article': "RuPaul's_Drag_Race", 'views': 14848, 'rank': 444},
#  {'article': 'Tom_Selleck', 'views': 14781, 'rank': 445},
#  {'article': 'Fear_Factor:_Khatron_Ke_Khiladi', 'views': 14778, 'rank': 446},
#  {'article': 'Johnny_Depp', 'views': 14765, 'rank': 447},
#  {'article': 'David_Beckham', 'views': 14743, 'rank': 448},
#  {'article': 'The_Invisible_Man_(1933_film)', 'views': 14732, 'rank': 449},
#  {'article': 'Ben_Affleck', 'views': 14692, 'rank': 451},
#  {'article': 'Emma_(2020_film)', 'views': 14688, 'rank': 452},
#  {'article': 'MasterChef_India', 'views': 14674, 'rank': 453},
#  {'article': 'Arnold_Schwarzenegger', 'views': 14666, 'rank': 454},
#  {'article': 'Roddy_Ricch', 'views': 14623, 'rank': 455},
#  {'article': 'Diamond_Princess_(ship)', 'views': 14617, 'rank': 456},
#  {'article': 'Taj_Mahal', 'views': 14612, 'rank': 457},
#  {'article': 'Louis_C.K.', 'views': 14547, 'rank': 458},
#  {'article': 'Jimmy_Fallon', 'views': 14511, 'rank': 459},
#  {'article': 'Mulan_(2020_film)', 'views': 14478, 'rank': 460},
#  {'article': 'Avengers:_Endgame', 'views': 14472, 'rank': 461},
#  {'article': 'Alex_Azar', 'views': 14465, 'rank': 462},
#  {'article': 'John_F._Kennedy', 'views': 14455, 'rank': 463},
#  {'article': 'Knives_Out_(film)', 'views': 14449, 'rank': 464},
#  {'article': 'Storm_Reid', 'views': 14448, 'rank': 465},
#  {'article': 'Queen_Victoria', 'views': 14436, 'rank': 466},
#  {'article': 'Iceland_in_the_Eurovision_Song_Contest_2020',
#   'views': 14412,
#   'rank': 467},
#  {'article': 'Dionne_Warwick', 'views': 14407, 'rank': 468},
#  {'article': 'List_of_S&P_500_companies', 'views': 14401, 'rank': 469},
#  {'article': 'Jean_Seberg', 'views': 14399, 'rank': 470},
#  {'article': 'John_Krasinski', 'views': 14388, 'rank': 471},
#  {'article': 'Edward_VIII', 'views': 14360, 'rank': 472},
#  {'article': 'Timeline_of_the_2019–20_coronavirus_outbreak',
#   'views': 14322,
#   'rank': 473},
#  {'article': 'Kiki_Camarena', 'views': 14321, 'rank': 474},
#  {'article': 'Charles,_Prince_of_Wales', 'views': 14316, 'rank': 475},
#  {'article': 'Kristen_Bell', 'views': 14293, 'rank': 476},
#  {'article': 'Joseph_Benavidez', 'views': 14267, 'rank': 477},
#  {'article': 'Strawberry', 'views': 14257, 'rank': 478},
#  {'article': 'Singapore', 'views': 14251, 'rank': 479},
#  {'article': 'Angelina_Jolie', 'views': 14239, 'rank': 480},
#  {'article': 'Crisis_on_Infinite_Earths_(Arrowverse)',
#   'views': 14200,
#   'rank': 481},
#  {'article': 'Queen_(band)', 'views': 14168, 'rank': 483},
#  {'article': 'Mahatma_Gandhi', 'views': 14162, 'rank': 484},
#  {'article': 'Phil_Spector', 'views': 14154, 'rank': 485},
#  {'article': 'Gretchen_Carlson', 'views': 14134, 'rank': 486},
#  {'article': 'Clint_Eastwood', 'views': 14113, 'rank': 487},
#  {'article': '2020_Republican_Party_presidential_primaries',
#   'views': 14107,
#   'rank': 488},
#  {'article': 'Manchester_United_F.C.', 'views': 14087, 'rank': 489},
#  {'article': "Bridegroom's_Oak", 'views': 14063, 'rank': 490},
#  {'article': 'Tom_Brady', 'views': 14055, 'rank': 491},
#  {'article': 'Splendor_in_the_Grass', 'views': 14045, 'rank': 492},
#  {'article': 'Mia_Khalifa', 'views': 14036, 'rank': 493},
#  {'article': 'Richard_Rishi', 'views': 14007, 'rank': 494},
#  {'article': 'Estonia_in_the_Eurovision_Song_Contest_2020',
#   'views': 13978,
#   'rank': 495},
#  {'article': 'Ricky_Martin', 'views': 13976, 'rank': 496},
#  {'article': 'Ja_Rule', 'views': 13973, 'rank': 497},
#  {'article': 'Malcolm_X', 'views': 13948, 'rank': 498},
#  {'article': 'Gregorian_calendar', 'views': 13947, 'rank': 499},
#  {'article': 'Russia', 'views': 13932, 'rank': 500},
#  {'article': 'John_Mulaney', 'views': 13905, 'rank': 501},
#  {'article': 'Malang_(film)', 'views': 13895, 'rank': 502},
#  {'article': 'Rafael_Aguilar_Guajardo', 'views': 13881, 'rank': 503},
#  {'article': 'Jarrod_Bowen', 'views': 13871, 'rank': 504},
#  {'article': 'A_Quiet_Place_Part_II', 'views': 13866, 'rank': 505},
#  {'article': 'Bong_Joon-ho', 'views': 13865, 'rank': 506},
#  {'article': 'Heath_Ledger', 'views': 13847, 'rank': 507},
#  {'article': 'The_Lighthouse_(2019_film)', 'views': 13814, 'rank': 508},
#  {'article': 'Alexander_the_Great', 'views': 13800, 'rank': 509},
#  {'article': 'Sylvester_Stallone', 'views': 13789, 'rank': 510},
#  {'article': 'Sinaloa_Cartel', 'views': 13745, 'rank': 511},
#  {'article': 'Bruce_Lee', 'views': 13721, 'rank': 512},
#  {'article': 'Narendra_Modi', 'views': 13713, 'rank': 513},
#  {'article': 'Millennials', 'views': 13695, 'rank': 514},
#  {'article': 'Malta', 'views': 13688, 'rank': 515},
#  {'article': 'Love_Aaj_Kal_(2020_film)', 'views': 13685, 'rank': 516},
#  {'article': 'Netflix', 'views': 13678, 'rank': 517},
#  {'article': 'List_of_highest-grossing_films', 'views': 13673, 'rank': 518},
#  {'article': 'Christian_Bale', 'views': 13671, 'rank': 519},
#  {'article': 'Peaky_Blinders_(TV_series)', 'views': 13671, 'rank': 519},
#  {'article': 'Robin_Williams', 'views': 13663, 'rank': 521},
#  {'article': 'Australia', 'views': 13634, 'rank': 522},
#  {'article': 'Dow_Jones_Industrial_Average', 'views': 13602, 'rank': 523},
#  {'article': 'List_of_most-viewed_online_videos_in_the_first_24_hours',
#   'views': 13565,
#   'rank': 525},
#  {'article': 'Philip_II_of_Macedon', 'views': 13554, 'rank': 526},
#  {'article': 'Amy_Klobuchar', 'views': 13495, 'rank': 527},
#  {'article': 'The_Weeknd', 'views': 13485, 'rank': 528},
#  {'article': 'Lionel_Messi', 'views': 13480, 'rank': 529},
#  {'article': 'Residente', 'views': 13477, 'rank': 530},
#  {'article': "Schitt's_Creek", 'views': 13411, 'rank': 531},
#  {'article': 'Better_Call_Saul_(season_5)', 'views': 13398, 'rank': 532},
#  {'article': 'Chris_Pratt', 'views': 13396, 'rank': 533},
#  {'article': 'First_Battle_of_Panipat', 'views': 13376, 'rank': 534},
#  {'article': 'Germany', 'views': 13375, 'rank': 535},
#  {'article': 'Tulsi_Gabbard', 'views': 13373, 'rank': 536},
#  {'article': 'Tom_Hanks', 'views': 13340, 'rank': 537},
#  {'article': 'Radhika_Madan', 'views': 13334, 'rank': 538},
#  {'article': 'Caroline_Flack', 'views': 13305, 'rank': 539},
#  {'article': 'Battle_of_Midway', 'views': 13301, 'rank': 540},
#  {'article': 'Albert_Einstein', 'views': 13294, 'rank': 541},
#  {'article': 'Tupac_Shakur', 'views': 13287, 'rank': 542},
#  {'article': 'Abraham_Lincoln', 'views': 13281, 'rank': 543},
#  {'article': 'Kylie_Jenner', 'views': 13273, 'rank': 544},
#  {'article': 'Severe_acute_respiratory_syndrome-related_coronavirus',
#   'views': 13272,
#   'rank': 545},
#  {'article': "Grey's_Anatomy", 'views': 13239, 'rank': 547},
#  {'article': 'River_Phoenix', 'views': 13205, 'rank': 548},
#  {'article': 'Bray_Wyatt', 'views': 13176, 'rank': 549},
#  {'article': 'Tanhaji', 'views': 13168, 'rank': 550},
#  {'article': 'Marvel_Cinematic_Universe', 'views': 13165, 'rank': 551},
#  {'article': 'Grimes_(musician)', 'views': 13160, 'rank': 552},
#  {'article': 'U.S._state', 'views': 13152, 'rank': 553},
#  {'article': 'Sarileru_Neekevvaru', 'views': 13150, 'rank': 554},
#  {'article': 'The_Mandalorian', 'views': 13141, 'rank': 555},
#  {'article': 'Gene_Haas', 'views': 13125, 'rank': 556},
#  {'article': 'Marilyn_Monroe', 'views': 13116, 'rank': 557},
#  {'article': 'Shafali_Verma', 'views': 13113, 'rank': 558},
#  {'article': 'Greg_Wise', 'views': 13112, 'rank': 559},
#  {'article': 'Novak_Djokovic', 'views': 13104, 'rank': 560},
#  {'article': 'Pirates_of_the_Caribbean_(film_series)',
#   'views': 13094,
#   'rank': 561},
#  {'article': 'Swine_influenza', 'views': 13081, 'rank': 562},
#  {'article': 'Pneumonia', 'views': 13079, 'rank': 563},
#  {'article': 'Michael_Dorman', 'views': 13072, 'rank': 564},
#  {'article': 'Will_Smith', 'views': 13047, 'rank': 565},
#  {'article': 'A_Beautiful_Day_in_the_Neighborhood',
#   'views': 13042,
#   'rank': 566},
#  {'article': 'Kareem_Abdul-Jabbar', 'views': 13039, 'rank': 567},
#  {'article': 'HTTP_404', 'views': 13021, 'rank': 568},
#  {'article': '.xxx', 'views': 13020, 'rank': 569},
#  {'article': '2020_Slovak_parliamentary_election',
#   'views': 12968,
#   'rank': 570},
#  {'article': 'Tones_and_I', 'views': 12960, 'rank': 571},
#  {'article': 'Greek_alphabet', 'views': 12935, 'rank': 572},
#  {'article': 'Nick_Lachey', 'views': 12920, 'rank': 573},
#  {'article': 'Turkey', 'views': 12881, 'rank': 574},
#  {'article': 'Al_Jazeera', 'views': 12876, 'rank': 575},
#  {'article': 'Tyra_Banks', 'views': 12871, 'rank': 576},
#  {'article': 'Bill_Gates', 'views': 12838, 'rank': 577},
#  {'article': 'Quentin_Tarantino', 'views': 12824, 'rank': 578},
#  {'article': 'Sam_Elliott', 'views': 12805, 'rank': 579},
#  {'article': 'My_Hero_Academia', 'views': 12784, 'rank': 580},
#  {'article': 'Shincheonji_Church_of_Jesus_the_Temple_of_the_Tabernacle_of_the_Testimony',
#   'views': 12783,
#   'rank': 581},
#  {'article': 'The_Undertaker', 'views': 12779, 'rank': 582},
#  {'article': 'Bobby_Ryan', 'views': 12754, 'rank': 583},
#  {'article': 'Ozzy_Osbourne', 'views': 12743, 'rank': 584},
#  {'article': 'Joseph_Stalin', 'views': 12739, 'rank': 585},
#  {'article': 'Dyson_sphere', 'views': 12726, 'rank': 586},
#  {'article': 'Alex_Caruso', 'views': 12705, 'rank': 587},
#  {'article': 'Pakistan', 'views': 12702, 'rank': 588},
#  {'article': 'James_Burke_(gangster)', 'views': 12696, 'rank': 589},
#  {'article': 'Brooklyn_Nine-Nine', 'views': 12682, 'rank': 590},
#  {'article': 'Japan', 'views': 12647, 'rank': 591},
#  {'article': 'Queen_Sono', 'views': 12646, 'rank': 592},
#  {'article': 'Jeffrey_Dahmer', 'views': 12616, 'rank': 593},
#  {'article': 'Dreyfus_affair', 'views': 12608, 'rank': 594},
#  {'article': 'Robert_De_Niro', 'views': 12597, 'rank': 595},
#  {'article': 'RT_(TV_network)', 'views': 12583, 'rank': 596},
#  {'article': 'Morarji_Desai', 'views': 12557, 'rank': 597},
#  {'article': 'Wernher_von_Braun', 'views': 12543, 'rank': 598},
#  {'article': 'Sasha_Banks', 'views': 12538, 'rank': 599},
#  {'article': 'Allu_Arjun', 'views': 12522, 'rank': 600},
#  {'article': 'September_11_attacks', 'views': 12510, 'rank': 601},
#  {'article': 'Premier_League_records_and_statistics',
#   'views': 12498,
#   'rank': 602},
#  {'article': 'Joshua_Zirkzee', 'views': 12494, 'rank': 603},
#  {'article': 'Shakira', 'views': 12486, 'rank': 604},
#  {'article': 'Ronald_Reagan', 'views': 12478, 'rank': 605},
#  {'article': 'Ryan_Reynolds', 'views': 12477, 'rank': 606},
#  {'article': 'Emily_Blunt', 'views': 12465, 'rank': 607},
#  {'article': 'Marjaavaan', 'views': 12465, 'rank': 607},
#  {'article': 'World_Health_Organization', 'views': 12456, 'rank': 609},
#  {'article': 'Smriti_Mandhana', 'views': 12455, 'rank': 610},
#  {'article': 'Monster_Hunter_(film)', 'views': 12431, 'rank': 611},
#  {'article': 'Michael_Crichton', 'views': 12414, 'rank': 612},
#  {'article': 'Zooey_Deschanel', 'views': 12402, 'rank': 613},
#  {'article': 'George_Washington', 'views': 12393, 'rank': 614},
#  {'article': 'List_of_Star_Wars_films', 'views': 12355, 'rank': 615},
#  {'article': 'Garth_Brooks', 'views': 12338, 'rank': 616},
#  {'article': 'Lennox_Lewis', 'views': 12305, 'rank': 617},
#  {'article': 'William_Shakespeare', 'views': 12282, 'rank': 618},
#  {'article': 'Global_warming', 'views': 12235, 'rank': 619},
#  {'article': 'RMS_Titanic', 'views': 12224, 'rank': 620},
#  {'article': 'Tom_Hardy', 'views': 12221, 'rank': 621},
#  {'article': 'List_of_states_and_territories_of_the_United_States',
#   'views': 12182,
#   'rank': 622},
#  {'article': 'Franklin_D._Roosevelt', 'views': 12181, 'rank': 623},
#  {'article': 'Ash_Wednesday', 'views': 12172, 'rank': 624},
#  {'article': 'Daniel_Ricciardo', 'views': 12171, 'rank': 625},
#  {'article': 'Bradley_Cooper', 'views': 12162, 'rank': 626},
#  {'article': 'Ric_Ocasek', 'views': 12156, 'rank': 627},
#  {'article': 'Prince_(musician)', 'views': 12144, 'rank': 628},
#  {'article': 'Bhad_Bhabie', 'views': 12135, 'rank': 629},
#  {'article': 'Snowpiercer', 'views': 12119, 'rank': 630},
#  {'article': 'Zoë_Kravitz', 'views': 12106, 'rank': 631},
#  {'article': 'Mary,_Queen_of_Scots', 'views': 12103, 'rank': 632},
#  {'article': 'The_Sinner_(TV_series)', 'views': 12095, 'rank': 633},
#  {'article': 'Vietnam_War', 'views': 12093, 'rank': 634},
#  {'article': 'Anthony_Mackie', 'views': 12084, 'rank': 635},
#  {'article': 'List_of_countries_by_GDP_(nominal)',
#   'views': 12069,
#   'rank': 636},
#  {'article': 'Nico_Hülkenberg', 'views': 12056, 'rank': 637},
#  {'article': 'Tejasswi_Prakash', 'views': 12053, 'rank': 638},
#  {'article': '24_Hours_of_Le_Mans', 'views': 12051, 'rank': 639},
#  {'article': 'The_Walking_Dead_(TV_series)', 'views': 12042, 'rank': 640},
#  {'article': 'The_Masked_Singer_(American_season_3)',
#   'views': 12036,
#   'rank': 641},
#  {'article': 'Tamil_language', 'views': 12035, 'rank': 642},
#  {'article': 'Kristen_Stewart', 'views': 12021, 'rank': 643},
#  {'article': 'Seven_deadly_sins', 'views': 12001, 'rank': 644},
#  {'article': 'The_Beatles', 'views': 11996, 'rank': 645},
#  {'article': 'WhatsApp', 'views': 11972, 'rank': 646},
#  {'article': 'Yahya_Abdul-Mateen_II', 'views': 11964, 'rank': 647},
#  {'article': 'Sam_Rockwell', 'views': 11962, 'rank': 648},
#  {'article': 'U2', 'views': 11944, 'rank': 649},
#  {'article': 'Amazon_(company)', 'views': 11940, 'rank': 650},
#  {'article': 'Bobby_Shmurda', 'views': 11936, 'rank': 651},
#  {'article': 'John_Wick:_Chapter_3_–_Parabellum', 'views': 11912, 'rank': 652},
#  {'article': 'Vin_Diesel', 'views': 11878, 'rank': 653},
#  {'article': 'Comparison_of_online_dating_services',
#   'views': 11866,
#   'rank': 654},
#  {'article': 'Niki_Lauda', 'views': 11856, 'rank': 655},
#  {'article': 'Drew_Peterson', 'views': 11846, 'rank': 656},
#  {'article': "Finneas_O'Connell", 'views': 11839, 'rank': 657},
#  {'article': 'Awkwafina', 'views': 11839, 'rank': 657},
#  {'article': 'Harriet_(film)', 'views': 11810, 'rank': 659},
#  {'article': 'June_Carter_Cash', 'views': 11805, 'rank': 660},
#  {'article': 'Kim_Kardashian', 'views': 11784, 'rank': 661},
#  {'article': 'Harrow_(TV_series)', 'views': 11777, 'rank': 662},
#  {'article': 'Generation_Z', 'views': 11771, 'rank': 663},
#  {'article': 'Darth_Vader', 'views': 11764, 'rank': 664},
#  {'article': 'Nigel_Pearson', 'views': 11764, 'rank': 664},
#  {'article': 'Jon_Bon_Jovi', 'views': 11757, 'rank': 666},
#  {'article': 'Francesca_Annis', 'views': 11752, 'rank': 667},
#  {'article': 'The_dress', 'views': 11752, 'rank': 667},
#  {'article': 'Website', 'views': 11715, 'rank': 669},
#  {'article': 'Galen_Rupp', 'views': 11705, 'rank': 670},
#  {'article': 'Warren_Beatty', 'views': 11704, 'rank': 671},
#  {'article': 'Kapil_Mishra', 'views': 11689, 'rank': 672},
#  {'article': 'McMillions', 'views': 11685, 'rank': 673},
#  {'article': 'Juice_Wrld', 'views': 11683, 'rank': 674},
#  {'article': 'Vanessa_Lachey', 'views': 11654, 'rank': 675},
#  {'article': 'Takeshi_Kovacs', 'views': 11614, 'rank': 676},
#  {'article': 'France', 'views': 11607, 'rank': 677},
#  {'article': 'Mexico', 'views': 11601, 'rank': 678},
#  {'article': 'List_of_WWE_pay-per-view_and_WWE_Network_events',
#   'views': 11586,
#   'rank': 679},
#  {'article': 'Charlie_Hunnam', 'views': 11585, 'rank': 680},
#  {'article': 'Anna_Kendrick', 'views': 11558, 'rank': 681},
#  {'article': 'Pope_Benedict_XVI', 'views': 11543, 'rank': 682},
#  {'article': "Grey's_Anatomy_(season_16)", 'views': 11540, 'rank': 683},
#  {'article': 'Anya_Taylor-Joy', 'views': 11535, 'rank': 684},
#  {'article': 'Dean_Koontz', 'views': 11526, 'rank': 685},
#  {'article': 'Charlize_Theron', 'views': 11526, 'rank': 685},
#  {'article': 'Yoel_Romero', 'views': 11525, 'rank': 687},
#  {'article': 'Major_League_Soccer', 'views': 11514, 'rank': 688},
#  {'article': 'Bex_Taylor-Klaus', 'views': 11502, 'rank': 689},
#  {'article': 'Soviet_Union', 'views': 11499, 'rank': 690},
#  {'article': 'Index_of_law_articles', 'views': 11488, 'rank': 691},
#  {'article': 'XXX:_State_of_the_Union', 'views': 11476, 'rank': 692},
#  {'article': 'States_and_union_territories_of_India',
#   'views': 11438,
#   'rank': 693},
#  {'article': 'Pet_Sematary_(2019_film)', 'views': 11422, 'rank': 694},
#  {'article': 'Melodifestivalen_2020', 'views': 11407, 'rank': 695},
#  {'article': 'Alec_Baldwin', 'views': 11384, 'rank': 696},
#  {'article': 'Stephen_Curry', 'views': 11377, 'rank': 697},
#  {'article': 'Pooja_Hegde', 'views': 11366, 'rank': 698},
#  {'article': 'Brahms:_The_Boy_II', 'views': 11353, 'rank': 699},
#  {'article': 'Rebel_Without_a_Cause', 'views': 11349, 'rank': 700},
#  {'article': 'Sexual_intercourse', 'views': 11339, 'rank': 701},
#  {'article': 'Stephen_Mulhern', 'views': 11339, 'rank': 701},
#  {'article': '2020_coronavirus_outbreak_in_Canada',
#   'views': 11335,
#   'rank': 703},
#  {'article': 'Breakthrough_(2019_film)', 'views': 11325, 'rank': 705},
#  {'article': 'California', 'views': 11315, 'rank': 706},
#  {'article': 'Instagram', 'views': 11309, 'rank': 707},
#  {'article': 'O._J._Simpson', 'views': 11302, 'rank': 708},
#  {'article': 'Rangers_F.C.', 'views': 11297, 'rank': 709},
#  {'article': 'Star_Wars', 'views': 11277, 'rank': 710},
#  {'article': 'Will_Arnett', 'views': 11266, 'rank': 711},
#  {'article': 'Rashmika_Mandanna', 'views': 11261, 'rank': 712},
#  {'article': 'Liza_Minnelli', 'views': 11245, 'rank': 714},
#  {'article': 'Henry_VIII_of_England', 'views': 11241, 'rank': 715},
#  {'article': 'UEFA_Euro_2020', 'views': 11237, 'rank': 716},
#  {'article': 'Erling_Braut_Håland', 'views': 11232, 'rank': 717},
#  {'article': 'Horse_Girl', 'views': 11225, 'rank': 718},
#  {'article': 'The_Holocaust', 'views': 11224, 'rank': 719},
#  {'article': 'Whitney_Houston', 'views': 11216, 'rank': 720},
#  {'article': 'F5_Networks', 'views': 11202, 'rank': 721},
#  {'article': 'Martin_Luther_King_Jr.', 'views': 11159, 'rank': 722},
#  {'article': 'Solar_System', 'views': 11152, 'rank': 723},
#  {'article': 'Suicide_methods', 'views': 11147, 'rank': 724},
#  {'article': 'Harvey_Weinstein_sexual_abuse_cases',
#   'views': 11144,
#   'rank': 725},
#  {'article': 'Academy_Award_for_Best_Picture', 'views': 11107, 'rank': 726},
#  {'article': 'Nicole_Scherzinger', 'views': 11106, 'rank': 727},
#  {'article': 'Fasting_and_abstinence_in_the_Catholic_Church',
#   'views': 11106,
#   'rank': 727},
#  {'article': 'Mandy_Moore', 'views': 11104, 'rank': 729},
#  {'article': 'Amber_Heard', 'views': 11104, 'rank': 729},
#  {'article': 'Cher', 'views': 11094, 'rank': 731},
#  {'article': 'Hilary_Duff', 'views': 11093, 'rank': 732},
#  {'article': 'Alexander_Hamilton', 'views': 11090, 'rank': 733},
#  {'article': 'John_Lennon', 'views': 11087, 'rank': 734},
#  {'article': 'Zodiac_Killer', 'views': 11080, 'rank': 736},
#  {'article': 'Leap_Year_(2010_film)', 'views': 11077, 'rank': 737},
#  {'article': 'Timeline_of_the_2019–20_coronavirus_outbreak_in_February_2020',
#   'views': 11073,
#   'rank': 738},
#  {'article': "To_All_the_Boys_I've_Loved_Before_(film)",
#   'views': 11072,
#   'rank': 739},
#  {'article': 'Beyoncé', 'views': 11065, 'rank': 740},
#  {'article': 'Riverdale_(2017_TV_series)', 'views': 11063, 'rank': 741},
#  {'article': 'Steve_McQueen', 'views': 11053, 'rank': 742},
#  {'article': 'Elizabeth_I_of_England', 'views': 11053, 'rank': 742},
#  {'article': 'Philippines', 'views': 11053, 'rank': 742},
#  {'article': 'Kirk_Douglas', 'views': 11024, 'rank': 745},
#  {'article': 'Imelda_Marcos', 'views': 11016, 'rank': 746},
#  {'article': 'Shah_Rukh_Khan', 'views': 11016, 'rank': 746},
#  {'article': 'Nikola_Tesla', 'views': 11016, 'rank': 746},
#  {'article': 'Tom_Holland_(actor)', 'views': 11011, 'rank': 749},
#  {'article': '2019–20_Premier_League', 'views': 11010, 'rank': 750},
#  {'article': 'Jason_Statham', 'views': 11006, 'rank': 751},
#  {'article': 'Stranger_Things', 'views': 11001, 'rank': 752},
#  {'article': 'Big_Brother_(2020_film)', 'views': 10989, 'rank': 753},
#  {'article': 'Ade_Edmondson', 'views': 10982, 'rank': 754},
#  {'article': 'South_Africa', 'views': 10981, 'rank': 755},
#  {'article': 'The_Gentlemen_(2019_film)', 'views': 10977, 'rank': 756},
#  {'article': 'Bernie_Taupin', 'views': 10976, 'rank': 757},
#  {'article': 'Friends', 'views': 10967, 'rank': 758},
#  {'article': 'Shameless_(U.S._TV_series)', 'views': 10954, 'rank': 759},
#  {'article': 'SAP_SE', 'views': 10950, 'rank': 760},
#  {'article': 'Diana,_Princess_of_Wales', 'views': 10949, 'rank': 761},
#  {'article': '92nd_Academy_Awards', 'views': 10937, 'rank': 762},
#  {'article': 'You_(TV_series)', 'views': 10924, 'rank': 763},
#  {'article': 'Battle_of_Panipat', 'views': 10907, 'rank': 764},
#  {'article': 'Salma_Hayek', 'views': 10892, 'rank': 765},
#  {'article': 'Fear_Factor:_Khatron_Ke_Khiladi_10',
#   'views': 10878,
#   'rank': 766},
#  {'article': 'Leigh_Whannell', 'views': 10870, 'rank': 767},
#  {'article': 'Sooryavanshi', 'views': 10847, 'rank': 768},
#  {'article': 'Italy', 'views': 10844, 'rank': 769},
#  {'article': 'Dakota_Johnson', 'views': 10838, 'rank': 770},
#  {'article': 'Marin_County_Civic_Center_attacks', 'views': 10822, 'rank': 771},
#  {'article': 'Fingerprint_(computing)', 'views': 10821, 'rank': 772},
#  {'article': 'Akira_(1988_film)', 'views': 10819, 'rank': 773},
#  {'article': 'Jennifer_Garner', 'views': 10801, 'rank': 774},
#  {'article': 'Charlie_Sheen', 'views': 10800, 'rank': 775},
#  {'article': 'Tiger_Shroff', 'views': 10784, 'rank': 777},
#  {'article': 'Meg_Johnson_(poet)', 'views': 10774, 'rank': 778},
#  {'article': 'Ottoman_Empire', 'views': 10770, 'rank': 779},
#  {'article': 'Robert_Downey_Jr.', 'views': 10767, 'rank': 780},
#  {'article': 'Ayushmann_Khurrana', 'views': 10762, 'rank': 781},
#  {'article': 'Academy_Awards', 'views': 10761, 'rank': 782},
#  {'article': 'I_Still_Believe_(film)', 'views': 10760, 'rank': 783},
#  {'article': 'Tate–LaBianca_murders', 'views': 10754, 'rank': 784},
#  {'article': 'Lisa_Bonet', 'views': 10753, 'rank': 785},
#  {'article': 'Selena_Gomez', 'views': 10745, 'rank': 786},
#  {'article': 'Jackie_Chan', 'views': 10740, 'rank': 787},
#  {'article': 'Israel', 'views': 10729, 'rank': 788},
#  {'article': 'Lucifer_(TV_series)', 'views': 10729, 'rank': 788},
#  {'article': 'Harriet_Dyer', 'views': 10714, 'rank': 790},
#  {'article': 'List_of_Star_Wars:_The_Clone_Wars_episodes',
#   'views': 10711,
#   'rank': 791},
#  {'article': 'Open_primaries_in_the_United_States',
#   'views': 10707,
#   'rank': 792},
#  {'article': 'William_Shatner', 'views': 10694, 'rank': 793},
#  {'article': 'WrestleMania_35', 'views': 10692, 'rank': 794},
#  {'article': 'Amy_Adams', 'views': 10671, 'rank': 795},
#  {'article': 'ADX_Florence', 'views': 10653, 'rank': 796},
#  {'article': 'Zendaya', 'views': 10645, 'rank': 797},
#  {'article': 'Indonesia', 'views': 10639, 'rank': 798},
#  {'article': 'Ford_GT40', 'views': 10635, 'rank': 799},
#  {'article': 'Lee_Iacocca', 'views': 10635, 'rank': 799},
#  {'article': 'Roman_Reigns', 'views': 10633, 'rank': 801},
#  {'article': 'Broken_Angels_(novel)', 'views': 10626, 'rank': 802},
#  {'article': 'List_of_most-followed_TikTok_accounts',
#   'views': 10623,
#   'rank': 803},
#  {'article': 'List_of_Walt_Disney_Pictures_films',
#   'views': 10617,
#   'rank': 804},
#  {'article': 'Jeremy_Camp', 'views': 10617, 'rank': 804},
#  {'article': 'Ritesh_Agarwal', 'views': 10613, 'rank': 806},
#  {'article': 'Spies_in_Disguise', 'views': 10613, 'rank': 806},
#  {'article': 'Lewis_Capaldi', 'views': 10608, 'rank': 808},
#  {'article': 'Blake_Lively', 'views': 10605, 'rank': 809},
#  {'article': 'Sal_Mineo', 'views': 10599, 'rank': 810},
#  {'article': 'Gaslighting', 'views': 10598, 'rank': 811},
#  {'article': 'American_Horror_Story', 'views': 10585, 'rank': 812},
#  {'article': 'Color_Out_of_Space_(film)', 'views': 10581, 'rank': 813},
#  {'article': 'Pakatan_Harapan', 'views': 10580, 'rank': 814},
#  {'article': 'Bridget_Moynahan', 'views': 10562, 'rank': 815},
#  {'article': '2020_coronavirus_outbreak_in_the_Philippines',
#   'views': 10560,
#   'rank': 816},
#  {'article': 'South_Korea', 'views': 10549, 'rank': 817},
#  {'article': 'Earth', 'views': 10545, 'rank': 818},
#  {'article': 'Madonna_(entertainer)', 'views': 10525, 'rank': 819},
#  {'article': 'Frank_Sheeran', 'views': 10523, 'rank': 820},
#  {'article': 'South_Carolina', 'views': 10515, 'rank': 821},
#  {'article': 'Julia_Roberts', 'views': 10504, 'rank': 822},
#  {'article': 'RuPaul', 'views': 10501, 'rank': 823},
#  {'article': 'Iran', 'views': 10483, 'rank': 825},
#  {'article': 'Chris_Hemsworth', 'views': 10483, 'rank': 825},
#  {'article': 'Jake_Gyllenhaal', 'views': 10479, 'rank': 827},
#  {'article': 'Emma_Watson', 'views': 10477, 'rank': 828},
#  {'article': 'Napoleon', 'views': 10467, 'rank': 829},
#  {'article': 'Rajya_Sabha_TV', 'views': 10463, 'rank': 830},
#  {'article': 'Arsenal_F.C.', 'views': 10463, 'rank': 830},
#  {'article': 'Matthew_McConaughey', 'views': 10450, 'rank': 832},
#  {'article': 'La_Bougie_du_Sapeur', 'views': 10425, 'rank': 833},
#  {'article': 'Sexy', 'views': 10421, 'rank': 834},
#  {'article': 'Reese_Witherspoon', 'views': 10419, 'rank': 835},
#  {'article': 'David_Bowie', 'views': 10401, 'rank': 836},
#  {'article': 'The_Walking_Dead_(season_10)', 'views': 10390, 'rank': 837},
#  {'article': 'Leylah_Annie_Fernandez', 'views': 10384, 'rank': 838},
#  {'article': 'Marcos_Alonso_(footballer,_born_1990)',
#   'views': 10379,
#   'rank': 839},
#  {'article': 'List_of_most-followed_Instagram_accounts',
#   'views': 10349,
#   'rank': 840},
#  {'article': 'Fuck_for_the_heir_Puppy_Bear!', 'views': 10348, 'rank': 841},
#  {'article': 'Titanic_(1997_film)', 'views': 10334, 'rank': 842},
#  {'article': 'New_Zealand', 'views': 10332, 'rank': 843},
#  {'article': '2020_Pakistan_Super_League', 'views': 10330, 'rank': 844},
#  {'article': 'Breaking_Bad', 'views': 10329, 'rank': 845},
#  {'article': 'Pierre_Gasly', 'views': 10325, 'rank': 846},
#  {'article': 'Alison_Brie', 'views': 10317, 'rank': 847},
#  {'article': 'Karen_Gillan', 'views': 10310, 'rank': 848},
#  {'article': 'Adam_Sandler', 'views': 10308, 'rank': 849},
#  {'article': 'North_Korea', 'views': 10302, 'rank': 850},
#  {'article': 'Index_of_underwater_diving', 'views': 10290, 'rank': 851},
#  {'article': 'Bob_Marley', 'views': 10287, 'rank': 852},
#  {'article': 'Richard_Halsey_Best', 'views': 10285, 'rank': 853},
#  {'article': 'Sean_Connery', 'views': 10282, 'rank': 854},
#  {'article': 'The_Shawshank_Redemption', 'views': 10272, 'rank': 855},
#  {'article': 'Sentinelese', 'views': 10271, 'rank': 856},
#  {'article': 'WWE_Universal_Championship', 'views': 10270, 'rank': 857},
#  {'article': 'Jon_Favreau', 'views': 10268, 'rank': 858},
#  {'article': 'Adam_Driver', 'views': 10260, 'rank': 859},
#  {'article': 'FC_Bayern_Munich', 'views': 10257, 'rank': 860},
#  {'article': 'Netherlands', 'views': 10256, 'rank': 861},
#  {'article': 'Emma_Thompson', 'views': 10255, 'rank': 862},
#  {'article': 'George_V', 'views': 10253, 'rank': 863},
#  {'article': 'Northwestern_Syria_offensive_(December_2019–present)',
#   'views': 10244,
#   'rank': 864},
#  {'article': 'Tacko_Fall', 'views': 10240, 'rank': 865},
#  {'article': 'Barry_Sanders', 'views': 10227, 'rank': 866},
#  {'article': 'Hamilton_(musical)', 'views': 10210, 'rank': 867},
#  {'article': 'Ryan_Gosling', 'views': 10201, 'rank': 868},
#  {'article': 'Warren_Buffett', 'views': 10195, 'rank': 869},
#  {'article': 'Rihanna', 'views': 10181, 'rank': 870},
#  {'article': 'Bubonic_plague', 'views': 10174, 'rank': 871},
#  {'article': 'Harry_Potter_(film_series)', 'views': 10160, 'rank': 872},
#  {'article': 'Red_Bull_Racing', 'views': 10159, 'rank': 873},
#  {'article': 'Kim_Jong-un', 'views': 10154, 'rank': 874},
#  {'article': 'Richard_Armitage_(actor)', 'views': 10148, 'rank': 875},
#  {'article': 'Neil_Armstrong', 'views': 10148, 'rank': 875},
#  {'article': 'Influenza_pandemic', 'views': 10146, 'rank': 877},
#  {'article': 'Robert_Pattinson', 'views': 10136, 'rank': 878},
#  {'article': 'The_Body_(2019_film)', 'views': 10136, 'rank': 878},
#  {'article': 'President_of_the_United_States', 'views': 10124, 'rank': 880},
#  {'article': 'Danny_Masterson', 'views': 10105, 'rank': 881},
#  {'article': 'Nicole_Kidman', 'views': 10103, 'rank': 882},
#  {'article': 'Formula_One', 'views': 10098, 'rank': 883},
#  {'article': 'Windows_10_version_history', 'views': 10097, 'rank': 884},
#  {'article': 'SARS-CoV-2', 'views': 10095, 'rank': 885},
#  {'article': 'Anne_Bancroft', 'views': 10093, 'rank': 886},
#  {'article': 'List_of_most-subscribed_YouTube_channels',
#   'views': 10089,
#   'rank': 887},
#  {'article': 'Benjamín_Arellano_Félix', 'views': 10088, 'rank': 888},
#  {'article': 'Fifth_Harmony', 'views': 10079, 'rank': 889},
#  {'article': 'Christina_El_Moussa', 'views': 10075, 'rank': 890},
#  {'article': 'Naomi_Scott', 'views': 10072, 'rank': 891},
#  {'article': 'Minecraft', 'views': 10072, 'rank': 891},
#  {'article': 'The_Magnificent_Seven', 'views': 10072, 'rank': 891},
#  {'article': 'Morgane_Polanski', 'views': 10049, 'rank': 894},
#  {'article': 'James_Harden', 'views': 10042, 'rank': 895},
#  {'article': 'Four_Horsemen_of_the_Apocalypse', 'views': 10040, 'rank': 896},
#  {'article': 'Canadian_Broadcasting_Corporation', 'views': 10040, 'rank': 896},
#  {'article': 'Rose_McGowan', 'views': 10035, 'rank': 898},
#  {'article': 'The_Revenant_(2015_film)', 'views': 10035, 'rank': 898},
#  {'article': 'Library_Genesis', 'views': 10035, 'rank': 898},
#  {'article': 'Impractical_Jokers:_The_Movie', 'views': 10016, 'rank': 901},
#  {'article': 'Westworld_(TV_series)', 'views': 10009, 'rank': 902},
#  {'article': 'To_All_the_Boys:_P.S._I_Still_Love_You',
#   'views': 10006,
#   'rank': 903},
#  {'article': '2019–20_coronavirus_outbreak_in_Mainland_China',
#   'views': 10000,
#   'rank': 904},
#  {'article': 'Apple_Inc.', 'views': 9999, 'rank': 905},
#  {'article': 'Rachel_McAdams', 'views': 9998, 'rank': 906},
#  {'article': 'Pierce_Brosnan', 'views': 9991, 'rank': 907},
#  {'article': 'Tijuana_Cartel', 'views': 9991, 'rank': 907},
#  {'article': 'Pokémon:_The_First_Movie', 'views': 9974, 'rank': 909},
#  {'article': 'Sam_Smith', 'views': 9968, 'rank': 910},
#  {'article': 'Woken_Furies', 'views': 9965, 'rank': 911},
#  {'article': 'Daniel_Radcliffe', 'views': 9961, 'rank': 912},
#  {'article': 'Rian_Johnson', 'views': 9958, 'rank': 913},
#  {'article': 'Andy_Gibb', 'views': 9952, 'rank': 914},
#  {'article': 'The_Favourite', 'views': 9951, 'rank': 915},
#  {'article': '2020_coronavirus_outbreak_in_Switzerland',
#   'views': 9950,
#   'rank': 916},
#  {'article': 'Hand_sanitizer', 'views': 9950, 'rank': 916},
#  {'article': 'Luka_Dončić', 'views': 9948, 'rank': 918},
#  {'article': 'Survivor:_Winners_at_War', 'views': 9937, 'rank': 919},
#  {'article': 'Natalie_Portman', 'views': 9934, 'rank': 920},
#  {'article': 'Beanie_Feldstein', 'views': 9931, 'rank': 921},
#  {'article': 'Gordon_Ramsay', 'views': 9925, 'rank': 922},
#  {'article': 'List_of_Knowing_Bros_episodes', 'views': 9924, 'rank': 923},
#  {'article': 'Darbar_(film)', 'views': 9916, 'rank': 924},
#  {'article': 'List_of_largest_daily_changes_in_the_Dow_Jones_Industrial_Average',
#   'views': 9907,
#   'rank': 925},
#  {'article': 'European_Union', 'views': 9894, 'rank': 926},
#  {'article': 'Maggie_Baird', 'views': 9882, 'rank': 927},
#  {'article': 'The_Andromeda_Strain', 'views': 9873, 'rank': 928},
#  {'article': 'The_Good_Place', 'views': 9871, 'rank': 929},
#  {'article': 'Ronan_Farrow', 'views': 9862, 'rank': 930},
#  {'article': 'The_Masked_Singer_(American_TV_series)',
#   'views': 9832,
#   'rank': 931},
#  {'article': 'London', 'views': 9825, 'rank': 932},
#  {'article': 'Nicolas_Cage', 'views': 9824, 'rank': 933},
#  {'article': 'Julius_Caesar', 'views': 9801, 'rank': 934},
#  {'article': 'American_Civil_War', 'views': 9798, 'rank': 935},
#  {'article': '2020_ATP_Tour', 'views': 9792, 'rank': 936},
#  {'article': 'The_Good_Doctor_(TV_series)', 'views': 9782, 'rank': 937},
#  {'article': 'Frank_Sinatra', 'views': 9771, 'rank': 938},
#  {'article': 'Jumanji:_Welcome_to_the_Jungle', 'views': 9763, 'rank': 939},
#  {'article': 'Superdelegate', 'views': 9756, 'rank': 940},
#  {'article': 'Citizenship_Amendment_Act_protests', 'views': 9754, 'rank': 941},
#  {'article': 'Millie_Bobby_Brown', 'views': 9748, 'rank': 942},
#  {'article': 'Dan_Levy_(Canadian_actor)', 'views': 9747, 'rank': 943},
#  {'article': '2020_coronavirus_outbreak_on_cruise_ships',
#   'views': 9739,
#   'rank': 944},
#  {'article': 'Train_to_Busan', 'views': 9721, 'rank': 945},
#  {'article': 'Spider-Man:_Far_From_Home', 'views': 9717, 'rank': 946},
#  {'article': 'Travis_Scott', 'views': 9716, 'rank': 947},
#  {'article': 'George_W._Bush', 'views': 9712, 'rank': 948},
#  {'article': 'Harry_Potter', 'views': 9711, 'rank': 949},
#  {'article': 'Georgia_Guidestones', 'views': 9710, 'rank': 950},
#  {'article': 'Zion_Williamson', 'views': 9708, 'rank': 951},
#  {'article': 'Anne,_Queen_of_Great_Britain', 'views': 9706, 'rank': 952},
#  {'article': '45th_César_Awards', 'views': 9705, 'rank': 953},
#  {'article': 'The_Buck_Sexton_Show', 'views': 9700, 'rank': 954},
#  {'article': 'Gretel_&_Hansel', 'views': 9678, 'rank': 955},
#  {'article': 'Bangladesh', 'views': 9670, 'rank': 956},
#  {'article': 'Floyd_Mayweather_Jr.', 'views': 9670, 'rank': 956},
#  {'article': 'Matt_Damon', 'views': 9663, 'rank': 958},
#  {'article': 'Milla_Jovovich', 'views': 9657, 'rank': 959},
#  {'article': 'Casino_Royale_(2006_film)', 'views': 9652, 'rank': 960},
#  {'article': 'Wonder_(film)', 'views': 9648, 'rank': 961},
#  {'article': 'Florence_Pugh', 'views': 9636, 'rank': 962},
#  {'article': 'Los_Angeles', 'views': 9634, 'rank': 963},
#  {'article': 'Donald_Trump_Jr.', 'views': 9630, 'rank': 964},
#  {'article': 'Dr._Romantic_2', 'views': 9629, 'rank': 965},
#  {'article': 'John_Wayne', 'views': 9627, 'rank': 966},
#  {'article': 'Sambhaji', 'views': 9624, 'rank': 967},
#  {'article': 'Carol_Kane', 'views': 9617, 'rank': 968},
#  {'article': 'Xenophobia_and_racism_related_to_the_2019–20_coronavirus_outbreak',
#   'views': 9613,
#   'rank': 969},
#  {'article': 'Kevin_Hart', 'views': 9611, 'rank': 970},
#  {'article': 'List_of_the_verified_oldest_people', 'views': 9609, 'rank': 971},
#  {'article': 'Joni_Mitchell', 'views': 9608, 'rank': 972},
#  {'article': 'Goldie_Hawn', 'views': 9605, 'rank': 973},
#  {'article': 'Jack_Nicholson', 'views': 9592, 'rank': 974},
#  {'article': 'Katharine_Ross', 'views': 9585, 'rank': 975},
#  {'article': 'Street_Dancer_3D', 'views': 9584, 'rank': 976},
#  {'article': "Crohn's_disease", 'views': 9571, 'rank': 977},
#  {'article': '2019–20_UEFA_Europa_League', 'views': 9560, 'rank': 978},
#  {'article': 'Telugu_language', 'views': 9555, 'rank': 979},
#  {'article': 'Snoop_Dogg', 'views': 9551, 'rank': 980},
#  {'article': 'The_Witcher', 'views': 9539, 'rank': 981},
#  {'article': 'Meghan,_Duchess_of_Sussex', 'views': 9516, 'rank': 982},
#  {'article': 'Switzerland', 'views': 9510, 'rank': 983},
#  {'article': 'Nasdaq', 'views': 9498, 'rank': 984},
#  {'article': 'Danny_DeVito', 'views': 9494, 'rank': 985},
#  {'article': 'Tony_Robbins', 'views': 9483, 'rank': 986},
#  {'article': 'Renée_Zellweger', 'views': 9482, 'rank': 987},
#  {'article': 'Generation_X', 'views': 9479, 'rank': 988},
#  {'article': '2020', 'views': 9473, 'rank': 989},
#  {'article': 'Socialism', 'views': 9472, 'rank': 990},
#  {'article': 'Britney_Spears', 'views': 9472, 'rank': 990},
#  {'article': 'Paulina_Porizkova', 'views': 9469, 'rank': 992},
#  {'article': 'Hong_Kong', 'views': 9468, 'rank': 993},
#  {'article': 'Idina_Menzel', 'views': 9463, 'rank': 994},
#  {'article': "The_Handmaid's_Tale_(TV_series)", 'views': 9461, 'rank': 995},
#  {'article': 'R._Sundarrajan_(director)', 'views': 9439, 'rank': 996},
#  {'article': 'China_Global_Television_Network', 'views': 9437, 'rank': 997},
#  {'article': 'Pablo_Picasso', 'views': 9423, 'rank': 998},
#  {'article': 'Rami_Malek', 'views': 9420, 'rank': 999},
#  {'article': 'Bloodshot_(film)', 'views': 9414, 'rank': 1000}]

# %%
import pandas as pd
import numpy as np

# %%
date1 = '2020-01-01'
date2 = '2021-01-07'
dates = pd.date_range(date1, date2).tolist()

# %%
dates[0].strftime('%Y')
# Out:
# '2020'

# %%
dates
# Out:
# [Timestamp('2020-01-01 00:00:00', freq='D'),
#  Timestamp('2020-01-02 00:00:00', freq='D'),
#  Timestamp('2020-01-03 00:00:00', freq='D'),
#  Timestamp('2020-01-04 00:00:00', freq='D'),
#  Timestamp('2020-01-05 00:00:00', freq='D'),
#  Timestamp('2020-01-06 00:00:00', freq='D'),
#  Timestamp('2020-01-07 00:00:00', freq='D'),
#  Timestamp('2020-01-08 00:00:00', freq='D'),
#  Timestamp('2020-01-09 00:00:00', freq='D'),
#  Timestamp('2020-01-10 00:00:00', freq='D'),
#  Timestamp('2020-01-11 00:00:00', freq='D'),
#  Timestamp('2020-01-12 00:00:00', freq='D'),
#  Timestamp('2020-01-13 00:00:00', freq='D'),
#  Timestamp('2020-01-14 00:00:00', freq='D'),
#  Timestamp('2020-01-15 00:00:00', freq='D'),
#  Timestamp('2020-01-16 00:00:00', freq='D'),
#  Timestamp('2020-01-17 00:00:00', freq='D'),
#  Timestamp('2020-01-18 00:00:00', freq='D'),
#  Timestamp('2020-01-19 00:00:00', freq='D'),
#  Timestamp('2020-01-20 00:00:00', freq='D'),
#  Timestamp('2020-01-21 00:00:00', freq='D'),
#  Timestamp('2020-01-22 00:00:00', freq='D'),
#  Timestamp('2020-01-23 00:00:00', freq='D'),
#  Timestamp('2020-01-24 00:00:00', freq='D'),
#  Timestamp('2020-01-25 00:00:00', freq='D'),
#  Timestamp('2020-01-26 00:00:00', freq='D'),
#  Timestamp('2020-01-27 00:00:00', freq='D'),
#  Timestamp('2020-01-28 00:00:00', freq='D'),
#  Timestamp('2020-01-29 00:00:00', freq='D'),
#  Timestamp('2020-01-30 00:00:00', freq='D'),
#  Timestamp('2020-01-31 00:00:00', freq='D'),
#  Timestamp('2020-02-01 00:00:00', freq='D'),
#  Timestamp('2020-02-02 00:00:00', freq='D'),
#  Timestamp('2020-02-03 00:00:00', freq='D'),
#  Timestamp('2020-02-04 00:00:00', freq='D'),
#  Timestamp('2020-02-05 00:00:00', freq='D'),
#  Timestamp('2020-02-06 00:00:00', freq='D'),
#  Timestamp('2020-02-07 00:00:00', freq='D'),
#  Timestamp('2020-02-08 00:00:00', freq='D'),
#  Timestamp('2020-02-09 00:00:00', freq='D'),
#  Timestamp('2020-02-10 00:00:00', freq='D'),
#  Timestamp('2020-02-11 00:00:00', freq='D'),
#  Timestamp('2020-02-12 00:00:00', freq='D'),
#  Timestamp('2020-02-13 00:00:00', freq='D'),
#  Timestamp('2020-02-14 00:00:00', freq='D'),
#  Timestamp('2020-02-15 00:00:00', freq='D'),
#  Timestamp('2020-02-16 00:00:00', freq='D'),
#  Timestamp('2020-02-17 00:00:00', freq='D'),
#  Timestamp('2020-02-18 00:00:00', freq='D'),
#  Timestamp('2020-02-19 00:00:00', freq='D'),
#  Timestamp('2020-02-20 00:00:00', freq='D'),
#  Timestamp('2020-02-21 00:00:00', freq='D'),
#  Timestamp('2020-02-22 00:00:00', freq='D'),
#  Timestamp('2020-02-23 00:00:00', freq='D'),
#  Timestamp('2020-02-24 00:00:00', freq='D'),
#  Timestamp('2020-02-25 00:00:00', freq='D'),
#  Timestamp('2020-02-26 00:00:00', freq='D'),
#  Timestamp('2020-02-27 00:00:00', freq='D'),
#  Timestamp('2020-02-28 00:00:00', freq='D'),
#  Timestamp('2020-02-29 00:00:00', freq='D'),
#  Timestamp('2020-03-01 00:00:00', freq='D'),
#  Timestamp('2020-03-02 00:00:00', freq='D'),
#  Timestamp('2020-03-03 00:00:00', freq='D'),
#  Timestamp('2020-03-04 00:00:00', freq='D'),
#  Timestamp('2020-03-05 00:00:00', freq='D'),
#  Timestamp('2020-03-06 00:00:00', freq='D'),
#  Timestamp('2020-03-07 00:00:00', freq='D'),
#  Timestamp('2020-03-08 00:00:00', freq='D'),
#  Timestamp('2020-03-09 00:00:00', freq='D'),
#  Timestamp('2020-03-10 00:00:00', freq='D'),
#  Timestamp('2020-03-11 00:00:00', freq='D'),
#  Timestamp('2020-03-12 00:00:00', freq='D'),
#  Timestamp('2020-03-13 00:00:00', freq='D'),
#  Timestamp('2020-03-14 00:00:00', freq='D'),
#  Timestamp('2020-03-15 00:00:00', freq='D'),
#  Timestamp('2020-03-16 00:00:00', freq='D'),
#  Timestamp('2020-03-17 00:00:00', freq='D'),
#  Timestamp('2020-03-18 00:00:00', freq='D'),
#  Timestamp('2020-03-19 00:00:00', freq='D'),
#  Timestamp('2020-03-20 00:00:00', freq='D'),
#  Timestamp('2020-03-21 00:00:00', freq='D'),
#  Timestamp('2020-03-22 00:00:00', freq='D'),
#  Timestamp('2020-03-23 00:00:00', freq='D'),
#  Timestamp('2020-03-24 00:00:00', freq='D'),
#  Timestamp('2020-03-25 00:00:00', freq='D'),
#  Timestamp('2020-03-26 00:00:00', freq='D'),
#  Timestamp('2020-03-27 00:00:00', freq='D'),
#  Timestamp('2020-03-28 00:00:00', freq='D'),
#  Timestamp('2020-03-29 00:00:00', freq='D'),
#  Timestamp('2020-03-30 00:00:00', freq='D'),
#  Timestamp('2020-03-31 00:00:00', freq='D'),
#  Timestamp('2020-04-01 00:00:00', freq='D'),
#  Timestamp('2020-04-02 00:00:00', freq='D'),
#  Timestamp('2020-04-03 00:00:00', freq='D'),
#  Timestamp('2020-04-04 00:00:00', freq='D'),
#  Timestamp('2020-04-05 00:00:00', freq='D'),
#  Timestamp('2020-04-06 00:00:00', freq='D'),
#  Timestamp('2020-04-07 00:00:00', freq='D'),
#  Timestamp('2020-04-08 00:00:00', freq='D'),
#  Timestamp('2020-04-09 00:00:00', freq='D'),
#  Timestamp('2020-04-10 00:00:00', freq='D'),
#  Timestamp('2020-04-11 00:00:00', freq='D'),
#  Timestamp('2020-04-12 00:00:00', freq='D'),
#  Timestamp('2020-04-13 00:00:00', freq='D'),
#  Timestamp('2020-04-14 00:00:00', freq='D'),
#  Timestamp('2020-04-15 00:00:00', freq='D'),
#  Timestamp('2020-04-16 00:00:00', freq='D'),
#  Timestamp('2020-04-17 00:00:00', freq='D'),
#  Timestamp('2020-04-18 00:00:00', freq='D'),
#  Timestamp('2020-04-19 00:00:00', freq='D'),
#  Timestamp('2020-04-20 00:00:00', freq='D'),
#  Timestamp('2020-04-21 00:00:00', freq='D'),
#  Timestamp('2020-04-22 00:00:00', freq='D'),
#  Timestamp('2020-04-23 00:00:00', freq='D'),
#  Timestamp('2020-04-24 00:00:00', freq='D'),
#  Timestamp('2020-04-25 00:00:00', freq='D'),
#  Timestamp('2020-04-26 00:00:00', freq='D'),
#  Timestamp('2020-04-27 00:00:00', freq='D'),
#  Timestamp('2020-04-28 00:00:00', freq='D'),
#  Timestamp('2020-04-29 00:00:00', freq='D'),
#  Timestamp('2020-04-30 00:00:00', freq='D'),
#  Timestamp('2020-05-01 00:00:00', freq='D'),
#  Timestamp('2020-05-02 00:00:00', freq='D'),
#  Timestamp('2020-05-03 00:00:00', freq='D'),
#  Timestamp('2020-05-04 00:00:00', freq='D'),
#  Timestamp('2020-05-05 00:00:00', freq='D'),
#  Timestamp('2020-05-06 00:00:00', freq='D'),
#  Timestamp('2020-05-07 00:00:00', freq='D'),
#  Timestamp('2020-05-08 00:00:00', freq='D'),
#  Timestamp('2020-05-09 00:00:00', freq='D'),
#  Timestamp('2020-05-10 00:00:00', freq='D'),
#  Timestamp('2020-05-11 00:00:00', freq='D'),
#  Timestamp('2020-05-12 00:00:00', freq='D'),
#  Timestamp('2020-05-13 00:00:00', freq='D'),
#  Timestamp('2020-05-14 00:00:00', freq='D'),
#  Timestamp('2020-05-15 00:00:00', freq='D'),
#  Timestamp('2020-05-16 00:00:00', freq='D'),
#  Timestamp('2020-05-17 00:00:00', freq='D'),
#  Timestamp('2020-05-18 00:00:00', freq='D'),
#  Timestamp('2020-05-19 00:00:00', freq='D'),
#  Timestamp('2020-05-20 00:00:00', freq='D'),
#  Timestamp('2020-05-21 00:00:00', freq='D'),
#  Timestamp('2020-05-22 00:00:00', freq='D'),
#  Timestamp('2020-05-23 00:00:00', freq='D'),
#  Timestamp('2020-05-24 00:00:00', freq='D'),
#  Timestamp('2020-05-25 00:00:00', freq='D'),
#  Timestamp('2020-05-26 00:00:00', freq='D'),
#  Timestamp('2020-05-27 00:00:00', freq='D'),
#  Timestamp('2020-05-28 00:00:00', freq='D'),
#  Timestamp('2020-05-29 00:00:00', freq='D'),
#  Timestamp('2020-05-30 00:00:00', freq='D'),
#  Timestamp('2020-05-31 00:00:00', freq='D'),
#  Timestamp('2020-06-01 00:00:00', freq='D'),
#  Timestamp('2020-06-02 00:00:00', freq='D'),
#  Timestamp('2020-06-03 00:00:00', freq='D'),
#  Timestamp('2020-06-04 00:00:00', freq='D'),
#  Timestamp('2020-06-05 00:00:00', freq='D'),
#  Timestamp('2020-06-06 00:00:00', freq='D'),
#  Timestamp('2020-06-07 00:00:00', freq='D'),
#  Timestamp('2020-06-08 00:00:00', freq='D'),
#  Timestamp('2020-06-09 00:00:00', freq='D'),
#  Timestamp('2020-06-10 00:00:00', freq='D'),
#  Timestamp('2020-06-11 00:00:00', freq='D'),
#  Timestamp('2020-06-12 00:00:00', freq='D'),
#  Timestamp('2020-06-13 00:00:00', freq='D'),
#  Timestamp('2020-06-14 00:00:00', freq='D'),
#  Timestamp('2020-06-15 00:00:00', freq='D'),
#  Timestamp('2020-06-16 00:00:00', freq='D'),
#  Timestamp('2020-06-17 00:00:00', freq='D'),
#  Timestamp('2020-06-18 00:00:00', freq='D'),
#  Timestamp('2020-06-19 00:00:00', freq='D'),
#  Timestamp('2020-06-20 00:00:00', freq='D'),
#  Timestamp('2020-06-21 00:00:00', freq='D'),
#  Timestamp('2020-06-22 00:00:00', freq='D'),
#  Timestamp('2020-06-23 00:00:00', freq='D'),
#  Timestamp('2020-06-24 00:00:00', freq='D'),
#  Timestamp('2020-06-25 00:00:00', freq='D'),
#  Timestamp('2020-06-26 00:00:00', freq='D'),
#  Timestamp('2020-06-27 00:00:00', freq='D'),
#  Timestamp('2020-06-28 00:00:00', freq='D'),
#  Timestamp('2020-06-29 00:00:00', freq='D'),
#  Timestamp('2020-06-30 00:00:00', freq='D'),
#  Timestamp('2020-07-01 00:00:00', freq='D'),
#  Timestamp('2020-07-02 00:00:00', freq='D'),
#  Timestamp('2020-07-03 00:00:00', freq='D'),
#  Timestamp('2020-07-04 00:00:00', freq='D'),
#  Timestamp('2020-07-05 00:00:00', freq='D'),
#  Timestamp('2020-07-06 00:00:00', freq='D'),
#  Timestamp('2020-07-07 00:00:00', freq='D'),
#  Timestamp('2020-07-08 00:00:00', freq='D'),
#  Timestamp('2020-07-09 00:00:00', freq='D'),
#  Timestamp('2020-07-10 00:00:00', freq='D'),
#  Timestamp('2020-07-11 00:00:00', freq='D'),
#  Timestamp('2020-07-12 00:00:00', freq='D'),
#  Timestamp('2020-07-13 00:00:00', freq='D'),
#  Timestamp('2020-07-14 00:00:00', freq='D'),
#  Timestamp('2020-07-15 00:00:00', freq='D'),
#  Timestamp('2020-07-16 00:00:00', freq='D'),
#  Timestamp('2020-07-17 00:00:00', freq='D'),
#  Timestamp('2020-07-18 00:00:00', freq='D'),
#  Timestamp('2020-07-19 00:00:00', freq='D'),
#  Timestamp('2020-07-20 00:00:00', freq='D'),
#  Timestamp('2020-07-21 00:00:00', freq='D'),
#  Timestamp('2020-07-22 00:00:00', freq='D'),
#  Timestamp('2020-07-23 00:00:00', freq='D'),
#  Timestamp('2020-07-24 00:00:00', freq='D'),
#  Timestamp('2020-07-25 00:00:00', freq='D'),
#  Timestamp('2020-07-26 00:00:00', freq='D'),
#  Timestamp('2020-07-27 00:00:00', freq='D'),
#  Timestamp('2020-07-28 00:00:00', freq='D'),
#  Timestamp('2020-07-29 00:00:00', freq='D'),
#  Timestamp('2020-07-30 00:00:00', freq='D'),
#  Timestamp('2020-07-31 00:00:00', freq='D'),
#  Timestamp('2020-08-01 00:00:00', freq='D'),
#  Timestamp('2020-08-02 00:00:00', freq='D'),
#  Timestamp('2020-08-03 00:00:00', freq='D'),
#  Timestamp('2020-08-04 00:00:00', freq='D'),
#  Timestamp('2020-08-05 00:00:00', freq='D'),
#  Timestamp('2020-08-06 00:00:00', freq='D'),
#  Timestamp('2020-08-07 00:00:00', freq='D'),
#  Timestamp('2020-08-08 00:00:00', freq='D'),
#  Timestamp('2020-08-09 00:00:00', freq='D'),
#  Timestamp('2020-08-10 00:00:00', freq='D'),
#  Timestamp('2020-08-11 00:00:00', freq='D'),
#  Timestamp('2020-08-12 00:00:00', freq='D'),
#  Timestamp('2020-08-13 00:00:00', freq='D'),
#  Timestamp('2020-08-14 00:00:00', freq='D'),
#  Timestamp('2020-08-15 00:00:00', freq='D'),
#  Timestamp('2020-08-16 00:00:00', freq='D'),
#  Timestamp('2020-08-17 00:00:00', freq='D'),
#  Timestamp('2020-08-18 00:00:00', freq='D'),
#  Timestamp('2020-08-19 00:00:00', freq='D'),
#  Timestamp('2020-08-20 00:00:00', freq='D'),
#  Timestamp('2020-08-21 00:00:00', freq='D'),
#  Timestamp('2020-08-22 00:00:00', freq='D'),
#  Timestamp('2020-08-23 00:00:00', freq='D'),
#  Timestamp('2020-08-24 00:00:00', freq='D'),
#  Timestamp('2020-08-25 00:00:00', freq='D'),
#  Timestamp('2020-08-26 00:00:00', freq='D'),
#  Timestamp('2020-08-27 00:00:00', freq='D'),
#  Timestamp('2020-08-28 00:00:00', freq='D'),
#  Timestamp('2020-08-29 00:00:00', freq='D'),
#  Timestamp('2020-08-30 00:00:00', freq='D'),
#  Timestamp('2020-08-31 00:00:00', freq='D'),
#  Timestamp('2020-09-01 00:00:00', freq='D'),
#  Timestamp('2020-09-02 00:00:00', freq='D'),
#  Timestamp('2020-09-03 00:00:00', freq='D'),
#  Timestamp('2020-09-04 00:00:00', freq='D'),
#  Timestamp('2020-09-05 00:00:00', freq='D'),
#  Timestamp('2020-09-06 00:00:00', freq='D'),
#  Timestamp('2020-09-07 00:00:00', freq='D'),
#  Timestamp('2020-09-08 00:00:00', freq='D'),
#  Timestamp('2020-09-09 00:00:00', freq='D'),
#  Timestamp('2020-09-10 00:00:00', freq='D'),
#  Timestamp('2020-09-11 00:00:00', freq='D'),
#  Timestamp('2020-09-12 00:00:00', freq='D'),
#  Timestamp('2020-09-13 00:00:00', freq='D'),
#  Timestamp('2020-09-14 00:00:00', freq='D'),
#  Timestamp('2020-09-15 00:00:00', freq='D'),
#  Timestamp('2020-09-16 00:00:00', freq='D'),
#  Timestamp('2020-09-17 00:00:00', freq='D'),
#  Timestamp('2020-09-18 00:00:00', freq='D'),
#  Timestamp('2020-09-19 00:00:00', freq='D'),
#  Timestamp('2020-09-20 00:00:00', freq='D'),
#  Timestamp('2020-09-21 00:00:00', freq='D'),
#  Timestamp('2020-09-22 00:00:00', freq='D'),
#  Timestamp('2020-09-23 00:00:00', freq='D'),
#  Timestamp('2020-09-24 00:00:00', freq='D'),
#  Timestamp('2020-09-25 00:00:00', freq='D'),
#  Timestamp('2020-09-26 00:00:00', freq='D'),
#  Timestamp('2020-09-27 00:00:00', freq='D'),
#  Timestamp('2020-09-28 00:00:00', freq='D'),
#  Timestamp('2020-09-29 00:00:00', freq='D'),
#  Timestamp('2020-09-30 00:00:00', freq='D'),
#  Timestamp('2020-10-01 00:00:00', freq='D'),
#  Timestamp('2020-10-02 00:00:00', freq='D'),
#  Timestamp('2020-10-03 00:00:00', freq='D'),
#  Timestamp('2020-10-04 00:00:00', freq='D'),
#  Timestamp('2020-10-05 00:00:00', freq='D'),
#  Timestamp('2020-10-06 00:00:00', freq='D'),
#  Timestamp('2020-10-07 00:00:00', freq='D'),
#  Timestamp('2020-10-08 00:00:00', freq='D'),
#  Timestamp('2020-10-09 00:00:00', freq='D'),
#  Timestamp('2020-10-10 00:00:00', freq='D'),
#  Timestamp('2020-10-11 00:00:00', freq='D'),
#  Timestamp('2020-10-12 00:00:00', freq='D'),
#  Timestamp('2020-10-13 00:00:00', freq='D'),
#  Timestamp('2020-10-14 00:00:00', freq='D'),
#  Timestamp('2020-10-15 00:00:00', freq='D'),
#  Timestamp('2020-10-16 00:00:00', freq='D'),
#  Timestamp('2020-10-17 00:00:00', freq='D'),
#  Timestamp('2020-10-18 00:00:00', freq='D'),
#  Timestamp('2020-10-19 00:00:00', freq='D'),
#  Timestamp('2020-10-20 00:00:00', freq='D'),
#  Timestamp('2020-10-21 00:00:00', freq='D'),
#  Timestamp('2020-10-22 00:00:00', freq='D'),
#  Timestamp('2020-10-23 00:00:00', freq='D'),
#  Timestamp('2020-10-24 00:00:00', freq='D'),
#  Timestamp('2020-10-25 00:00:00', freq='D'),
#  Timestamp('2020-10-26 00:00:00', freq='D'),
#  Timestamp('2020-10-27 00:00:00', freq='D'),
#  Timestamp('2020-10-28 00:00:00', freq='D'),
#  Timestamp('2020-10-29 00:00:00', freq='D'),
#  Timestamp('2020-10-30 00:00:00', freq='D'),
#  Timestamp('2020-10-31 00:00:00', freq='D'),
#  Timestamp('2020-11-01 00:00:00', freq='D'),
#  Timestamp('2020-11-02 00:00:00', freq='D'),
#  Timestamp('2020-11-03 00:00:00', freq='D'),
#  Timestamp('2020-11-04 00:00:00', freq='D'),
#  Timestamp('2020-11-05 00:00:00', freq='D'),
#  Timestamp('2020-11-06 00:00:00', freq='D'),
#  Timestamp('2020-11-07 00:00:00', freq='D'),
#  Timestamp('2020-11-08 00:00:00', freq='D'),
#  Timestamp('2020-11-09 00:00:00', freq='D'),
#  Timestamp('2020-11-10 00:00:00', freq='D'),
#  Timestamp('2020-11-11 00:00:00', freq='D'),
#  Timestamp('2020-11-12 00:00:00', freq='D'),
#  Timestamp('2020-11-13 00:00:00', freq='D'),
#  Timestamp('2020-11-14 00:00:00', freq='D'),
#  Timestamp('2020-11-15 00:00:00', freq='D'),
#  Timestamp('2020-11-16 00:00:00', freq='D'),
#  Timestamp('2020-11-17 00:00:00', freq='D'),
#  Timestamp('2020-11-18 00:00:00', freq='D'),
#  Timestamp('2020-11-19 00:00:00', freq='D'),
#  Timestamp('2020-11-20 00:00:00', freq='D'),
#  Timestamp('2020-11-21 00:00:00', freq='D'),
#  Timestamp('2020-11-22 00:00:00', freq='D'),
#  Timestamp('2020-11-23 00:00:00', freq='D'),
#  Timestamp('2020-11-24 00:00:00', freq='D'),
#  Timestamp('2020-11-25 00:00:00', freq='D'),
#  Timestamp('2020-11-26 00:00:00', freq='D'),
#  Timestamp('2020-11-27 00:00:00', freq='D'),
#  Timestamp('2020-11-28 00:00:00', freq='D'),
#  Timestamp('2020-11-29 00:00:00', freq='D'),
#  Timestamp('2020-11-30 00:00:00', freq='D'),
#  Timestamp('2020-12-01 00:00:00', freq='D'),
#  Timestamp('2020-12-02 00:00:00', freq='D'),
#  Timestamp('2020-12-03 00:00:00', freq='D'),
#  Timestamp('2020-12-04 00:00:00', freq='D'),
#  Timestamp('2020-12-05 00:00:00', freq='D'),
#  Timestamp('2020-12-06 00:00:00', freq='D'),
#  Timestamp('2020-12-07 00:00:00', freq='D'),
#  Timestamp('2020-12-08 00:00:00', freq='D'),
#  Timestamp('2020-12-09 00:00:00', freq='D'),
#  Timestamp('2020-12-10 00:00:00', freq='D'),
#  Timestamp('2020-12-11 00:00:00', freq='D'),
#  Timestamp('2020-12-12 00:00:00', freq='D'),
#  Timestamp('2020-12-13 00:00:00', freq='D'),
#  Timestamp('2020-12-14 00:00:00', freq='D'),
#  Timestamp('2020-12-15 00:00:00', freq='D'),
#  Timestamp('2020-12-16 00:00:00', freq='D'),
#  Timestamp('2020-12-17 00:00:00', freq='D'),
#  Timestamp('2020-12-18 00:00:00', freq='D'),
#  Timestamp('2020-12-19 00:00:00', freq='D'),
#  Timestamp('2020-12-20 00:00:00', freq='D'),
#  Timestamp('2020-12-21 00:00:00', freq='D'),
#  Timestamp('2020-12-22 00:00:00', freq='D'),
#  Timestamp('2020-12-23 00:00:00', freq='D'),
#  Timestamp('2020-12-24 00:00:00', freq='D'),
#  Timestamp('2020-12-25 00:00:00', freq='D'),
#  Timestamp('2020-12-26 00:00:00', freq='D'),
#  Timestamp('2020-12-27 00:00:00', freq='D'),
#  Timestamp('2020-12-28 00:00:00', freq='D'),
#  Timestamp('2020-12-29 00:00:00', freq='D'),
#  Timestamp('2020-12-30 00:00:00', freq='D'),
#  Timestamp('2020-12-31 00:00:00', freq='D'),
#  Timestamp('2021-01-01 00:00:00', freq='D'),
#  Timestamp('2021-01-02 00:00:00', freq='D'),
#  Timestamp('2021-01-03 00:00:00', freq='D'),
#  Timestamp('2021-01-04 00:00:00', freq='D'),
#  Timestamp('2021-01-05 00:00:00', freq='D'),
#  Timestamp('2021-01-06 00:00:00', freq='D'),
#  Timestamp('2021-01-07 00:00:00', freq='D')]

# %%
#array of 25 most popular articles
top_array = []

for date in dates:
    year=date.strftime('%Y')
    month = date.strftime('%m')
    day = date.strftime('%d')
    print(date)
#     wiki_info = get_wiki_info('en', 'wikipedia')
    raw_traffic = get_traffic(year, month, day)
    articles = [a for a in raw_traffic if is_article(a['article'], wiki_info)]
    top_array.append(articles[:25])
# Out:
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-28 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-24 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-21 00:00:00
# 2020-05-22 00:00:00
# 2020-05-23 00:00:00
# 2020-05-24 00:00:00
# 2020-05-25 00:00:00
# 2020-05-26 00:00:00
# 2020-05-27 00:00:00
# 2020-05-28 00:00:00
# 2020-05-29 00:00:00
# 2020-05-30 00:00:00
# 2020-05-31 00:00:00
# 2020-06-01 00:00:00
# 2020-06-02 00:00:00
# 2020-06-03 00:00:00
# 2020-06-04 00:00:00
# 2020-06-05 00:00:00
# 2020-06-06 00:00:00
# 2020-06-07 00:00:00
# 2020-06-08 00:00:00
# 2020-06-09 00:00:00
# 2020-06-10 00:00:00
# 2020-06-11 00:00:00
# 2020-06-12 00:00:00
# 2020-06-13 00:00:00
# 2020-06-14 00:00:00
# 2020-06-15 00:00:00
# 2020-06-16 00:00:00
# 2020-06-17 00:00:00
# 2020-06-18 00:00:00
# 2020-06-19 00:00:00
# 2020-06-20 00:00:00
# 2020-06-21 00:00:00
# 2020-06-22 00:00:00
# 2020-06-23 00:00:00
# 2020-06-24 00:00:00
# 2020-06-25 00:00:00
# 2020-06-26 00:00:00
# 2020-06-27 00:00:00
# 2020-06-28 00:00:00
# 2020-06-29 00:00:00
# 2020-06-30 00:00:00
# 2020-07-01 00:00:00
# 2020-07-02 00:00:00
# 2020-07-03 00:00:00
# 2020-07-04 00:00:00
# 2020-07-05 00:00:00
# 2020-07-06 00:00:00
# 2020-07-07 00:00:00
# 2020-07-08 00:00:00
# 2020-07-09 00:00:00
# 2020-07-10 00:00:00
# 2020-07-11 00:00:00
# 2020-07-12 00:00:00
# 2020-07-13 00:00:00
# 2020-07-14 00:00:00
# 2020-07-15 00:00:00
# 2020-07-16 00:00:00
# 2020-07-17 00:00:00
# 2020-07-18 00:00:00
# 2020-07-19 00:00:00
# 2020-07-20 00:00:00
# 2020-07-21 00:00:00
# 2020-07-22 00:00:00
# 2020-07-23 00:00:00
# 2020-07-24 00:00:00
# 2020-07-25 00:00:00
# 2020-07-26 00:00:00
# 2020-07-27 00:00:00
# 2020-07-28 00:00:00
# 2020-07-29 00:00:00
# 2020-07-30 00:00:00
# 2020-07-31 00:00:00
# 2020-08-01 00:00:00
# 2020-08-02 00:00:00
# 2020-08-03 00:00:00
# 2020-08-04 00:00:00
# 2020-08-05 00:00:00
# 2020-08-06 00:00:00
# 2020-08-07 00:00:00
# 2020-08-08 00:00:00
# 2020-08-09 00:00:00
# 2020-08-10 00:00:00
# 2020-08-11 00:00:00
# 2020-08-12 00:00:00
# 2020-08-13 00:00:00
# 2020-08-14 00:00:00
# 2020-08-15 00:00:00
# 2020-08-16 00:00:00
# 2020-08-17 00:00:00
# 2020-08-18 00:00:00
# 2020-08-19 00:00:00
# 2020-08-20 00:00:00
# 2020-08-21 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-03 00:00:00
# 2020-09-04 00:00:00
# 2020-09-05 00:00:00
# 2020-09-06 00:00:00
# 2020-09-07 00:00:00
# 2020-09-08 00:00:00
# 2020-09-09 00:00:00
# 2020-09-10 00:00:00
# 2020-09-11 00:00:00
# 2020-09-12 00:00:00
# 2020-09-13 00:00:00
# 2020-09-14 00:00:00
# 2020-09-15 00:00:00
# 2020-09-16 00:00:00
# 2020-09-17 00:00:00
# 2020-09-18 00:00:00
# 2020-09-19 00:00:00
# 2020-09-20 00:00:00
# 2020-09-21 00:00:00
# 2020-09-22 00:00:00
# 2020-09-23 00:00:00
# 2020-09-24 00:00:00
# 2020-09-25 00:00:00
# 2020-09-26 00:00:00
# 2020-09-27 00:00:00
# 2020-09-28 00:00:00
# 2020-09-29 00:00:00
# 2020-09-30 00:00:00
# 2020-10-01 00:00:00
# 2020-10-02 00:00:00
# 2020-10-03 00:00:00
# 2020-10-04 00:00:00
# 2020-10-05 00:00:00
# 2020-10-06 00:00:00
# 2020-10-07 00:00:00
# 2020-10-08 00:00:00
# 2020-10-09 00:00:00
# 2020-10-10 00:00:00
# 2020-10-11 00:00:00
# 2020-10-12 00:00:00
# 2020-10-13 00:00:00
# 2020-10-14 00:00:00
# 2020-10-15 00:00:00
# 2020-10-16 00:00:00
# 2020-10-17 00:00:00
# 2020-10-18 00:00:00
# 2020-10-19 00:00:00
# 2020-10-20 00:00:00
# 2020-10-21 00:00:00
# 2020-10-22 00:00:00
# 2020-10-23 00:00:00
# 2020-10-24 00:00:00
# 2020-10-25 00:00:00
# 2020-10-26 00:00:00
# 2020-10-27 00:00:00
# 2020-10-28 00:00:00
# 2020-10-29 00:00:00
# 2020-10-30 00:00:00
# 2020-10-31 00:00:00
# 2020-11-01 00:00:00
# 2020-11-02 00:00:00
# 2020-11-03 00:00:00
# 2020-11-04 00:00:00
# 2020-11-05 00:00:00
# 2020-11-06 00:00:00
# 2020-11-07 00:00:00
# 2020-11-08 00:00:00
# 2020-11-09 00:00:00
# 2020-11-10 00:00:00
# 2020-11-11 00:00:00
# 2020-11-12 00:00:00
# 2020-11-13 00:00:00
# 2020-11-14 00:00:00
# 2020-11-15 00:00:00
# 2020-11-16 00:00:00
# 2020-11-17 00:00:00
# 2020-11-18 00:00:00
# 2020-11-19 00:00:00
# 2020-11-20 00:00:00
# 2020-11-21 00:00:00
# 2020-11-22 00:00:00
# 2020-11-23 00:00:00
# 2020-11-24 00:00:00
# 2020-11-25 00:00:00
# 2020-11-26 00:00:00
# 2020-11-27 00:00:00
# 2020-11-28 00:00:00
# 2020-11-29 00:00:00
# 2020-11-30 00:00:00
# 2020-12-01 00:00:00
# 2020-12-02 00:00:00
# 2020-12-03 00:00:00
# 2020-12-04 00:00:00
# 2020-12-05 00:00:00
# 2020-12-06 00:00:00
# 2020-12-07 00:00:00
# 2020-12-08 00:00:00
# 2020-12-09 00:00:00
# 2020-12-10 00:00:00
# 2020-12-11 00:00:00
# 2020-12-12 00:00:00
# 2020-12-13 00:00:00
# 2020-12-14 00:00:00
# 2020-12-15 00:00:00
# 2020-12-16 00:00:00
# 2020-12-17 00:00:00
# 2020-12-18 00:00:00
# 2020-12-19 00:00:00
# 2020-12-20 00:00:00
# 2020-12-21 00:00:00
# 2020-12-22 00:00:00
# 2020-12-23 00:00:00
# 2020-12-24 00:00:00
# 2020-12-25 00:00:00
# 2020-12-26 00:00:00
# 2020-12-27 00:00:00
# 2020-12-28 00:00:00
# 2020-12-29 00:00:00
# 2020-12-30 00:00:00
# 2020-12-31 00:00:00
# 2021-01-01 00:00:00
# 2021-01-02 00:00:00
# 2021-01-03 00:00:00
# 2021-01-04 00:00:00
# 2021-01-05 00:00:00
# 2021-01-06 00:00:00
# 2021-01-07 00:00:00

# %%
top_array[0][0]
# Out:
# {'article': 'Post_Malone', 'views': 415705, 'rank': 3}

# %%
dates_array = []
views_array = []
articles_array = []
ranks_array = []

for i in range(len(top_array)):
    date = dates[i]
    array = top_array[i]
    for j in range(25):
        row = array[j]
        dates_array.append(date)
        articles_array.append(row['article'].replace('_', ' '))
#         print(articles_array)
        views_array.append(row['views'])
        ranks_array.append(row['rank'])

# %%
len(dates_array)
# articles_array
# Out:
# 9325

# %%
dict = {'date': dates_array, 'article': articles_array, 'views': views_array, 'rank': ranks_array}
df = pd.DataFrame(data=dict)
df
# Out:
#            date                                   article   views  rank
# 0    2020-01-01                               Post Malone  415705     3
# 1    2020-01-01                            New Year's Day  277191     4
# 2    2020-01-01                         Natašha Stanković  255088     5
# 3    2020-01-01                               Paula Abdul  246877     6
# 4    2020-01-01                   The Witcher (TV series)  244934     7
# ...         ...                                       ...     ...   ...
# 9320 2021-01-07                                Mike Pence  172759    23
# 9321 2021-01-07                                 Joe Biden  164591    24
# 9322 2021-01-07  2020 United States presidential election  160966    25
# 9323 2021-01-07                                     Bible  148171    26
# 9324 2021-01-07                                 Ben Sasse  143082    27
#
# [9325 rows x 4 columns]

# %%
df[df.article == "United States Senate"]
# Out:
# Empty DataFrame
# Columns: [date, article, views, rank]
# Index: []

# %%
df.sort_values(by="views", ascending=False)
# Out:
#            date                     article    views  rank
# 6025 2020-08-29            Chadwick Boseman  9929065     1
# 625  2020-01-26                 Kobe Bryant  9513452     2
# 650  2020-01-27                 Kobe Bryant  8045344     2
# 4125 2020-06-14        Sushant Singh Rajput  7062335     1
# 7800 2020-11-08               Kamala Harris  6591413     1
# ...         ...                         ...      ...   ...
# 3571 2020-05-22                   Candy Ken    58373    25
# 3572 2020-05-22  COVID-19 pandemic in India    57314    26
# 3573 2020-05-22          Paul Warner Powell    57105    27
# 5524 2020-08-08           Jerry Falwell Jr.    56988    27
# 3574 2020-05-22                 Eid al-Fitr    56827    28
#
# [9325 rows x 4 columns]

# %%
df.groupby('article').count()
# Out:
#                                 date  views  rank
# article
# 13 Ghosts                          1      1     1
# 13 Reasons Why                     5      5     5
# 1838                               1      1     1
# 1917 (2019 film)                  24     24    24
# 1927 Liberian general election     1      1     1
# ...                              ...    ...   ...
# Zone Rouge                         1      1     1
# Zoo hypothesis                     1      1     1
# Zooey Deschanel                    3      3     3
# special:search                     1      1     1
# Élan School                        1      1     1
#
# [2979 rows x 3 columns]

# %%
df.groupby('article').agg({'date':'first', 
                         'views':'max', 
                         'rank':'count'}).sort_values(by=['views'], ascending=False)
# Out:
#                                       date    views  rank
# article
# Chadwick Boseman                2020-08-29  9929065    12
# Kobe Bryant                     2020-01-26  9513452    22
# Sushant Singh Rajput            2020-06-14  7062335    33
# Kamala Harris                   2020-07-29  6591413    40
# United States Electoral College 2020-10-27  4986159    13
# ...                                    ...      ...   ...
# Dany Garcia                     2020-08-03    61620     1
# Brian Cage                      2020-05-24    60418     1
# Maurizio Sarri                  2020-08-08    59633     1
# Robert Sheehan                  2020-08-03    59413     1
# Parmeet Sethi                   2020-08-08    58511     1
#
# [2979 rows x 3 columns]

# %%
df.to_csv('wiki_pageviews_jan-jan.csv')
